# %% [markdown]
# Clustering Analysis: Use clustering algorithms such as K-means or DBSCAN to identify groups or clusters of plants based on their chemical compositions. This can help identify similarities and differences among different plant species. Find hidden structures is the data that are not immidiately availible. K-means - groups of simmilar instances - the closest centroid to each data sample.

# %%
import pandas as pd

# Load the data and set the first column as the index
data = pd.read_csv('./initial_data/chemicals_data_clean.csv', index_col=0)

# Extract row indices (species)
species_list = data.index.tolist()

# Count the total number of species
species_count = len(species_list)

# Create a new DataFrame from the species list
species_df = pd.DataFrame(species_list, columns=['Plant_Species'])

# Save the new DataFrame to a CSV file
species_df.to_csv('./initial_data/plant_species_list.csv', index=False)

# Print the total number of species
print(f'Total number of species: {species_count}')
# Out:
# Total number of species: 4087

# %% [markdown]
# Part 2: Clustering
#
# This part will perform the clustering using Euclidian distances
#
# This script will save a separate CSV file for each cluster. Each file will contain a similarity matrix for the plants within that cluster. The filename will include the cluster number for identification. The similarity scores are calculated by normalizing the distances (dividing by the maximum distance) and then subtracting from 1, so that a higher score corresponds to greater similarity.
#
# Part 3: This script will create an additional CSV file for each cluster, which contains only the plants that have similarity scores greater than 90% to at least one other plant within the same cluster. The filename will include the cluster number for identification.
#
# In this script, for each cluster I've created a list of tuples where each tuple consists of a high-similarity plant and a list of plants to which it's similar to more than 80%. This list of tuples is then converted to a DataFrame and saved to a CSV file. The filename includes the cluster number for identification.

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, pairwise_distances
from tqdm import tqdm
import numpy as np
import os

# Load the data
df = pd.read_csv('./initial_data/chemicals_data_clean.csv', index_col=0)

# Set the range of number of clusters to explore
min_clusters = 30
max_clusters = min(len(df), 150)

# Initialize variables
best_score = -1
best_num_clusters = -1
silhouette_scores = []

# Create directory for saving outputs
output_directory = "./initial_data/clusters_euclidean"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Perform Agglomerative Clustering for different numbers of clusters
for num_clusters in tqdm(range(min_clusters, max_clusters + 1), desc='Clustering'):
    clustering = AgglomerativeClustering(n_clusters=num_clusters, metric='euclidean', linkage='ward')
    cluster_labels = clustering.fit_predict(df.values)
    
    silhouette_avg = silhouette_score(df.values, cluster_labels)
    silhouette_scores.append(silhouette_avg)

    # Check if the current silhouette score is the best so far
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_num_clusters = num_clusters

# Perform Agglomerative Clustering with the best number of clusters
clustering = AgglomerativeClustering(n_clusters=best_num_clusters, metric='euclidean', linkage='ward')
cluster_labels = clustering.fit_predict(df.values)

# Assign cluster labels to plants
df['cluster'] = cluster_labels

# Enforce no more than 50 plants per cluster
cluster_sizes = df.groupby('cluster').size()
for i in cluster_sizes[cluster_sizes > 50].index:
    excess = df[df['cluster'] == i].sample(cluster_sizes[i] - 50, replace=False)
    df.loc[excess.index, 'cluster'] = max(df['cluster']) + 1

# For each cluster, extract the subset of the DataFrame, calculate similarity scores, and save to CSV files
for cluster in set(df['cluster']):
    cluster_df = df[df['cluster'] == cluster].drop('cluster', axis=1)
    cluster_df.to_csv(f'{output_directory}/cluster_{cluster}_chemical_compositions.csv')
    
    distances = pairwise_distances(cluster_df.values)
    similarities = 1 - distances / distances.max()
    similarities_df = pd.DataFrame(similarities, index=cluster_df.index, columns=cluster_df.index)
    similarities_df.to_csv(f'{output_directory}/cluster_{cluster}_plant_similarities.csv')

print('Number of clusters:', len(set(df['cluster'])))
# Out:
# Clustering: 100%|███████████████| 121/121 [18:57<00:00,  9.40s/it]
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3534108466.py:57: RuntimeWarning: invalid value encountered in divide
#   similarities = 1 - distances / distances.max()
# Number of clusters: 175

# %% [markdown]
# Now we delete all columns that only contain zeroes in every CSV cluster file.

# %%
import pandas as pd
import glob

# Get list of all CSV files
csv_files = glob.glob("./initial_data/clusters_euclidean/cluster_*_chemical_compositions.csv")

for file in csv_files:
    # Load file into DataFrame
    df = pd.read_csv(file)
    
    # Get columns that only contain zero
    zero_cols = [col for col in df.columns if (df[col] == 0).all()]
    
    # Drop these columns
    df = df.drop(zero_cols, axis=1)
    
    # Write cleaned DataFrame back to CSV
    df.to_csv(file, index=False)

print("All files have been cleaned.")
# Out:
# All files have been cleaned.

# %% [markdown]
# Part 3 high similarity

# %% [markdown]
# This script will generate a PDF file for each high similarity pairs CSV file that contains a heatmap. The heatmap shows the similarity scores between pairs of plants.To cluster plants that are most similar to each other together in the heatmap, we can use hierarchical clustering which creates a tree of clusters, which we can then cut at a certain level to create a heat map where similar items are placed next to each other.
#
# To create meaningful titles for our heatmaps, we will extract the family names from the plant names, identify the unique families within each cluster, and then use this information to create a title that reflects the commonality among the plants in the cluster.

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# Function to extract family names
def extract_family(plant_name):
    match = re.search(r'fam\. (\w+)', plant_name)
    if match:
        return match.group(1)
    
    match = re.search(r'\(([^)]+)\)', plant_name)
    if match and len(match.group(1)) >= 4:
        return match.group(1)
    
    words = plant_name.split()
    for word in reversed(words):
        if len(word) >= 4:
            return word
    return plant_name

# Set paths
path = './initial_data/clusters_euclidean/'
output_dir = './initial_data/clusters_euclidean/heatmaps/'

# Create output directory if it does not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load cluster files
cluster_files = [file for file in os.listdir(path) if 'plant_similarities' in file]
print(f"Found {len(cluster_files)} cluster files.")

for cluster_file in cluster_files:
    print(f"Processing {cluster_file}...")
    
    # Load similarity data
    similarity_df = pd.read_csv(path + cluster_file, index_col=0)
    
    # Remove rows and columns that are all NaN
    similarity_df = similarity_df.dropna(axis=0, how='all')
    similarity_df = similarity_df.dropna(axis=1, how='all')

    # Check if DataFrame is empty after removing NaN values
    if similarity_df.empty:
        print(f"Skipping {cluster_file} because it's empty after removing NaN values.")
        continue

    # Extract family names from plant names and identify unique families
    families = set(extract_family(name) for name in similarity_df.index)
    common_families = ', '.join(families)

    # Create a title for the heatmap
    cluster_number = re.search(r'\d+', cluster_file).group()  # Extract cluster number from file name
    title = f"Cluster {cluster_number} Heatmap: Common Families - {common_families}"


    # Calculate the font size based on cluster size
    num_plants = len(similarity_df)
    max_cluster_size = 100
    font_ratio = num_plants / max_cluster_size
    font_size = max(8, int(8 * font_ratio))
    annot_font_size = max(6, int(6 * font_ratio))  # Adjust font size for annotations
    
    # Create a mask for the mirror part of the heatmap
    mask = np.triu(np.ones_like(similarity_df, dtype=bool))
    
    # Create a figure and axes
    fig, ax = plt.subplots(figsize=(20, 15))
    
    # Visualize the similarity scores using a masked heatmap
    heatmap = sns.heatmap(similarity_df, cmap="YlGnBu", mask=mask, ax=ax,
                          cbar_kws={'label': 'Similarity Score', 'format': '%.1f'},
                          annot=True, fmt=".1f", annot_kws={'fontsize': annot_font_size})  # Adjust font size
    
    # Set the title for the heatmap
    ax.set_title(title, fontsize=font_size)
    
    # Add a legend explaining the heatmap colors
    cbar = heatmap.collections[0].colorbar
    cbar.set_label('Similarity Score Legend')
    
    # Save the heatmap as a vector-based PDF file
    output_file = cluster_file.replace('_plant_similarities.csv', '.pdf')
    output_path = os.path.join(output_dir, output_file)
    fig.savefig(output_path, format='pdf', bbox_inches='tight')
    plt.close()
    
print("All done.")
# Out:
# Found 175 cluster files.
# Processing cluster_105_plant_similarities.csv...
# Processing cluster_34_plant_similarities.csv...
# Processing cluster_170_plant_similarities.csv...
# Processing cluster_41_plant_similarities.csv...
# Processing cluster_80_plant_similarities.csv...
# Processing cluster_141_plant_similarities.csv...
# Processing cluster_70_plant_similarities.csv...
# Processing cluster_5_plant_similarities.csv...
# Processing cluster_134_plant_similarities.csv...
# Processing cluster_102_plant_similarities.csv...
# Processing cluster_33_plant_similarities.csv...
# Processing cluster_46_plant_similarities.csv...
# Processing cluster_87_plant_similarities.csv...
# Processing cluster_39_plant_similarities.csv...
# Processing cluster_108_plant_similarities.csv...
# Processing cluster_139_plant_similarities.csv...
# Processing cluster_8_plant_similarities.csv...
# Processing cluster_146_plant_similarities.csv...
# Processing cluster_77_plant_similarities.csv...
# Processing cluster_2_plant_similarities.csv...
# Processing cluster_133_plant_similarities.csv...
# Skipping cluster_133_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_45_plant_similarities.csv...
# Processing cluster_174_plant_similarities.csv...
# Processing cluster_84_plant_similarities.csv...
# Processing cluster_30_plant_similarities.csv...
# Processing cluster_101_plant_similarities.csv...
# Processing cluster_130_plant_similarities.csv...
# Skipping cluster_130_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_74_plant_similarities.csv...
# Processing cluster_145_plant_similarities.csv...
# Processing cluster_1_plant_similarities.csv...
# Processing cluster_48_plant_similarities.csv...
# Processing cluster_89_plant_similarities.csv...
# Processing cluster_42_plant_similarities.csv...
# Processing cluster_173_plant_similarities.csv...
# Processing cluster_83_plant_similarities.csv...
# Processing cluster_37_plant_similarities.csv...
# Processing cluster_106_plant_similarities.csv...
# Processing cluster_137_plant_similarities.csv...
# Skipping cluster_137_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_73_plant_similarities.csv...
# Processing cluster_142_plant_similarities.csv...
# Processing cluster_6_plant_similarities.csv...
# Processing cluster_148_plant_similarities.csv...
# Processing cluster_79_plant_similarities.csv...
# Processing cluster_149_plant_similarities.csv...
# Processing cluster_78_plant_similarities.csv...
# Processing cluster_136_plant_similarities.csv...
# Processing cluster_7_plant_similarities.csv...
# Processing cluster_72_plant_similarities.csv...
# Processing cluster_143_plant_similarities.csv...
# Skipping cluster_143_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_82_plant_similarities.csv...
# Processing cluster_43_plant_similarities.csv...
# Processing cluster_172_plant_similarities.csv...
# Processing cluster_36_plant_similarities.csv...
# Processing cluster_107_plant_similarities.csv...
# Processing cluster_88_plant_similarities.csv...
# Processing cluster_49_plant_similarities.csv...
# Processing cluster_131_plant_similarities.csv...
# Processing cluster_0_plant_similarities.csv...
# Processing cluster_75_plant_similarities.csv...
# Processing cluster_144_plant_similarities.csv...
# Processing cluster_85_plant_similarities.csv...
# Processing cluster_44_plant_similarities.csv...
# Processing cluster_31_plant_similarities.csv...
# Processing cluster_100_plant_similarities.csv...
# Processing cluster_3_plant_similarities.csv...
# Processing cluster_147_plant_similarities.csv...
# Skipping cluster_147_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_76_plant_similarities.csv...
# Processing cluster_132_plant_similarities.csv...
# Skipping cluster_132_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_138_plant_similarities.csv...
# Processing cluster_9_plant_similarities.csv...
# Processing cluster_38_plant_similarities.csv...
# Processing cluster_109_plant_similarities.csv...
# Processing cluster_103_plant_similarities.csv...
# Processing cluster_32_plant_similarities.csv...
# Processing cluster_86_plant_similarities.csv...
# Processing cluster_47_plant_similarities.csv...
# Processing cluster_4_plant_similarities.csv...
# Processing cluster_140_plant_similarities.csv...
# Processing cluster_71_plant_similarities.csv...
# Processing cluster_135_plant_similarities.csv...
# Skipping cluster_135_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_104_plant_similarities.csv...
# Processing cluster_35_plant_similarities.csv...
# Processing cluster_81_plant_similarities.csv...
# Processing cluster_171_plant_similarities.csv...
# Processing cluster_40_plant_similarities.csv...
# Processing cluster_158_plant_similarities.csv...
# Processing cluster_69_plant_similarities.csv...
# Processing cluster_63_plant_similarities.csv...
# Processing cluster_152_plant_similarities.csv...
# Processing cluster_16_plant_similarities.csv...
# Processing cluster_127_plant_similarities.csv...
# Processing cluster_27_plant_similarities.csv...
# Processing cluster_116_plant_similarities.csv...
# Processing cluster_52_plant_similarities.csv...
# Processing cluster_163_plant_similarities.csv...
# Processing cluster_93_plant_similarities.csv...
# Processing cluster_169_plant_similarities.csv...
# Processing cluster_58_plant_similarities.csv...
# Processing cluster_99_plant_similarities.csv...
# Processing cluster_64_plant_similarities.csv...
# Processing cluster_155_plant_similarities.csv...
# Processing cluster_11_plant_similarities.csv...
# Processing cluster_120_plant_similarities.csv...
# Processing cluster_20_plant_similarities.csv...
# Processing cluster_111_plant_similarities.csv...
# Processing cluster_55_plant_similarities.csv...
# Processing cluster_164_plant_similarities.csv...
# Processing cluster_94_plant_similarities.csv...
# Processing cluster_123_plant_similarities.csv...
# Processing cluster_12_plant_similarities.csv...
# Processing cluster_156_plant_similarities.csv...
# Processing cluster_67_plant_similarities.csv...
# Processing cluster_18_plant_similarities.csv...
# Processing cluster_129_plant_similarities.csv...
# Processing cluster_29_plant_similarities.csv...
# Processing cluster_118_plant_similarities.csv...
# Processing cluster_167_plant_similarities.csv...
# Processing cluster_56_plant_similarities.csv...
# Processing cluster_97_plant_similarities.csv...
# Processing cluster_112_plant_similarities.csv...
# Processing cluster_23_plant_similarities.csv...
# Processing cluster_124_plant_similarities.csv...
# Processing cluster_15_plant_similarities.csv...
# Processing cluster_151_plant_similarities.csv...
# Processing cluster_60_plant_similarities.csv...
# Processing cluster_160_plant_similarities.csv...
# Processing cluster_51_plant_similarities.csv...
# Processing cluster_90_plant_similarities.csv...
# Processing cluster_115_plant_similarities.csv...
# Processing cluster_24_plant_similarities.csv...
# Processing cluster_91_plant_similarities.csv...
# Processing cluster_161_plant_similarities.csv...
# Processing cluster_50_plant_similarities.csv...
# Processing cluster_114_plant_similarities.csv...
# Processing cluster_25_plant_similarities.csv...
# Processing cluster_125_plant_similarities.csv...
# Processing cluster_14_plant_similarities.csv...
# Processing cluster_150_plant_similarities.csv...
# Processing cluster_61_plant_similarities.csv...
# Processing cluster_96_plant_similarities.csv...
# Processing cluster_166_plant_similarities.csv...
# Processing cluster_57_plant_similarities.csv...
# Processing cluster_113_plant_similarities.csv...
# Processing cluster_22_plant_similarities.csv...
# Processing cluster_28_plant_similarities.csv...
# Processing cluster_119_plant_similarities.csv...
# Processing cluster_19_plant_similarities.csv...
# Processing cluster_128_plant_similarities.csv...
# Processing cluster_122_plant_similarities.csv...
# Processing cluster_13_plant_similarities.csv...
# Processing cluster_157_plant_similarities.csv...
# Processing cluster_66_plant_similarities.csv...
# Processing cluster_21_plant_similarities.csv...
# Processing cluster_110_plant_similarities.csv...
# Processing cluster_95_plant_similarities.csv...
# Processing cluster_54_plant_similarities.csv...
# Processing cluster_165_plant_similarities.csv...
# Skipping cluster_165_plant_similarities.csv because it's empty after removing NaN values.
# Processing cluster_65_plant_similarities.csv...
# Processing cluster_154_plant_similarities.csv...
# Processing cluster_10_plant_similarities.csv...
# Processing cluster_121_plant_similarities.csv...
# Processing cluster_98_plant_similarities.csv...
# Processing cluster_168_plant_similarities.csv...
# Processing cluster_59_plant_similarities.csv...
# Processing cluster_26_plant_similarities.csv...
# Processing cluster_117_plant_similarities.csv...
# Processing cluster_92_plant_similarities.csv...
# Processing cluster_53_plant_similarities.csv...
# Processing cluster_162_plant_similarities.csv...
# Processing cluster_62_plant_similarities.csv...
# Processing cluster_153_plant_similarities.csv...
# Processing cluster_17_plant_similarities.csv...
# Processing cluster_126_plant_similarities.csv...
# Processing cluster_159_plant_similarities.csv...
# Processing cluster_68_plant_similarities.csv...
# All done.

# %% [markdown]
# Now we compare the chemical compositions of plants with high similarity scores 80% and identify the most present chemicals that contributes to the similarity between them. After creating the results_df DataFrame, we remove duplicates based on the chemical compositions by rounding the columns 'First Most Present Amount', 'Second ...' and so on.. to two decimal places using .round() method. Then, we drop duplicates based on these rounded columns.

# %% [markdown]
# here's the code modified to display the top 5 present chemicals in order to later create a barplot

# %%
import pandas as pd
from tqdm import tqdm
import os

# Define the path to the cluster data
data_path = '/Users/mariiakokina/Documents/eo_database/'

# Get a list of cluster files
cluster_files = [file for file in os.listdir(data_path) if file.startswith('cluster_')]

# Iterate over the cluster files
for cluster_file in cluster_files:
    # Extract the cluster number from the file name
    cluster_num = cluster_file.split('_')[1]
    
    # Load the chemical compositions data
    composition_file = os.path.join(data_path, f'cluster_{cluster_num}_chemical_compositions.csv')
    chemical_compositions = pd.read_csv(composition_file, index_col=0)

    # Load the plant similarities data
    similarities_file = os.path.join(data_path, f'cluster_{cluster_num}_plant_similarities.csv')
    plant_similarities = pd.read_csv(similarities_file, index_col=0)

    # Create an empty DataFrame to store the results
    results_df = pd.DataFrame(columns=['Plant 1', 'Plant 2', 'Similarity Score', 'First Most Present Chemical',
                                       'First Most Present Amount', 'Second Most Present Chemical',
                                       'Second Most Present Amount', 'Third Most Present Chemical',
                                       'Third Most Present Amount', 'Fourth Most Present Chemical',
                                       'Fourth Most Present Amount', 'Fifth Most Present Chemical',
                                       'Fifth Most Present Amount'])

    # Iterate over the rows of the plant similarities data
    for index, row in tqdm(plant_similarities.iterrows(), total=len(plant_similarities), desc=f'Processing Cluster {cluster_num}'):
        plant_1 = index  # Plant 1 name
        for column in row.index:
            if index != column:  # Exclude diagonal comparisons
                similarity_score = row[column]  # Similarity score
                if similarity_score >= 0.8:  # Filter similarity score
                    plant_2 = column  # Plant 2 name

                    # Get the chemical composition of the two plants
                    composition_1 = chemical_compositions.loc[plant_1]
                    composition_2 = chemical_compositions.loc[plant_2]

                    # Find the chemicals present in both plants
                    common_chemicals = set(composition_1.index) & set(composition_2.index)

                    # Find the most present chemical and its amount in each plant
                    most_present_chemicals = [None]*5
                    max_amounts = [0]*5
                    for chemical in common_chemicals:
                        amount_1 = composition_1[chemical]
                        amount_2 = composition_2[chemical]
                        for i in range(5):
                            if amount_1 > max_amounts[i]:
                                for j in range(4, i, -1):
                                    max_amounts[j] = max_amounts[j-1]
                                    most_present_chemicals[j] = most_present_chemicals[j-1]
                                max_amounts[i] = amount_1
                                most_present_chemicals[i] = chemical
                                break

                    # Create a temporary DataFrame to store the current result
                    temp_df = pd.DataFrame({
                        'Plant 1': [plant_1],
                        'Plant 2': [plant_2],
                        'Similarity Score': [similarity_score],
                        'First Most Present Chemical': [most_present_chemicals[0]],
                        'First Most Present Amount': [max_amounts[0]],
                        'Second Most Present Chemical': [most_present_chemicals[1]],
                        'Second Most Present Amount': [max_amounts[1]],
                        'Third Most Present Chemical': [most_present_chemicals[2]],
                        'Third Most Present Amount': [max_amounts[2]],
                        'Fourth Most Present Chemical': [most_present_chemicals[3]],
                        'Fourth Most Present Amount': [max_amounts[3]],
                        'Fifth Most Present Chemical': [most_present_chemicals[4]],
                        'Fifth Most Present Amount': [max_amounts[4]]
                    })

                    # Concatenate the temporary DataFrame with the results DataFrame
                    results_df = pd.concat([results_df, temp_df], ignore_index=True)

    # Remove duplicates based on the chemical compositions
    results_df_deduplicated = results_df.round({'First Most Present Amount': 2,
                                                'Second Most Present Amount': 2,
                                                'Third Most Present Amount': 2,
                                                'Fourth Most Present Amount': 2,
                                                'Fifth Most Present Amount': 2}).drop_duplicates(subset=['First Most Present Amount',
                                                                                                      'Second Most Present Chemical',
                                                                                                      'Second Most Present Amount',
                                                                                                      'Third Most Present Chemical',
                                                                                                      'Third Most Present Amount',
                                                                                                      'Fourth Most Present Chemical',
                                                                                                      'Fourth Most Present Amount',
                                                                                                      'Fifth Most Present Chemical',
                                                                                                      'Fifth Most Present Amount'])

    # Save the results in a folder with the cluster name
    results_path = os.path.join(data_path, f'cluster_{cluster_num}')
    
    # Ensure the directory exists
    if not os.path.exists(results_path):
        os.makedirs(results_path)

    # Save the results dataframe to a csv file with designated name
    filename = f'high_similarity_plants_top5chemicals.csv'
    results_df_deduplicated.to_csv(os.path.join(results_path, filename), index=False)
# Out:
# Processing Cluster 71: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 390.63it/s]
# Processing Cluster 34: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 448.51it/s]
# Processing Cluster 41: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 25266.89it/s]
# Processing Cluster 80: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 187.33it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 163.51it/s]
# Processing Cluster 79: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 164/164 [00:01<00:00, 127.68it/s]
# Processing Cluster 70: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 177.90it/s]
# Processing Cluster 20: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 292.35it/s]
# Processing Cluster 5: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 401.29it/s]
# Processing Cluster 57: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 71.56it/s]
# Processing Cluster 33: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 733.19it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1614.95it/s]
# Processing Cluster 87: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 2970.58it/s]
# Processing Cluster 82: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 101.13it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1283.01it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 161.71it/s]
# Processing Cluster 39: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 63.83it/s]
# Processing Cluster 6: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 73.28it/s]
# Processing Cluster 64: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 3693.65it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1047.45it/s]
# Processing Cluster 8: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 673.84it/s]
# Processing Cluster 77: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 33058.55it/s]
# Processing Cluster 2: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 97.54it/s]
# Processing Cluster 51: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 767.20it/s]
# Processing Cluster 8: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 666.14it/s]
# Processing Cluster 56: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 597.37it/s]
# Processing Cluster 9: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 95.67it/s]
# Processing Cluster 60: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 183.96it/s]
# Processing Cluster 45: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 688.10it/s]
# Processing Cluster 6: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 73.00it/s]
# Processing Cluster 84: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 142.37it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1471.89it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 2210.17it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 245.89it/s]
# Processing Cluster 30: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 221.99it/s]
# Processing Cluster 58: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 746.40it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 247.60it/s]
# Processing Cluster 45: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 658.41it/s]
# Processing Cluster 33: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 686.49it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 1623.67it/s]
# Processing Cluster 74: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 34.58it/s]
# Processing Cluster 85: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 2471.14it/s]
# Processing Cluster 34: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 441.40it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 238.95it/s]
# Processing Cluster 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 252.91it/s]
# Processing Cluster 59: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1101.12it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1530.41it/s]
# Processing Cluster 27: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 400.36it/s]
# Processing Cluster 61: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 32109.50it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 1049.81it/s]
# Processing Cluster 7: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 88.22it/s]
# Processing Cluster 89: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 51.59it/s]
# Processing Cluster 64: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 3722.25it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 151.58it/s]
# Processing Cluster 57: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 73.22it/s]
# Processing Cluster 83: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 6517.71it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1559.39it/s]
# Processing Cluster 9: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 92.13it/s]
# Processing Cluster 37: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 3489.96it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1547.35it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 1702.36it/s]
# Processing Cluster 73: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 157.62it/s]
# Processing Cluster 58: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 855.88it/s]
# Processing Cluster 6: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 68.48it/s]
# Processing Cluster 79: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 164/164 [00:01<00:00, 129.26it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1259.04it/s]
# Processing Cluster 76: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 204.36it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 1805.28it/s]
# Processing Cluster 10: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 614.80it/s]
# Processing Cluster 78: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 683.20it/s]
# Processing Cluster 73: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 155.12it/s]
# Processing Cluster 17: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 181.70it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 167.09it/s]
# Processing Cluster 21: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 747.90it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 165.78it/s]
# Processing Cluster 26: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 728.20it/s]
# Processing Cluster 7: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 92.75it/s]
# Processing Cluster 20: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 306.49it/s]
# Processing Cluster 19: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 630.07it/s]
# Processing Cluster 72: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1255.22it/s]
# Processing Cluster 82: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 101.60it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1823.68it/s]
# Processing Cluster 36: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 5275.85it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1565.19it/s]
# Processing Cluster 55: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 542.95it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1909.74it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 112.66it/s]
# Processing Cluster 88: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 3759.09it/s]
# Processing Cluster 44: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1140.97it/s]
# Processing Cluster 49: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 5486.10it/s]
# Processing Cluster 27: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 398.51it/s]
# Processing Cluster 19: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 628.60it/s]
# Processing Cluster 18: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 580.68it/s]
# Processing Cluster 20: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 298.41it/s]
# Processing Cluster 19: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 624.46it/s]
# Processing Cluster 6: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 68.04it/s]
# Processing Cluster 16: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 120.44it/s]
# Processing Cluster 29: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 527.55it/s]
# Processing Cluster 40: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 593.12it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2529.49it/s]
# Processing Cluster 80: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 193.98it/s]
# Processing Cluster 37: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 3658.58it/s]
# Processing Cluster 11: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 164.15it/s]
# Processing Cluster 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 264.13it/s]
# Processing Cluster 75: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83/83 [00:00<00:00, 513.80it/s]
# Processing Cluster 85: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 2687.28it/s]
# Processing Cluster 44: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1152.66it/s]
# Processing Cluster 11: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 162.04it/s]
# Processing Cluster 45: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 700.80it/s]
# Processing Cluster 66: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 262.83it/s]
# Processing Cluster 31: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1571.36it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 162.27it/s]
# Processing Cluster 88: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 3741.94it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 1155.65it/s]
# Processing Cluster 3: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 128.45it/s]
# Processing Cluster 76: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 196.67it/s]
# Processing Cluster 38: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 129.58it/s]
# Processing Cluster 61: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 34169.48it/s]
# Processing Cluster 9: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 95.88it/s]
# Processing Cluster 16: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 124.86it/s]
# Processing Cluster 30: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 237.52it/s]
# Processing Cluster 87: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 3156.11it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2523.07it/s]
# Processing Cluster 38: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 140.78it/s]
# Processing Cluster 3: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 136.29it/s]
# Processing Cluster 47: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 34952.53it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 1824.30it/s]
# Processing Cluster 86: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 992.37it/s]
# Processing Cluster 69: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 716/716 [02:13<00:00,  5.37it/s]
# Processing Cluster 47: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 10205.12it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2246.07it/s]
# Processing Cluster 25: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 144.58it/s]
# Processing Cluster 71: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 531.86it/s]
# Processing Cluster 9: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 96.01it/s]
# Processing Cluster 52: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1021.66it/s]
# Processing Cluster 40: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 598.77it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 115.27it/s]
# Processing Cluster 74: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 35.97it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1339.02it/s]
# Processing Cluster 81: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 1732.75it/s]
# Processing Cluster 40: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 597.35it/s]
# Processing Cluster 69: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 716/716 [02:14<00:00,  5.32it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1970.00it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 2252.25it/s]
# Processing Cluster 75: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83/83 [00:00<00:00, 500.21it/s]
# Processing Cluster 16: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 122.61it/s]
# Processing Cluster 27: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 403.06it/s]
# Processing Cluster 57: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 73.18it/s]
# Processing Cluster 24: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 76.57it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1273.62it/s]
# Processing Cluster 52: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 932.48it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 20510.04it/s]
# Processing Cluster 58: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 822.35it/s]
# Processing Cluster 31: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1383.65it/s]
# Processing Cluster 86: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 904.53it/s]
# Processing Cluster 2: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 97.67it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1658.81it/s]
# Processing Cluster 64: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 3676.28it/s]
# Processing Cluster 68: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 423.67it/s]
# Processing Cluster 11: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 159.91it/s]
# Processing Cluster 20: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 298.92it/s]
# Processing Cluster 39: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 63.39it/s]
# Processing Cluster 55: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 527.14it/s]
# Processing Cluster 60: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 180.74it/s]
# Processing Cluster 17: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 179.28it/s]
# Processing Cluster 10: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 583.66it/s]
# Processing Cluster 37: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 3354.39it/s]
# Processing Cluster 12: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 292.10it/s]
# Processing Cluster 67: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 74.56it/s]
# Processing Cluster 67: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 75.44it/s]
# Processing Cluster 30: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 232.17it/s]
# Processing Cluster 89: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 61/61 [00:01<00:00, 52.80it/s]
# Processing Cluster 39: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 62.77it/s]
# Processing Cluster 18: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 555.70it/s]
# Processing Cluster 49: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 4900.27it/s]
# Processing Cluster 55: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 530.46it/s]
# Processing Cluster 29: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 516.04it/s]
# Processing Cluster 52: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 973.56it/s]
# Processing Cluster 18: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 563.84it/s]
# Processing Cluster 41: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 27200.42it/s]
# Processing Cluster 5: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 420.50it/s]
# Processing Cluster 2: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 97.59it/s]
# Processing Cluster 56: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 607.44it/s]
# Processing Cluster 64: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 3619.75it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 2294.02it/s]
# Processing Cluster 5: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 419.07it/s]
# Processing Cluster 58: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 706.40it/s]
# Processing Cluster 23: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 450.00it/s]
# Processing Cluster 81: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 1591.89it/s]
# Processing Cluster 36: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 4887.33it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1054.89it/s]
# Processing Cluster 38: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 137.86it/s]
# Processing Cluster 60: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 185.69it/s]
# Processing Cluster 54: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 630.11it/s]
# Processing Cluster 55: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 536.97it/s]
# Processing Cluster 31: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1460.21it/s]
# Processing Cluster 36: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 4848.16it/s]
# Processing Cluster 23: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 456.97it/s]
# Processing Cluster 62: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 4476.31it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2427.29it/s]
# Processing Cluster 3: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 134.61it/s]
# Processing Cluster 72: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1162.13it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 30012.91it/s]
# Processing Cluster 51: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 752.89it/s]
# Processing Cluster 54: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 635.52it/s]
# Processing Cluster 24: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 77.14it/s]
# Processing Cluster 49: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 5095.12it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1478.84it/s]
# Processing Cluster 25: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 143.48it/s]
# Processing Cluster 59: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1066.91it/s]
# Processing Cluster 47: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 29746.84it/s]
# Processing Cluster 40: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 576.17it/s]
# Processing Cluster 77: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 34344.35it/s]
# Processing Cluster 51: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 756.87it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1545.08it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1043.32it/s]
# Processing Cluster 26: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 723.70it/s]
# Processing Cluster 25: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 142.48it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1531.91it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 113.10it/s]
# Processing Cluster 61: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 33723.05it/s]
# Processing Cluster 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 258.01it/s]
# Processing Cluster 44: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1146.18it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 164.96it/s]
# Processing Cluster 41: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 31441.56it/s]
# Processing Cluster 57: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 73.17it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 114.08it/s]
# Processing Cluster 33: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 713.29it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1708.94it/s]
# Processing Cluster 84: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 145.67it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 167.72it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 1135.80it/s]
# Processing Cluster 23: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 456.89it/s]
# Processing Cluster 19: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 614.59it/s]
# Processing Cluster 24: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 77.14it/s]
# Processing Cluster 8: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 679.47it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1070.13it/s]
# Processing Cluster 12: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 298.42it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1072.52it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1072.72it/s]
# Processing Cluster 62: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 5068.65it/s]
# Processing Cluster 66: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 261.16it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:01<00:00, 105.55it/s]
# Processing Cluster 12: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 299.68it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 257.37it/s]
# Processing Cluster 21: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 724.12it/s]
# Processing Cluster 54: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 592.14it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:01<00:00, 104.95it/s]
# Processing Cluster 10: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 609.29it/s]
# Processing Cluster 83: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 6445.22it/s]
# Processing Cluster 34: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 451.03it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1816.14it/s]
# Processing Cluster 7: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 86.81it/s]
# Processing Cluster 59: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 999.23it/s]
# Processing Cluster 78: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 633.42it/s]
# Processing Cluster 26: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 685.89it/s]
# Processing Cluster 21: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 684.40it/s]
# Processing Cluster 45: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 647.92it/s]
# Processing Cluster 56: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 584.59it/s]
# Processing Cluster 27: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 384.53it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 25771.45it/s]
# Processing Cluster 70: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 177.88it/s]
# Processing Cluster 62: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 3563.86it/s]
# Processing Cluster 17: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 176.95it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1092.99it/s]
# Processing Cluster 29: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 517.36it/s]
# Processing Cluster 68: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 420.95it/s]

# %% [markdown]
# Next we represent the most similar plants and their simillarity scores in one dataframe and their chemical composion in another dataframe so that we can later visualize it as a heatmap

# %%
import pandas as pd
from tqdm import tqdm
import os

# Define the path to the cluster data
data_path = '/Users/mariiakokina/Documents/eo_database/'

# Get a list of cluster files
cluster_files = [file for file in os.listdir(data_path) if file.startswith('cluster_')]

# Iterate over the cluster files
for cluster_file in cluster_files:
    # Extract the cluster number from the file name
    cluster_num = cluster_file.split('_')[1]
    
    # Load the plant similarities data
    similarities_file = os.path.join(data_path, f'cluster_{cluster_num}_plant_similarities.csv')
    plant_similarities = pd.read_csv(similarities_file, index_col=0)

    # Create an empty DataFrame to store the results
    results_df = pd.DataFrame(columns=['Plant 1', 'Plant 2', 'Similarity Score'])

    # Iterate over the rows of the plant similarities data
    for plant_1 in tqdm(plant_similarities.index, total=len(plant_similarities), desc=f'Processing Cluster {cluster_num}'):
        for plant_2 in plant_similarities.columns:
            if plant_1 != plant_2:  # Exclude diagonal comparisons
                similarity_score = plant_similarities.loc[plant_1, plant_2]  # Similarity score
                if similarity_score >= 0.8:  # Filter similarity score
                    
                    # Create a temporary DataFrame to store the current result
                    temp_df = pd.DataFrame({
                        'Plant 1': [plant_1],
                        'Plant 2': [plant_2],
                        'Similarity Score': [similarity_score]
                    })

                    # Append the temporary DataFrame to the results DataFrame
                    results_df = pd.concat([results_df, temp_df], ignore_index=True)

    # Save the results to a CSV file
    results_path = os.path.join(data_path, f'cluster_{cluster_num}')
    
    # Ensure the directory exists
    if not os.path.exists(results_path):
        os.makedirs(results_path)

    # Save the results dataframe to a csv file with designated name
    filename = f'high_similarity_plants.csv'
    results_df.to_csv(os.path.join(results_path, filename), index=False)
# Out:
# Processing Cluster 71: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 618.32it/s]
# Processing Cluster 34: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 2192.99it/s]
# Processing Cluster 41: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 25145.71it/s]
# Processing Cluster 80: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 694.74it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 987.96it/s]
# Processing Cluster 79: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 164/164 [00:00<00:00, 883.36it/s]
# Processing Cluster 70: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 1198.81it/s]
# Processing Cluster 20: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 1660.81it/s]
# Processing Cluster 5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1114.52it/s]
# Processing Cluster 57: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 380.54it/s]
# Processing Cluster 33: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 3779.37it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 5753.50it/s]
# Processing Cluster 87: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 8210.57it/s]
# Processing Cluster 82: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 914.72it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 4309.98it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 868.15it/s]
# Processing Cluster 39: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 450.69it/s]
# Processing Cluster 6: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 780.95it/s]
# Processing Cluster 64: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 10943.39it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 4461.66it/s]
# Processing Cluster 8: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2864.49it/s]
# Processing Cluster 77: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 21690.00it/s]
# Processing Cluster 2: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 435.11it/s]
# Processing Cluster 51: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3149.82it/s]
# Processing Cluster 8: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2956.15it/s]
# Processing Cluster 56: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 3085.56it/s]
# Processing Cluster 9: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1020.11it/s]
# Processing Cluster 69: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 716/716 [00:05<00:00, 136.99it/s]
# Processing Cluster 60: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 1019.78it/s]
# Processing Cluster 45: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3502.43it/s]
# Processing Cluster 6: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 800.96it/s]
# Processing Cluster 84: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 1133.75it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3724.43it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 8622.19it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 939.97it/s]
# Processing Cluster 67: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 1336.55it/s]
# Processing Cluster 30: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 1542.19it/s]
# Processing Cluster 58: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 4324.92it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 884.72it/s]
# Processing Cluster 45: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3457.34it/s]
# Processing Cluster 33: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 3739.29it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 4047.51it/s]
# Processing Cluster 74: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 239.29it/s]
# Processing Cluster 85: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 3149.76it/s]
# Processing Cluster 34: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 2516.38it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 888.54it/s]
# Processing Cluster 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2900.26it/s]
# Processing Cluster 66: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 2213.11it/s]
# Processing Cluster 59: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 4732.20it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 5702.66it/s]
# Processing Cluster 27: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2503.73it/s]
# Processing Cluster 61: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 21845.33it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 4153.55it/s]
# Processing Cluster 7: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 526.67it/s]
# Processing Cluster 89: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 61/61 [00:00<00:00, 449.67it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 890.88it/s]
# Processing Cluster 57: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 402.65it/s]
# Processing Cluster 83: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 8617.59it/s]
# Processing Cluster 68: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 2431.08it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 6340.60it/s]
# Processing Cluster 9: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1053.70it/s]
# Processing Cluster 37: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 6089.42it/s]
# Processing Cluster 73: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 1098.73it/s]
# Processing Cluster 58: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 4381.85it/s]
# Processing Cluster 6: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 809.12it/s]
# Processing Cluster 79: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 164/164 [00:00<00:00, 883.38it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 4277.20it/s]
# Processing Cluster 76: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 1378.44it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 3872.54it/s]
# Processing Cluster 10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3696.07it/s]
# Processing Cluster 78: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 3428.30it/s]
# Processing Cluster 73: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 1061.07it/s]
# Processing Cluster 17: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 1100.31it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 951.66it/s]
# Processing Cluster 21: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 3335.72it/s]
# Processing Cluster 26: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3311.68it/s]
# Processing Cluster 7: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 525.16it/s]
# Processing Cluster 19: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 2812.29it/s]
# Processing Cluster 72: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 6006.16it/s]
# Processing Cluster 82: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 891.43it/s]
# Processing Cluster 72: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 5802.59it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 6765.01it/s]
# Processing Cluster 86: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 2273.15it/s]
# Processing Cluster 36: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 10452.66it/s]
# Processing Cluster 81: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 4868.79it/s]
# Processing Cluster 75: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83/83 [00:00<00:00, 1814.40it/s]
# Processing Cluster 88: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 19026.58it/s]
# Processing Cluster 55: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 2679.45it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 7250.88it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 558.08it/s]
# Processing Cluster 88: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 20832.64it/s]
# Processing Cluster 44: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 4754.96it/s]
# Processing Cluster 49: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 10196.85it/s]
# Processing Cluster 27: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2557.94it/s]
# Processing Cluster 18: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 3156.44it/s]
# Processing Cluster 20: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 1721.53it/s]
# Processing Cluster 19: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 2780.13it/s]
# Processing Cluster 16: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 712.22it/s]
# Processing Cluster 29: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 2117.86it/s]
# Processing Cluster 40: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 2750.36it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3256.50it/s]
# Processing Cluster 80: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 700.37it/s]
# Processing Cluster 37: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 6244.51it/s]
# Processing Cluster 11: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1000.68it/s]
# Processing Cluster 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3075.59it/s]
# Processing Cluster 75: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83/83 [00:00<00:00, 1811.60it/s]
# Processing Cluster 85: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 3148.99it/s]
# Processing Cluster 44: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 4849.93it/s]
# Processing Cluster 11: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1007.36it/s]
# Processing Cluster 45: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3640.83it/s]
# Processing Cluster 66: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 2228.58it/s]
# Processing Cluster 31: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 5845.72it/s]
# Processing Cluster 89: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 61/61 [00:00<00:00, 459.46it/s]
# Processing Cluster 42: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 907.90it/s]
# Processing Cluster 74: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 237.24it/s]
# Processing Cluster 88: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 20639.00it/s]
# Processing Cluster 80: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:00<00:00, 725.68it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 4439.59it/s]
# Processing Cluster 87: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 10203.81it/s]
# Processing Cluster 73: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 1107.42it/s]
# Processing Cluster 3: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2417.22it/s]
# Processing Cluster 76: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 1435.09it/s]
# Processing Cluster 38: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 827.53it/s]
# Processing Cluster 61: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 23797.47it/s]
# Processing Cluster 9: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1060.81it/s]
# Processing Cluster 16: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 752.74it/s]
# Processing Cluster 30: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 1551.28it/s]
# Processing Cluster 87: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 10353.62it/s]
# Processing Cluster 38: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 837.06it/s]
# Processing Cluster 3: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2491.69it/s]
# Processing Cluster 47: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 23730.15it/s]
# Processing Cluster 32: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 4014.63it/s]
# Processing Cluster 86: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 2251.00it/s]
# Processing Cluster 69: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 716/716 [00:05<00:00, 136.59it/s]
# Processing Cluster 47: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 22280.50it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3255.64it/s]
# Processing Cluster 25: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1418.13it/s]
# Processing Cluster 71: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 882.90it/s]
# Processing Cluster 52: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 4230.69it/s]
# Processing Cluster 74: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 234.45it/s]
# Processing Cluster 35: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 4560.81it/s]
# Processing Cluster 81: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 5042.04it/s]
# Processing Cluster 40: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 2805.84it/s]
# Processing Cluster 69: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 716/716 [00:05<00:00, 135.27it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 8129.93it/s]
# Processing Cluster 75: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83/83 [00:00<00:00, 1918.29it/s]
# Processing Cluster 16: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 772.02it/s]
# Processing Cluster 27: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2713.74it/s]
# Processing Cluster 24: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 677.76it/s]
# Processing Cluster 52: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 4252.13it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 28339.89it/s]
# Processing Cluster 58: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 4197.66it/s]
# Processing Cluster 31: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 6068.93it/s]
# Processing Cluster 86: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 2385.73it/s]
# Processing Cluster 2: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 451.53it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 6459.40it/s]
# Processing Cluster 64: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 11943.40it/s]
# Processing Cluster 68: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 2549.39it/s]
# Processing Cluster 11: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1056.73it/s]
# Processing Cluster 20: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 1458.07it/s]
# Processing Cluster 39: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 446.27it/s]
# Processing Cluster 55: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 2816.99it/s]
# Processing Cluster 60: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 1047.30it/s]
# Processing Cluster 17: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 1189.41it/s]
# Processing Cluster 10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3981.23it/s]
# Processing Cluster 37: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 7074.30it/s]
# Processing Cluster 12: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2751.48it/s]
# Processing Cluster 67: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 1394.49it/s]
# Processing Cluster 67: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 1273.34it/s]
# Processing Cluster 30: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 1478.57it/s]
# Processing Cluster 89: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 61/61 [00:00<00:00, 427.35it/s]
# Processing Cluster 39: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 451.25it/s]
# Processing Cluster 18: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 3311.73it/s]
# Processing Cluster 49: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 11012.53it/s]
# Processing Cluster 55: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 2782.82it/s]
# Processing Cluster 29: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 2335.39it/s]
# Processing Cluster 52: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 4026.79it/s]
# Processing Cluster 18: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 3235.10it/s]
# Processing Cluster 41: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 28571.55it/s]
# Processing Cluster 5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1163.25it/s]
# Processing Cluster 2: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 410.16it/s]
# Processing Cluster 56: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 2906.99it/s]
# Processing Cluster 64: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 9196.20it/s]
# Processing Cluster 63: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 8442.33it/s]
# Processing Cluster 5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1075.31it/s]
# Processing Cluster 23: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 2719.11it/s]
# Processing Cluster 81: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 5068.85it/s]
# Processing Cluster 36: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 10899.96it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3539.02it/s]
# Processing Cluster 38: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 834.40it/s]
# Processing Cluster 60: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 1026.55it/s]
# Processing Cluster 54: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 3587.94it/s]
# Processing Cluster 31: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 6190.35it/s]
# Processing Cluster 36: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 10699.76it/s]
# Processing Cluster 23: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 2732.40it/s]
# Processing Cluster 62: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11052.18it/s]
# Processing Cluster 4: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3361.84it/s]
# Processing Cluster 3: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2581.81it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:00<00:00, 544.41it/s]
# Processing Cluster 72: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 6536.58it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 29641.72it/s]
# Processing Cluster 51: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3419.51it/s]
# Processing Cluster 54: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 3495.98it/s]
# Processing Cluster 24: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 673.66it/s]
# Processing Cluster 49: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 11414.11it/s]
# Processing Cluster 82: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 960.79it/s]
# Processing Cluster 76: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 1477.39it/s]
# Processing Cluster 50: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 6461.30it/s]
# Processing Cluster 25: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1501.72it/s]
# Processing Cluster 59: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 5046.29it/s]
# Processing Cluster 71: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 917.01it/s]
# Processing Cluster 85: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 3313.65it/s]
# Processing Cluster 78: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 3658.38it/s]
# Processing Cluster 47: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 24528.09it/s]
# Processing Cluster 40: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 2847.26it/s]
# Processing Cluster 77: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 23464.64it/s]
# Processing Cluster 51: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3396.03it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3981.46it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 4847.61it/s]
# Processing Cluster 26: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3641.08it/s]
# Processing Cluster 25: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1453.49it/s]
# Processing Cluster 14: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3990.39it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 595.57it/s]
# Processing Cluster 61: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 24618.07it/s]
# Processing Cluster 0: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3251.85it/s]
# Processing Cluster 44: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 5159.05it/s]
# Processing Cluster 41: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 27485.61it/s]
# Processing Cluster 57: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 412.52it/s]
# Processing Cluster 22: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 596.17it/s]
# Processing Cluster 79: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 164/164 [00:00<00:00, 896.99it/s]
# Processing Cluster 33: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 3994.17it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 6271.08it/s]
# Processing Cluster 84: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 1154.66it/s]
# Processing Cluster 28: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 1050.44it/s]
# Processing Cluster 84: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 1121.90it/s]
# Processing Cluster 70: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 1242.68it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 4462.92it/s]
# Processing Cluster 77: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 23109.11it/s]
# Processing Cluster 83: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 8589.86it/s]
# Processing Cluster 23: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 2712.54it/s]
# Processing Cluster 19: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 2947.22it/s]
# Processing Cluster 24: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 664.34it/s]
# Processing Cluster 8: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3191.04it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3666.03it/s]
# Processing Cluster 12: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2736.58it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 4945.22it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3620.34it/s]
# Processing Cluster 62: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 10868.89it/s]
# Processing Cluster 66: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 2348.27it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:00<00:00, 550.11it/s]
# Processing Cluster 12: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 2730.31it/s]
# Processing Cluster 21: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 3464.38it/s]
# Processing Cluster 54: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 3502.55it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:00<00:00, 548.72it/s]
# Processing Cluster 10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 4020.92it/s]
# Processing Cluster 83: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 8329.90it/s]
# Processing Cluster 34: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 2775.72it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 7055.72it/s]
# Processing Cluster 7: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 562.45it/s]
# Processing Cluster 59: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 5211.75it/s]
# Processing Cluster 78: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 3612.50it/s]
# Processing Cluster 26: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 3634.52it/s]
# Processing Cluster 21: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 3488.55it/s]
# Processing Cluster 56: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 3284.07it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 30012.91it/s]
# Processing Cluster 70: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 1248.10it/s]
# Processing Cluster 62: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11208.72it/s]
# Processing Cluster 17: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 1183.46it/s]
# Processing Cluster 29: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 2314.57it/s]
# Processing Cluster 68: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 2585.24it/s]

# %% [markdown]
# Here we create a data frame with the full chemical compositions of the most similar plants

# %%
import pandas as pd
import glob
import os

# Path to the chemicals data
chemicals_data_path = '/Users/mariiakokina/Documents/eo_database/chemicals_data_clean.csv'

# Read the full chemical composition data
chemicals_df = pd.read_csv(chemicals_data_path, index_col=0)  # Assume the plant name is the index

# Get the list of high similarity plant files
high_similarity_files = glob.glob('/Users/mariiakokina/Documents/eo_database/cluster_*/high_similarity_plants.csv')

# Iterate over each high similarity file
for hs_file in high_similarity_files:
    # Read the high similarity file
    hs_df = pd.read_csv(hs_file)
    
    # Get the plant names from high similarity file
    plant_names = hs_df.iloc[:, 0].unique()  # Assuming plant names are in the first column
    
    # Get the chemical compositions for the plants in high similarity file
    compositions = chemicals_df.loc[plant_names]
    
    # Save the compositions DataFrame as a CSV file in the corresponding cluster folder
    compositions.to_csv(os.path.join(os.path.dirname(hs_file), 'high_similarity_plants_compositions.csv'))

# Pattern to match your CSV files
pattern = '/Users/mariiakokina/Documents/eo_database/cluster_*/high_similarity_plants_compositions.csv'

# Get a list of all matching file paths
files = glob.glob(pattern)

for file in files:
    # Load the data
    df = pd.read_csv(file, index_col=0)  # Assuming the first column is the index

    # Remove columns that only contain zeros
    df = df.loc[:, (df != 0).any(axis=0)]

    # Save the dataframe back to CSV
    df.to_csv(file, index=True)

# %% [markdown]
# This code will create a bar plot with the x-axis representing main chemicals and the y-axis representing the amount.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

files = glob.glob('/Users/mariiakokina/Documents/eo_database/cluster_*/high_similarity_plants_top5chemicals.csv')

barWidth = 0.15

# Use a more colorful palette
colors = sns.color_palette('Set3')

# Set the dark grid style
sns.set_style('darkgrid')

for file in files:
    df = pd.read_csv(file)
    unique_plants = []
    plants = []
    
    for i in range(len(df)):
        plant = df.iloc[i, 0]
        if plant in unique_plants:
            continue
        unique_plants.append(plant)
        
        chemicals = [df.iloc[i, j] for j in range(3, 13, 2)]
        amounts = [df.iloc[i, j]*100 for j in range(4, 14, 2)]
        
        plants.append(pd.DataFrame({"Plant": plant, "Chemical": chemicals, "Amount": amounts}))
    
    if not plants:
        continue

    fig, axs = plt.subplots(len(plants), 1, figsize=(12, 8*len(plants)))
    
    if isinstance(axs, plt.Axes):
        axs = [axs]
        
    for i, ax in enumerate(axs):
        print(plants[i]["Chemical"])
        plants[i]["Chemical"] = plants[i]["Chemical"].astype(str)

        bars = ax.bar(plants[i]["Chemical"], plants[i]["Amount"], color=colors[i % len(colors)], 
                width=barWidth, edgecolor='grey', 
                label='{}'.format(plants[i]['Plant'][0]))
        ax.set_xlabel('Chemical', fontweight='bold')
        ax.set_ylabel('Percentage (%)', fontweight='bold')
        ax.set_ylim([0, 100])

        # Add gridlines
        ax.grid(True)

        # Rotate the x-axis labels if they are overlapping
        plt.xticks(rotation=45, ha='right')

        for bar in bars:
            yval = bar.get_height()
            ax.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval,2), ha='center', va='bottom')

        ax.text(0.75, 0.5, 'Sum of main chemicals: {:.2f}%'.format(sum(plants[i]["Amount"])), 
                transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

        ax.legend()
    
    dir_name = os.path.dirname(file)
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

    fig.savefig(os.path.splitext(file)[0] + '.pdf', format='pdf', bbox_inches='tight')
    plt.close(fig)
# Out:
# 0          Limonene
# 1          Camphene
# 2      alpha-Pinene
# 3    Bornyl acetate
# 4       beta-Pinene
# Name: Chemical, dtype: object
# 0          Limonene
# 1          Camphene
# 2    Bornyl acetate
# 3      alpha-Pinene
# 4       beta-Pinene
# Name: Chemical, dtype: object
# 0              Limonene
# 1    beta-Caryophyllene
# 2          Germacrene D
# 3               Myrcene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0              Limonene
# 1    beta-Caryophyllene
# 2          Germacrene D
# 3               Myrcene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0                       Limonene
# 1               (Z)-beta-Ocimene
# 2                        Myrcene
# 3                  beta-Selinene
# 4    n-Pentyl-1,3-cyclohexadiene
# Name: Chemical, dtype: object
# 0              Limonene
# 1      (Z)-beta-Ocimene
# 2    3-n-Butylphthalide
# 3               Myrcene
# 4       gamma-Terpinene
# Name: Chemical, dtype: object
# 0         Limonene
# 1      beta-Pinene
# 2         Geranial
# 3    Neryl acetate
# 4            Neral
# Name: Chemical, dtype: object
# 0        Limonene
# 1    alpha-Pinene
# 2     beta-Pinene
# 3        Sabinene
# 4         Myrcene
# Name: Chemical, dtype: object
# 0       Limonene
# 1       Geranial
# 2    beta-Pinene
# 3          Neral
# 4          Nerol
# Name: Chemical, dtype: object
# 0    Limonene
# 1    Geranial
# 2       Neral
# 3    Linalool
# 4       Nerol
# Name: Chemical, dtype: object
# 0           Limonene
# 1        beta-Pinene
# 2           Geranial
# 3      Neryl acetate
# 4    Linalyl acetate
# Name: Chemical, dtype: object
# 0         Limonene
# 1      beta-Pinene
# 2         Geranial
# 3            Neral
# 4    Neryl acetate
# Name: Chemical, dtype: object
# 0         Limonene
# 1         Geranial
# 2      beta-Pinene
# 3            Neral
# 4    Neryl acetate
# Name: Chemical, dtype: object
# 0    Limonene
# 1    Geranial
# 2       Neral
# 3    Geraniol
# 4       Nerol
# Name: Chemical, dtype: object
# 0        Limonene
# 1     beta-Pinene
# 2        Geranial
# 3           Neral
# 4    beta-Ocimene
# Name: Chemical, dtype: object
# 0       Limonene
# 1          Nerol
# 2    beta-Pinene
# 3       Geranial
# 4          Neral
# Name: Chemical, dtype: object
# 0            Limonene
# 1            Geranial
# 2               Neral
# 3     Geranyl acetate
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0          Limonene
# 1      alpha-Pinene
# 2    delta-3-Carene
# 3               NaN
# 4               NaN
# Name: Chemical, dtype: object
# 0                   Limonene
# 1                   Geranial
# 2                      Neral
# 3                   Linalool
# 4    6-Methyl-5-hepten-2-one
# Name: Chemical, dtype: object
# 0          Sabinene
# 1    delta-3-Carene
# 2      alpha-Pinene
# 3       beta-Pinene
# 4          Limonene
# Name: Chemical, dtype: object
# 0             Sabinene
# 1       delta-3-Carene
# 2          Terpinolene
# 3    beta-Phellandrene
# 4             Limonene
# Name: Chemical, dtype: object
# 0         Sabinene
# 1         Linalool
# 2     beta-Ocimene
# 3    Terpinen-4-ol
# 4      Citronellal
# Name: Chemical, dtype: object
# 0               Linalool
# 1               Sabinene
# 2    Ethyl hexadecanoate
# 3          Terpinen-4-ol
# 4       Ethyl linolenate
# Name: Chemical, dtype: object
# 0               Linalool
# 1               Sabinene
# 2       Ethyl linolenate
# 3    Ethyl hexadecanoate
# 4          Terpinen-4-ol
# Name: Chemical, dtype: object
# 0               Sabinene
# 1               Linalool
# 2       (Z)-beta-Ocimene
# 3    Ethyl hexadecanoate
# 4       Ethyl linolenate
# Name: Chemical, dtype: object
# 0        Sabinene
# 1     1,8-Cineole
# 2     para-Cymene
# 3     beta-Pinene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0         Sabinene
# 1     alpha-Pinene
# 2      beta-Pinene
# 3    Terpinen-4-ol
# 4         Limonene
# Name: Chemical, dtype: object
# 0         Sabinene
# 1     alpha-Pinene
# 2      beta-Pinene
# 3       Myristicin
# 4    Terpinen-4-ol
# Name: Chemical, dtype: object
# 0     alpha-Pinene
# 1         Sabinene
# 2      beta-Pinene
# 3       Myristicin
# 4    Terpinen-4-ol
# Name: Chemical, dtype: object
# 0    alpha-Pinene
# 1        Sabinene
# 2     beta-Pinene
# 3      Myristicin
# 4        Limonene
# Name: Chemical, dtype: object
# 0         Sabinene
# 1     alpha-Pinene
# 2      beta-Pinene
# 3    Terpinen-4-ol
# 4         Limonene
# Name: Chemical, dtype: object
# 0              Sabinene
# 1          alpha-Pinene
# 2           beta-Pinene
# 3    Tetradecanoic acid
# 4              Elemicin
# Name: Chemical, dtype: object
# 0            Sabinene
# 1            Linalool
# 2    (E)-beta-Ocimene
# 3            Limonene
# 4      delta-3-Carene
# Name: Chemical, dtype: object
# 0           Sabinene
# 1    gamma-Terpinene
# 2            Myrcene
# 3           Linalool
# 4     delta-3-Carene
# Name: Chemical, dtype: object
# 0            Sabinene
# 1            Linalool
# 2       Terpinen-4-ol
# 3    (E)-beta-Ocimene
# 4      delta-3-Carene
# Name: Chemical, dtype: object
# 0            Sabinene
# 1      delta-3-Carene
# 2    (E)-beta-Ocimene
# 3            Linalool
# 4             Myrcene
# Name: Chemical, dtype: object
# 0            Sabinene
# 1            Linalool
# 2       Terpinen-4-ol
# 3     alpha-Terpinene
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0          Sabinene
# 1          Linalool
# 2       beta-Pinene
# 3    delta-3-Carene
# 4           Myrcene
# Name: Chemical, dtype: object
# 0            Sabinene
# 1       Terpinen-4-ol
# 2      delta-3-Carene
# 3    (E)-beta-Ocimene
# 4            Limonene
# Name: Chemical, dtype: object
# 0          Sabinene
# 1          Linalool
# 2      beta-Ocimene
# 3    delta-3-Carene
# 4           Myrcene
# Name: Chemical, dtype: object
# 0    cis-Sabinyl acetate
# 1               Sabinene
# 2                Myrcene
# 3          Terpinen-4-ol
# 4           alpha-Pinene
# Name: Chemical, dtype: object
# 0    cis-Sabinyl acetate
# 1               Sabinene
# 2                Myrcene
# 3          Terpinen-4-ol
# 4           alpha-Pinene
# Name: Chemical, dtype: object
# 0          Precocene II
# 1           Precocene I
# 2    beta-Caryophyllene
# 3        beta-Farnesene
# 4              Coumarin
# Name: Chemical, dtype: object
# 0                Precocene I
# 1         beta-Caryophyllene
# 2               alpha-Pinene
# 3               Germacrene D
# 4    beta-Sesquiphellandrene
# Name: Chemical, dtype: object
# 0      Precocene II
# 1       Precocene I
# 2          Camphene
# 3    beta-Farnesene
# 4     beta-Cubebene
# Name: Chemical, dtype: object
# 0           Precocene I
# 1    beta-Caryophyllene
# 2          Precocene II
# 3        beta-Farnesene
# 4       alpha-Farnesene
# Name: Chemical, dtype: object
# 0                              Precocene II
# 1                               Precocene I
# 2                        beta-Caryophyllene
# 3                            gamma-Cadinene
# 4    6-Vinyl-7-methoxy-2,2-dimethylchromene
# Name: Chemical, dtype: object
# 0                Precocene I
# 1         beta-Caryophyllene
# 2    beta-Sesquiphellandrene
# 3             alpha-Humulene
# 4               Germacrene D
# Name: Chemical, dtype: object
# 0          Precocene II
# 1           Precocene I
# 2    beta-Caryophyllene
# 3       beta-Bisabolene
# 4       alpha-Farnesene
# Name: Chemical, dtype: object
# 0           Precocene I
# 1    beta-Caryophyllene
# 2          Precocene II
# 3       alpha-Farnesene
# 4        beta-Farnesene
# Name: Chemical, dtype: object
# 0           Precocene I
# 1    beta-Caryophyllene
# 2          Precocene II
# 3       alpha-Farnesene
# 4        beta-Farnesene
# Name: Chemical, dtype: object
# 0          Precocene II
# 1           Precocene I
# 2    beta-Caryophyllene
# 3         beta-Cubebene
# 4        beta-Gurjunene
# Name: Chemical, dtype: object
# 0     Nonadecane
# 1    Heneicosane
# 2      Tricosane
# 3        Kaurene
# 4    Pentacosane
# Name: Chemical, dtype: object
# 0       Linalool
# 1       Undecane
# 2        Eugenol
# 3         Decane
# 4    1-Octenol-3
# Name: Chemical, dtype: object
# 0                  Diallyl trisulfide
# 1                   Diallyl disulfide
# 2                Diallyl tetrasulfide
# 3             3-Vinyl-1,2-dithi-4-ene
# 4    cis-1-Propenyl propyl trisulfide
# Name: Chemical, dtype: object
# 0         Diallyl disulfide
# 1        Diallyl trisulfide
# 2         Methyl salicylate
# 3               1-Octenol-3
# 4    Allyl isobutyl sulfide
# Name: Chemical, dtype: object
# 0             Germacrene D
# 1                 Limonene
# 2          gamma-Terpinene
# 3                  Myrcene
# 4    (E,E)-alpha-Farnesene
# Name: Chemical, dtype: object
# 0          Agarospirol
# 1         Jinkoheremol
# 2              Kusunol
# 3    Norketoagarofuran
# 4      beta-Agarofuran
# Name: Chemical, dtype: object
# 0             Guaia-1(10),11-dien-15-oic acid
# 1                   2-(2-Phenylethyl)chromone
# 2                              Oxoagarospirol
# 3    2-Hydroxyguaia-1(10),11-dien-15-oic acid
# 4                                 Acetic acid
# Name: Chemical, dtype: object
# 0    Dihydrokaranone
# 1       Benzaldehyde
# 2       Anisaldehyde
# 3     Oxoagarospirol
# 4           Furfural
# Name: Chemical, dtype: object
# 0          Diallyl disulfide
# 1         Diallyl trisulfide
# 2    Allyl methyl trisulfide
# 3     Allyl methyl disulfide
# 4            Diallyl sulfide
# Name: Chemical, dtype: object
# 0                     Caryophyllene oxide
# 1    Sesquiterpene hydrocarbons (unknown)
# 2                         beta-Bisabolene
# 3                          gamma-Selinene
# 4        Sesquiterpene alcohols (unknown)
# Name: Chemical, dtype: object
# 0    beta-Sesquiphellandrene
# 1            beta-Bisabolene
# 2                1,8-Cineole
# 3         beta-Caryophyllene
# 4             delta-Selinene
# Name: Chemical, dtype: object
# 0       Ethyl butyrate
# 1         alpha-Pinene
# 2    Ethyl isovalerate
# 3      Ethyl hexanoate
# 4             Linalool
# Name: Chemical, dtype: object
# 0    (E)-2-Hexenal
# 1      beta-Pinene
# 2    (E)-2-Hexenol
# 3          Hexanal
# 4        1-Hexanol
# Name: Chemical, dtype: object
# 0    (E,E)-Farnesyl acetate
# 1              Ambrettolide
# 2             Linoleic acid
# 3    (Z,Z)-Farnesyl acetate
# 4         Ethyl dodecanoate
# Name: Chemical, dtype: object
# 0               (E,E)-Farnesyl acetate
# 1                Hexadec-7-en-16-olide
# 2    Farnesyl acetate (unknown isomer)
# 3                       (E,E)-Farnesol
# 4                        Decyl acetate
# Name: Chemical, dtype: object
# 0    (E,E)-Farnesyl acetate
# 1              Ambrettolide
# 2             Decyl acetate
# 3           Dodecyl acetate
# 4    (Z,E)-Farnesyl acetate
# Name: Chemical, dtype: object
# 0    (E,E)-Farnesyl acetate
# 1              Ambrettolide
# 2             Decyl acetate
# 3           Dodecyl acetate
# 4    (Z,E)-Farnesyl acetate
# Name: Chemical, dtype: object
# 0       (E,E)-Farnesyl acetate
# 1                 Ambrettolide
# 2                   Oleic acid
# 3    (Z)-Octadec-9-en-18-olide
# 4       (Z,E)-Farnesyl acetate
# Name: Chemical, dtype: object
# 0               Dodecyl acetate
# 1                 Decyl acetate
# 2         5-Tetradecen-14-olide
# 3    (Z)-5-Tetradecenyl acetate
# 4           5-Dodecenyl acetate
# Name: Chemical, dtype: object
# 0      beta-Himachalene
# 1         gamma-Elemene
# 2         delta-Elemene
# 3        Bornyl acetate
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0           Linalool
# 1             Cedrol
# 2        1,8-Cineole
# 3        para-Cymene
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0            Decanal
# 1           2-Octene
# 2        2-Undecenal
# 3    Methyl phaseate
# 4          1-Decanol
# Name: Chemical, dtype: object
# 0    alpha-Eudesmol
# 1     beta-Eudesmol
# 2    delta-Cadinene
# 3     (E)-Nerolidol
# 4      ar-Curcumene
# Name: Chemical, dtype: object
# 0      alpha-Eudesmol
# 1    (E)-beta-Ocimene
# 2        alpha-Pinene
# 3             Myrcene
# 4       beta-Eudesmol
# Name: Chemical, dtype: object
# 0                 Valerianol
# 1              beta-Eudesmol
# 2      10-epi-gamma-Eudesmol
# 3                     Elemol
# 4    Selin-5-en-7-ol (tent.)
# Name: Chemical, dtype: object
# 0              Valerianol
# 1    7-epi-alpha-Eudesmol
# 2                  Elemol
# 3           beta-Eudesmol
# 4          gamma-Eudesmol
# Name: Chemical, dtype: object
# 0                       Sabinene
# 1                         Osthol
# 2                   alpha-Pinene
# 3    trans-Chrysanthenyl acetate
# 4                Pentadecanolide
# Name: Chemical, dtype: object
# 0     beta-Phellandrene
# 1                Osthol
# 2          alpha-Pinene
# 3    alpha-Copaen-11-ol
# 4              Sabinene
# Name: Chemical, dtype: object
# 0                                      beta-Bisabolene
# 1                                         Pregeijerene
# 2    2-(1,2-Epoxypropane)-5-methoxyphenyl 2-methylb...
# 3                                            Geijerene
# 4                                         (E)-Anethole
# Name: Chemical, dtype: object
# 0          Nonacosane
# 1           Tricosane
# 2      Benzyl alcohol
# 3         Heptacosane
# 4    Cinnamyl alcohol
# Name: Chemical, dtype: object
# 0          Caryophyllene oxide
# 1        6-epi-alpha-Bisabolol
# 2                  para-Cymene
# 3                      Borneol
# 4    14-Hydroxy-alpha-humulene
# Name: Chemical, dtype: object
# 0           Santolinatriene
# 1               Chamazulene
# 2       1,10-di-epi-Cubenol
# 3    14-oxy-alpha-Muurolene
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0                      Borneol
# 1    Ionol (unknown structure)
# 2                     Linalool
# 3                        Ledol
# 4                       Guaiol
# Name: Chemical, dtype: object
# 0       alpha-Bisabolol
# 1          Germacrene A
# 2              Linalool
# 3    beta-Caryophyllene
# 4         beta-Eudesmol
# Name: Chemical, dtype: object
# 0    Sesquiterpene alcohols (unknown)
# 1                             Camphor
# 2                       beta-Eudesmol
# 3                         1,8-Cineole
# 4                   Artemisia alcohol
# Name: Chemical, dtype: object
# 0    beta-Caryophyllene
# 1           1,8-Cineole
# 2               Camphor
# 3          7-Octen-4-ol
# 4        alpha-Humulene
# Name: Chemical, dtype: object
# 0     Neryl acetate
# 1    Bornyl acetate
# 2    trans-Verbenol
# 3        Lavandulol
# 4          Linalool
# Name: Chemical, dtype: object
# 0     beta-Himachalene
# 1      alpha-Atlantone
# 2          1,8-Cineole
# 3           Himachalol
# 4    Artemisia alcohol
# Name: Chemical, dtype: object
# 0    Sesquiterpene alcohols (unknown)
# 1                       beta-Selinene
# 2                 Coumarins (mixture)
# 3                             Eugenol
# 4                         Longifolene
# Name: Chemical, dtype: object
# 0                     1-Hexanol
# 1                      Limonene
# 2                        Elemol
# 3                       Hexanal
# 4    Nerolidol (unknown isomer)
# Name: Chemical, dtype: object
# 0          Ethyl hexanoate
# 1           Ethyl butyrate
# 2          Ethyl octanoate
# 3          Butyl hexanoate
# 4    Ethyl (E)-3-hexenoate
# Name: Chemical, dtype: object
# 0    Hexadecanoic acid
# 1             Furfural
# 2           Oleic acid
# 3       Linolenic acid
# 4        (Z)-3-Hexenol
# Name: Chemical, dtype: object
# 0    beta-Bisabolol
# 1     (E)-Nerolidol
# 2      ar-Curcumene
# 3            Guaiol
# 4          Camphene
# Name: Chemical, dtype: object
# 0          (E)-Nerolidol
# 1              T-Cadinol
# 2                Cubenol
# 3        gamma-Muurolene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0         (E)-Nerolidol
# 1          Germacrene D
# 2    beta-Caryophyllene
# 3       gamma-Muurolene
# 4             T-Cadinol
# Name: Chemical, dtype: object
# 0    Sesquiterpene alcohols (unknown)
# 1                       alpha-Cadinol
# 2                        Germacrene D
# 3                           T-Cadinol
# 4                  beta-Caryophyllene
# Name: Chemical, dtype: object
# 0    3-Methylbutanol
# 1      (Z)-3-Hexenol
# 2    Isoamyl acetate
# 3          1-Butanol
# 4          1-Hexanol
# Name: Chemical, dtype: object
# 0               Safrole
# 1               Eugenol
# 2    beta-Caryophyllene
# 3         beta-Selinene
# 4        alpha-Cubebene
# Name: Chemical, dtype: object
# 0                               (E)-beta-Ionone
# 1                            (Z)-Heptadec-8-ene
# 2            Methyl (E)-4-(geranyloxy)cinnamate
# 3    (N)-[2-(4-Prenyloxyphenyl)ethyl] tiglamide
# 4                               Dodecyl acetate
# Name: Chemical, dtype: object
# 0                             Linalool
# 1    Farnesyl acetate (unknown isomer)
# 2                      Farnesylacetone
# 3                       (E,E)-Farnesol
# 4                               Phytol
# Name: Chemical, dtype: object
# 0        alpha-Terpineol
# 1    Coumarins (mixture)
# 2              Bupleurol
# 3        Geranyl acetate
# 4    Citronellyl acetate
# Name: Chemical, dtype: object
# 0         alpha-Copaene
# 1          Germacrene D
# 2          Germacrene B
# 3    beta-Caryophyllene
# 4        delta-Cadinene
# Name: Chemical, dtype: object
# 0                         (E)-Nerolidol
# 1                    (E)-alpha-Farnesol
# 2            Bisabolol (unknown isomer)
# 3    Sesquiterpenes, oxygen-containing-
# 4                                   NaN
# Name: Chemical, dtype: object
# 0        Preisocalamenediol
# 1                 Acorenone
# 2             Isoshyobunone
# 3              Calamenediol
# 4    1,7-Diepi-beta-cedrene
# Name: Chemical, dtype: object
# 0    (Z)-Methyl isoeugenol
# 1    1(10)-Aristolen-2-one
# 2       beta-Caryophyllene
# 3          Acoragermacrone
# 4             Isoacolamone
# Name: Chemical, dtype: object
# 0    (Z)-Methyl isoeugenol
# 1               Calamenene
# 2          Isocalamenediol
# 3          Acoragermacrone
# 4               Shyobunone
# Name: Chemical, dtype: object
# 0           epi-Shyobunone
# 1               Calamenone
# 2           beta-Gurjunene
# 3               Calamenene
# 4    (Z)-Methyl isoeugenol
# Name: Chemical, dtype: object
# 0      beta-Asarone (Z)
# 1            Shyobunone
# 2             Acorenone
# 3    Preisocalamenediol
# 4     alpha-Asarone (E)
# Name: Chemical, dtype: object
# 0           Acorenone
# 1             Acorone
# 2    beta-Asarone (Z)
# 3          Shyobunone
# 4     Isocalamenediol
# Name: Chemical, dtype: object
# 0    beta-Asarone (Z)
# 1            Limonene
# 2     alpha-Terpineol
# 3         Longifolene
# 4     alpha-Bulnesene
# Name: Chemical, dtype: object
# 0               alpha-Asarone (E)
# 1    2,4,5-Trimethoxybenzaldehyde
# 2                     1,8-Cineole
# 3                    beta-Ocimene
# 4                         Calamol
# Name: Chemical, dtype: object
# 0             Acorenone
# 1        beta-Gurjunene
# 2         Isoshyobunone
# 3    beta-Asarone oxide
# 4          Calamenediol
# Name: Chemical, dtype: object
# 0      beta-Asarone (Z)
# 1    Preisocalamenediol
# 2            Shyobunone
# 3     alpha-Asarone (E)
# 4        epi-Shyobunone
# Name: Chemical, dtype: object
# 0                             Acorenone
# 1                        epi-Shyobunone
# 2                    Preisocalamenediol
# 3    Sesquiterpenes, oxygen-containing-
# 4                            Isoacorone
# Name: Chemical, dtype: object
# 0       Preisocalamenediol
# 1            Isoshyobunone
# 2                Acorenone
# 3                  Camphor
# 4    2,6-di-epi-Shyobunone
# Name: Chemical, dtype: object
# 0    beta-Caryophyllene
# 1    (E)-beta-Farnesene
# 2    (Z)-beta-Farnesene
# 3               Myrcene
# 4              Drimenol
# Name: Chemical, dtype: object
# 0    Caryophyllene oxide
# 1                Myrcene
# 2               Linalool
# 3     beta-Caryophyllene
# 4               Drimenol
# Name: Chemical, dtype: object
# 0         2-Nonanone
# 1        2-Heptanone
# 2    3-Methylbutanal
# 3      2-Tridecanone
# 4          Verbenone
# Name: Chemical, dtype: object
# 0           Linalool
# 1            Carotol
# 2            Carvone
# 3    Linalyl acetate
# 4            Myrcene
# Name: Chemical, dtype: object
# 0               alpha-Asarone (E)
# 1                 beta-Bisabolene
# 2    2,4,5-Trimethoxybenzaldehyde
# 3                beta-Asarone (Z)
# 4                         Eugenol
# Name: Chemical, dtype: object
# 0      para-Cymene
# 1     alpha-Pinene
# 2    alpha-Thujene
# 3          Myrcene
# 4         Linalool
# Name: Chemical, dtype: object
# 0          para-Cymene
# 1             Linalool
# 2    Cascarilladiene I
# 3        beta-Eudesmol
# 4         alpha-Pinene
# Name: Chemical, dtype: object
# 0    Hexadecanoic acid
# 1       Linolenic acid
# 2        Linoleic acid
# 3           Oleic acid
# 4    Methyl salicylate
# Name: Chemical, dtype: object
# 0                    Hexadecanoic acid
# 1                     Methyl palmitate
# 2                       Geranylacetone
# 3                      (E)-beta-Ionone
# 4    6,10,14-Trimethyl-2-pentadecanone
# Name: Chemical, dtype: object
# 0        Thujopsene
# 1            Cedrol
# 2     alpha-Cedrene
# 3    3-Thujopsanone
# 4      beta-Cedrene
# Name: Chemical, dtype: object
# 0        Thujopsene
# 1     alpha-Cedrene
# 2            Cedrol
# 3      beta-Cedrene
# 4    gamma-Eudesmol
# Name: Chemical, dtype: object
# 0            Cedrol
# 1     alpha-Cedrene
# 2        Thujopsene
# 3    3-Thujopsanone
# 4      beta-Cedrene
# Name: Chemical, dtype: object
# 0            Cedrol
# 1     alpha-Cedrene
# 2        Thujopsene
# 3      beta-Cedrene
# 4    gamma-Eudesmol
# Name: Chemical, dtype: object
# 0    alpha-Cedrene
# 1           Cedrol
# 2       Thujopsene
# 3     beta-Cedrene
# 4          Widdrol
# Name: Chemical, dtype: object
# 0                      Thujopsene
# 1                   Thujopsadiene
# 2                  3-Thujopsanone
# 3                          Cedrol
# 4    Acoradienes (alpha- & beta-)
# Name: Chemical, dtype: object
# 0     alpha-Copaene
# 1    delta-Cadinene
# 2     (E)-Nerolidol
# 3    alpha-Cubebene
# 4    beta-Curcumene
# Name: Chemical, dtype: object
# 0                      beta-Himachalene
# 1                     alpha-Himachalene
# 2                     gamma-Himachalene
# 3            Sesquiterpene hydrocarbons
# 4    Sesquiterpenes, oxygen-containing-
# Name: Chemical, dtype: object
# 0    3-Ethyl-4-methylhexane
# 1               para-Cymene
# 2                  Limonene
# 3           gamma-Terpinene
# 4          (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0           Ligustilide
# 1    3-n-Butylphthalide
# 2        alpha-Selinene
# 3         Pentylbenzene
# 4         beta-Eudesmol
# Name: Chemical, dtype: object
# 0           Ligustilide
# 1    3-n-Butylphthalide
# 2        alpha-Selinene
# 3         Pentylbenzene
# 4         beta-Eudesmol
# Name: Chemical, dtype: object
# 0                              Nonanal
# 1                      (E)-beta-Ionone
# 2    6,10,14-Trimethyl-2-pentadecanone
# 3                   (E)-beta-Farnesene
# 4                      Eugenyl acetate
# Name: Chemical, dtype: object
# 0    (E)-beta-Farnesene
# 1           beta-Pinene
# 2      (Z)-beta-Ocimene
# 3      (E)-beta-Ocimene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0    (E)-beta-Farnesene
# 1      (Z)-beta-Ocimene
# 2      (E)-beta-Ocimene
# 3           beta-Pinene
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0                              alpha-Bisabolol oxide A
# 1                           Farnesene (unknown isomer)
# 2    1,4,9,9-Tetramethyloctahydro-1H,3a,7-methylazu...
# 3                           Nerolidol (unknown isomer)
# 4                            Farnesol (unknown isomer)
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide B
# 1    alpha-Bisabolol oxide A
# 2         (Z)-beta-Farnesene
# 3            alpha-Bisabolol
# 4                Chamazulene
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide A
# 1         (E)-beta-Farnesene
# 2            alpha-Bisabolol
# 3    alpha-Bisabolol oxide B
# 4                Chamazulene
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide A
# 1                Chamazulene
# 2    alpha-Bisabolol oxide B
# 3     alpha-Bisabolone oxide
# 4         (E)-beta-Farnesene
# Name: Chemical, dtype: object
# 0        (E)-beta-Farnesene
# 1    alpha-Bisabolone oxide
# 2              alpha-Pinene
# 3                   Camphor
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide A
# 1    alpha-Bisabolol oxide B
# 2            alpha-Bisabolol
# 3                Chamazulene
# 4                Spiro ether
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide A
# 1    alpha-Bisabolol oxide B
# 2           Artemisia ketone
# 3            alpha-Bisabolol
# 4         (E)-beta-Farnesene
# Name: Chemical, dtype: object
# 0      (E,E)-alpha-Farnesene
# 1                 Isoborneol
# 2    alpha-Bisabolol oxide A
# 3    alpha-Bisabolol oxide B
# 4                      Nerol
# Name: Chemical, dtype: object
# 0         (E)-beta-Farnesene
# 1    cis-En-yn-dicyclo ether
# 2                Chamomillol
# 3               beta-Elemene
# 4             alpha-Humulene
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide A
# 1    alpha-Bisabolol oxide B
# 2                Chamazulene
# 3     alpha-Bisabolone oxide
# 4         (E)-beta-Farnesene
# Name: Chemical, dtype: object
# 0    alpha-Bisabolol oxide A
# 1    alpha-Bisabolol oxide B
# 2            Chamospiroether
# 3     alpha-Bisabolone oxide
# 4                Chamazulene
# Name: Chemical, dtype: object
# 0                           Furfural
# 1                   5-Methylfurfural
# 2    Dihydro-2-methyl-3(2H)-furanone
# 3                      2-Acetylfuran
# 4                   Furfuryl alcohol
# Name: Chemical, dtype: object
# 0                           Furfural
# 1                   5-Methylfurfural
# 2                      2-Acetylfuran
# 3    Dihydro-2-methyl-3(2H)-furanone
# 4                   Furfuryl acetate
# Name: Chemical, dtype: object
# 0       (E)-2-Dodecenal
# 1    (E)-2-Tetradecenal
# 2         (E)-2-Decenal
# 3               Decanal
# 4         (E)-2-Decenol
# Name: Chemical, dtype: object
# 0    (E)-2-Tetradecenal
# 1       (E)-2-Dodecenal
# 2               Decanal
# 3        2-Pentadecenal
# 4         (E)-2-Decenal
# Name: Chemical, dtype: object
# 0    2-Methylene-3-buten-1-yl benzoate
# 1                          Spathulenol
# 2                        (E)-Nerolidol
# 3                  Caryophyllene oxide
# 4                   beta-Caryophyllene
# Name: Chemical, dtype: object
# 0    2-Methylene-3-buten-1-yl benzoate
# 1                             Linalool
# 2                          Spathulenol
# 3                             Elemicin
# 4                   beta-Caryophyllene
# Name: Chemical, dtype: object
# 0    (E)-Methyl isoeugenol
# 1           Methyl eugenol
# 2                 Linalool
# 3       beta-Caryophyllene
# 4    (Z)-Methyl isoeugenol
# Name: Chemical, dtype: object
# 0       (E)-Cinnamyl acetate
# 1    trans-alpha-Bergamotene
# 2        Caryophyllene oxide
# 3              alpha-Cadinol
# 4               Tetradecanal
# Name: Chemical, dtype: object
# 0      (E)-Cinnamyl acetate
# 1        beta-Caryophyllene
# 2    3-Phenylpropyl acetate
# 3            alpha-Humulene
# 4                 T-Cadinol
# Name: Chemical, dtype: object
# 0        delta-Cadinene
# 1          alpha-Pinene
# 2    beta-Caryophyllene
# 3        alpha-Muurolol
# 4           beta-Pinene
# Name: Chemical, dtype: object
# 0                        Camphene
# 1    2,2,6-Trimethylcyclohexanone
# 2                     para-Cymene
# 3                  Bornyl acetate
# 4                    alpha-Pinene
# Name: Chemical, dtype: object
# 0           Linalool
# 1    Linalyl acetate
# 2    Hexatriacontane
# 3    alpha-Terpineol
# 4      epi-13-Manool
# Name: Chemical, dtype: object
# 0    Acids and esters
# 1             Alkanes
# 2              Maltol
# 3            Linalool
# 4     1-Phenylethanol
# Name: Chemical, dtype: object
# 0             Alkanes
# 1    Acids and esters
# 2              Maltol
# 3            Linalool
# 4              Phenol
# Name: Chemical, dtype: object
# 0       3-Tetradecanone
# 1    Tetradecyl acetate
# 2       Dodecyl acetate
# 3        3-Hexadecanone
# 4          Tetradecanal
# Name: Chemical, dtype: object
# 0                     3-Tetradecanone
# 1                  Tetradecyl acetate
# 2                      3-Hexadecanone
# 3                     Dodecyl acetate
# 4    3-Tetradecenone (unknown isomer)
# Name: Chemical, dtype: object
# 0    Hexadecanoic acid
# 1        Linoleic acid
# 2             Pyridine
# 3           Oleic acid
# 4      4-Vinylguaiacol
# Name: Chemical, dtype: object
# 0    (E)-beta-Farnesene
# 1              Limonene
# 2    beta-Caryophyllene
# 3          Germacrene D
# 4     Bicyclogermacrene
# Name: Chemical, dtype: object
# 0    beta-Caryophyllene
# 1         alpha-Copaene
# 2        delta-Cadinene
# 3        gamma-Cadinene
# 4                Cedrol
# Name: Chemical, dtype: object
# 0       Ethyl butyrate
# 1        Ethyl acetate
# 2              Ethanol
# 3         Acetaldehyde
# 4    Methyl salicylate
# Name: Chemical, dtype: object
# 0           Costus lactone, dehydro-
# 1    Costus lactone, dihydrodehydro-
# 2                           Linalool
# 3                    Linalyl acetate
# 4                             Costol
# Name: Chemical, dtype: object
# 0           Spathulenol
# 1               Borneol
# 2    beta-Caryophyllene
# 3              Cyperene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0               beta-Cubebene
# 1    Copaene (unknown isomer)
# 2                     Cubebol
# 3              delta-Cadinene
# 4              alpha-Cubebene
# Name: Chemical, dtype: object
# 0     alpha-Copaene
# 1           Cubebol
# 2     beta-Cubebene
# 3    delta-Cadinene
# 4    alpha-Cubebene
# Name: Chemical, dtype: object
# 0            Isoborneol
# 1     Isobornyl acetate
# 2               Camphor
# 3    oxo-alpha-Ylangene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0      Isobornyl acetate
# 1             Isoborneol
# 2     (Z)-beta-Farnesene
# 3     beta-Caryophyllene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0               Camphor
# 1            Isoborneol
# 2    beta-Caryophyllene
# 3    (Z)-beta-Farnesene
# 4           beta-Pinene
# Name: Chemical, dtype: object
# 0               (E)-beta-Ionone
# 1      2,4-Dimethyl-3-pentanone
# 2           3-Methyl-3-pentanol
# 3           Dihydro-beta-ionone
# 4    2,6-di-tert-Butyl-p-cresol
# Name: Chemical, dtype: object
# 0                              Limonene
# 1    Sesquiterpenes, oxygen-containing-
# 2                    (E)-beta-Farnesene
# 3             Eudesmol (unknown isomer)
# 4                                Elemol
# Name: Chemical, dtype: object
# 0     Cyperotudone
# 1         Cyperene
# 2    Patchoulenone
# 3        Rotundone
# 4        Rotundene
# Name: Chemical, dtype: object
# 0         alpha-Copaene
# 1        alpha-Humulene
# 2    beta-Caryophyllene
# 3          Germacrene D
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0     delta-Cadinene
# 1       Germacrene D
# 2      alpha-Copaene
# 3    gamma-Muurolene
# 4            Cubenol
# Name: Chemical, dtype: object
# 0       alpha-Santalene
# 1        Methyl eugenol
# 2              Elemicin
# 3        delta-Cadinene
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0            Benzyl alcohol
# 1           Benzyl benzoate
# 2          Methyl linoleate
# 3    2-Phenylethyl benzoate
# 4         Benzyl salicylate
# Name: Chemical, dtype: object
# 0              Davanone
# 1                 Nerol
# 2              Geraniol
# 3    Davanone, hydroxy-
# 4    dihydro-Rosefurans
# Name: Chemical, dtype: object
# 0                                    Davanone
# 1                           Bicyclogermacrene
# 2                                 Spathulenol
# 3    5-Ethenyldihydro-5-methyl-2(3H)-furanone
# 4                                   T-Cadinol
# Name: Chemical, dtype: object
# 0              Davanone
# 1                 Nerol
# 2              Geraniol
# 3    Davanone, hydroxy-
# 4        8-Oxonerolidol
# Name: Chemical, dtype: object
# 0    2,6-Dimethyl-3(E),5(E),7-octatrien-2-ol
# 1                            Methyl benzoate
# 2                           (E)-beta-Ocimene
# 3    2,6-Dimethyl-1,3(E),5(E),7-octatetraene
# 4                             Benzyl alcohol
# Name: Chemical, dtype: object
# 0    2,6-Dimethyl-3(E),5(E),7-octatrien-2-ol
# 1                         Phenylacetonitrile
# 2    2,6-Dimethyl-1,3(E),5(E),7-octatetraene
# 3                      trans-Ocimene epoxide
# 4                              (E)-Nerolidol
# Name: Chemical, dtype: object
# 0    2-Hydroxy-4-methoxybenzaldehyde
# 1                         Oleic acid
# 2                  Hexadecanoic acid
# 3                           Vanillin
# 4                  Octadecanoic acid
# Name: Chemical, dtype: object
# 0        1,11-Dodecadiene
# 1    Butyl tetradecanoate
# 2              Oleic acid
# 3                 Camphor
# 4             Longifolene
# Name: Chemical, dtype: object
# 0            Nonanal
# 1      Nonanoic acid
# 2    Dodecanoic acid
# 3        Heptadecane
# 4         Hexadecane
# Name: Chemical, dtype: object
# 0          Decanal
# 1    alpha-Thujene
# 2        1-Decanol
# 3         Sclareol
# 4         Limonene
# Name: Chemical, dtype: object
# 0                          delta-Cadinene
# 1                            Germacrene D
# 2    Sesquiterpene hydrocarbons (unknown)
# 3                               T-Cadinol
# 4        Sesquiterpene alcohols (unknown)
# Name: Chemical, dtype: object
# 0             Campherenone
# 1      Caryophyllene oxide
# 2         alpha-Bisabolone
# 3       beta-Caryophyllene
# 4    6-epi-alpha-Bisabolol
# Name: Chemical, dtype: object
# 0             Campherenone
# 1       epi-beta-Santalene
# 2      Caryophyllene oxide
# 3         alpha-Bisabolone
# 4    6-epi-alpha-Bisabolol
# Name: Chemical, dtype: object
# 0             T-Muurolol
# 1          alpha-Cadinol
# 2         gamma-Cadinene
# 3    Caryophyllene oxide
# 4        alpha-Muurolene
# Name: Chemical, dtype: object
# 0        Ethyl hexadecanoate
# 1    trans-alpha-Bergamotene
# 2        Humulene epoxide II
# 3              beta-Selinene
# 4                 T-Muurolol
# Name: Chemical, dtype: object
# 0    5-epi-Paradisiol
# 1      delta-Selinene
# 2       beta-Selinene
# 3      Neointermedeol
# 4      alpha-Eudesmol
# Name: Chemical, dtype: object
# 0                 Globulol
# 1            Viridiflorene
# 2             epi-Globulol
# 3              Spathulenol
# 4    10-epi-gamma-Eudesmol
# Name: Chemical, dtype: object
# 0    beta-Caryophyllene
# 1          beta-Elemene
# 2         alpha-Copaene
# 3         alpha-Cadinol
# 4     Bicyclogermacrene
# Name: Chemical, dtype: object
# 0     Germacrene-D-4-ol
# 1         gamma-Elemene
# 2    beta-Caryophyllene
# 3         beta-Selinene
# 4       gamma-Muurolene
# Name: Chemical, dtype: object
# 0         Globulol
# 1     Viridiflorol
# 2     epi-Globulol
# 3            Ledol
# 4    alpha-Cadinol
# Name: Chemical, dtype: object
# 0         beta-Selinene
# 1    allo-Aromadendrene
# 2    epi-alpha-Selinene
# 3       beta-Chamigrene
# 4      Isocaryophyllene
# Name: Chemical, dtype: object
# 0          beta-Elemene
# 1     Bicyclogermacrene
# 2    beta-Caryophyllene
# 3          Germacrene D
# 4        delta-Cadinene
# Name: Chemical, dtype: object
# 0          alpha-Thujene
# 1            beta-Pinene
# 2     beta-Caryophyllene
# 3    Caryophyllene oxide
# 4            1,8-Cineole
# Name: Chemical, dtype: object
# 0              Limonene
# 1      (E)-beta-Ocimene
# 2    beta-Caryophyllene
# 3               Myrcene
# 4              Sabinene
# Name: Chemical, dtype: object
# 0          Germacrene B
# 1    beta-Caryophyllene
# 2         gamma-Elemene
# 3          beta-Elemene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1        Linalool
# 2        Geraniol
# 3     Citronellol
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0         beta-Elemene
# 1          Pentadecane
# 2            Tridecane
# 3          Tetradecane
# 4    epsilon-Muurolene
# Name: Chemical, dtype: object
# 0    2,3-Dihydrobenzofuran
# 1                1-Hexanol
# 2     Dihydroactinidiolide
# 3          Dodecanoic acid
# 4             1-Hexadecene
# Name: Chemical, dtype: object
# 0          1-Hexanol
# 1     Heptanoic acid
# 2    Dodecanoic acid
# 3    alpha-Muurolene
# 4         Calamenene
# Name: Chemical, dtype: object
# 0         (E)-2-Hexenal
# 1    beta-Caryophyllene
# 2           1,8-Cineole
# 3              Linalool
# 4               Myrcene
# Name: Chemical, dtype: object
# 0                 (E)-2-Hexenal
# 1            beta-Caryophyllene
# 2                   1,8-Cineole
# 3                       Myrcene
# 4    Nerolidol (unknown isomer)
# Name: Chemical, dtype: object
# 0              beta-Phellandrene
# 1    Germacra-1(10),5-dien-11-ol
# 2                       Linalool
# 3                       Sabinene
# 4                Linalyl acetate
# Name: Chemical, dtype: object
# 0                  delta-Cadinene
# 1                   alpha-Cadinol
# 2    Cadina-4.1(10)-dien-8beta-ol
# 3                    alpha-Pinene
# 4                 alpha-Bisabolol
# Name: Chemical, dtype: object
# 0    alpha-Terpineol
# 1      Terpinen-4-ol
# 2     Bornyl acetate
# 3            Borneol
# 4            Camphor
# Name: Chemical, dtype: object
# 0        T-Cadinol
# 1    beta-Selinene
# 2         Linalool
# 3    beta-Eudesmol
# 4       T-Muurolol
# Name: Chemical, dtype: object
# 0    (E)-beta-Farnesene
# 1       beta-Bisabolene
# 2     alpha-Bergamotene
# 3          alpha-Pinene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0          Diallyl disulfide
# 1         Diallyl trisulfide
# 2    Allyl methyl trisulfide
# 3            Diallyl sulfide
# 4     Allyl methyl disulfide
# Name: Chemical, dtype: object
# 0         Diallyl trisulfide
# 1    Allyl methyl trisulfide
# 2          Diallyl disulfide
# 3            Diallyl sulfide
# 4     Allyl methyl disulfide
# Name: Chemical, dtype: object
# 0      Hexadecanoic acid
# 1               Linalool
# 2    Ethyl hexadecanoate
# 3         Linolenic acid
# 4       Methyl linoleate
# Name: Chemical, dtype: object
# 0        Linolenic acid
# 1     Hexadecanoic acid
# 2            Oleic acid
# 3         Linoleic acid
# 4    Tetradecanoic acid
# Name: Chemical, dtype: object
# 0                  (E,E)-Germacrone
# 1              trans-beta-Elemenone
# 2                        Piperitone
# 3    2-Phenylethyl 3-methylbutyrate
# 4                          Linalool
# Name: Chemical, dtype: object
# 0             Piperitone
# 1    Caryophyllene oxide
# 2                Borneol
# 3               Linalool
# 4      2-Methyltridecane
# Name: Chemical, dtype: object
# 0    cis-3-Butylidene-4,5-dihydrophthalide
# 1       Sesquiterpenes, oxygen-containing-
# 2                       alpha-Phellandrene
# 3                              Dill apiole
# 4                        beta-Phellandrene
# Name: Chemical, dtype: object
# 0             Camphene
# 1    beta-Phellandrene
# 2          1,8-Cineole
# 3         ar-Curcumene
# 4             Geranial
# Name: Chemical, dtype: object
# 0        Camphene
# 1     1,8-Cineole
# 2    ar-Curcumene
# 3        Geranial
# 4           Neral
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1                   Geranial
# 2           alpha-Bisabolene
# 3    beta-Sesquiphellandrene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0        Zingiberene
# 1    beta-Bisabolene
# 2           Sabinene
# 3           Camphene
# 4           Geraniol
# Name: Chemical, dtype: object
# 0        Zingiberene
# 1    beta-Bisabolene
# 2           Sabinene
# 3           Camphene
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0               ar-Curcumene
# 1          alpha-Zingiberene
# 2    beta-Sesquiphellandrene
# 3            beta-Bisabolene
# 4           gamma-Bisabolene
# Name: Chemical, dtype: object
# 0          Zingiberene
# 1    cis-beta-Santalol
# 2    beta-Phellandrene
# 3      beta-Bisabolene
# 4             Camphene
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1               ar-Curcumene
# 2    beta-Sesquiphellandrene
# 3            beta-Bisabolene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0          alpha-Zingiberene
# 1    beta-Sesquiphellandrene
# 2            beta-Bisabolene
# 3               ar-Curcumene
# 4                   Limonene
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1    beta-Sesquiphellandrene
# 2                   Camphene
# 3               ar-Curcumene
# 4       cis-gamma-Bisabolene
# Name: Chemical, dtype: object
# 0             alpha-Zingiberene
# 1                        Citral
# 2                      Geraniol
# 3                  ar-Curcumene
# 4    Nerolidol (unknown isomer)
# Name: Chemical, dtype: object
# 0               ar-Curcumene
# 1    beta-Sesquiphellandrene
# 2            beta-Bisabolene
# 3                Zingiberene
# 4                   Geraniol
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1               ar-Curcumene
# 2    beta-Sesquiphellandrene
# 3                   Limonene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0               ar-Curcumene
# 1    beta-Sesquiphellandrene
# 2                Zingiberene
# 3             beta-Farnesene
# 4            beta-Bisabolene
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1               ar-Curcumene
# 2    beta-Sesquiphellandrene
# 3            beta-Bisabolene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0        Zingiberene
# 1           Geraniol
# 2           Geranial
# 3    beta-Bisabolene
# 4              Nerol
# Name: Chemical, dtype: object
# 0                   Geranial
# 1                      Neral
# 2                Zingiberene
# 3    beta-Sesquiphellandrene
# 4               ar-Curcumene
# Name: Chemical, dtype: object
# 0           beta-Zingiberene
# 1    beta-Sesquiphellandrene
# 2                   Geranial
# 3            beta-Bisabolene
# 4      (E,E)-alpha-Farnesene
# Name: Chemical, dtype: object
# 0                   Geranial
# 1           beta-Zingiberene
# 2                1,8-Cineole
# 3                      Neral
# 4    beta-Sesquiphellandrene
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1    beta-Sesquiphellandrene
# 2                   Camphene
# 3          beta-Phellandrene
# 4            alpha-Farnesene
# Name: Chemical, dtype: object
# 0    beta-Bisabolene
# 1       ar-Curcumene
# 2           Camphene
# 3           Geranial
# 4      beta-Eudesmol
# Name: Chemical, dtype: object
# 0    beta-Bisabolene
# 1       ar-Curcumene
# 2           Camphene
# 3              Neral
# 4           Limonene
# Name: Chemical, dtype: object
# 0    beta-Bisabolene
# 1           Camphene
# 2           Geranial
# 3              Neral
# 4       ar-Curcumene
# Name: Chemical, dtype: object
# 0              beta-Bisabolene
# 1                 ar-Curcumene
# 2                        Neral
# 3                     Geranial
# 4    Farnesol (unknown isomer)
# Name: Chemical, dtype: object
# 0    beta-Bisabolene
# 1       ar-Curcumene
# 2           Geranial
# 3           Camphene
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0                   Geranial
# 1            beta-Bisabolene
# 2    beta-Sesquiphellandrene
# 3          beta-Phellandrene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0           Geranial
# 1           Camphene
# 2    Geranyl acetate
# 3        Citronellol
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0             Geranial
# 1             Camphene
# 2          Zingiberene
# 3                Neral
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0                           Limonene
# 1      trans,p-1(7),8-Menthadienol-2
# 2        cis,p-1(7),8-Menthadienol-2
# 3       trans-p-Mentha-2,8-dien-1-ol
# 4    p-Menthadienol (unknown isomer)
# Name: Chemical, dtype: object
# 0                         Limonene
# 1      cis,p-1(7),8-Menthadienol-2
# 2    trans,p-1(7),8-Menthadienol-2
# 3                      Piperitenol
# 4     trans-p-Mentha-2,8-dien-1-ol
# Name: Chemical, dtype: object
# 0                     Valencene
# 1             Alkanes & alkenes
# 2    Nerolidol (unknown isomer)
# 3                 2-Tridecanone
# 4         Nonadecene/nonadecane
# Name: Chemical, dtype: object
# 0      para-Cymene
# 1    Terpinen-4-ol
# 2         Linalool
# 3         Limonene
# 4      Citronellol
# Name: Chemical, dtype: object
# 0    Bornyl acetate
# 1      alpha-Pinene
# 2          Camphene
# 3          Limonene
# 4       beta-Pinene
# Name: Chemical, dtype: object
# 0           Bulnesol
# 1             Guaiol
# 2    alpha-Bulnesene
# 3     beta-Bulnesene
# 4          Guaioxide
# Name: Chemical, dtype: object
# 0                 Bulnesol
# 1                   Guaiol
# 2    10-epi-gamma-Eudesmol
# 3                   Elemol
# 4            beta-Eudesmol
# Name: Chemical, dtype: object
# 0    Guai-6-en-10beta-ol
# 1                  Ledol
# 2           Manoyl oxide
# 3     allo-Aromadendrene
# 4         gamma-Cadinene
# Name: Chemical, dtype: object
# 0           Calamenene
# 1       delta-Cadinene
# 2    Bicyclogermacrene
# 3             Globulol
# 4       alpha-Cubebene
# Name: Chemical, dtype: object
# 0    (Z)-3-Hexenyl acetate
# 1         Cinnamyl alcohol
# 2              2-Pentanone
# 3            (Z)-3-Hexenol
# 4               2-Pentanol
# Name: Chemical, dtype: object
# 0            beta-Bisabolene
# 1    beta-Sesquiphellandrene
# 2         beta-Caryophyllene
# 3           gamma-Bisabolene
# 4               ar-Curcumene
# Name: Chemical, dtype: object
# 0    (Z)-Methyl jasmonate
# 1                Linalool
# 2               Carvacrol
# 3             beta-Pinene
# 4                 Eugenol
# Name: Chemical, dtype: object
# 0       ar-Curcumene
# 1       alpha-Pinene
# 2    gamma-Curcumene
# 3      alpha-Cedrene
# 4      Neryl acetate
# Name: Chemical, dtype: object
# 0                  ar-Curcumene
# 1                  alpha-Pinene
# 2               gamma-Curcumene
# 3                 Neryl acetate
# 4    Nerolidol (unknown isomer)
# Name: Chemical, dtype: object
# 0       Neryl acetate
# 1     gamma-Curcumene
# 2            Limonene
# 3    Neryl propionate
# 4               Nerol
# Name: Chemical, dtype: object
# 0                 Neryl acetate
# 1                         Nerol
# 2              Neryl propionate
# 3                      Linalool
# 4    Curcumene (unknown isomer)
# Name: Chemical, dtype: object
# 0       Neryl acetate
# 1     gamma-Curcumene
# 2    Neryl propionate
# 3               Nerol
# 4        alpha-Pinene
# Name: Chemical, dtype: object
# 0       Neryl acetate
# 1            Linalool
# 2               Nerol
# 3            Limonene
# 4    Neryl propionate
# Name: Chemical, dtype: object
# 0              beta-Caryophyllene
# 1                    beta-Elemene
# 2                 Benzyl benzoate
# 3    1H-Cyclopropane-azulene-4-ol
# 4                   Aromadendrene
# Name: Chemical, dtype: object
# 0    2-Hydroxy-4-methoxybenzaldehyde
# 1                              Ledol
# 2         Nerolidol (unknown isomer)
# 3                            Camphor
# 4                            Borneol
# Name: Chemical, dtype: object
# 0                    (+)-Pulegone
# 1    8-Hydroxy-p-menth-4-en-3-one
# 2                        Linalool
# 3               8-Hydroxymenthone
# 4                     Isopulegone
# Name: Chemical, dtype: object
# 0                    Elemol
# 1    alpha-Terpinyl acetate
# 2            gamma-Eudesmol
# 3            Bornyl acetate
# 4             beta-Eudesmol
# Name: Chemical, dtype: object
# 0     alpha-Cadinol
# 1        T-Muurolol
# 2    gamma-Cadinene
# 3    delta-Cadinene
# 4         T-Cadinol
# Name: Chemical, dtype: object
# 0          Germacrene D
# 1         alpha-Copaene
# 2        delta-Cadinene
# 3    beta-Caryophyllene
# 4          Germacrene B
# Name: Chemical, dtype: object
# 0     gamma-Cadinene
# 1             Elemol
# 2     delta-Cadinene
# 3    alpha-Muurolene
# 4          T-Cadinol
# Name: Chemical, dtype: object
# 0                  Linalool
# 1    p-Methoxyphenylacetone
# 2             Terpinen-4-ol
# 3                  Limonene
# 4                   Safrole
# Name: Chemical, dtype: object
# 0        Acids and esters
# 1                 Alkanes
# 2                Linalool
# 3    Benzyl phenylacetate
# 4    Methyl phenylacetate
# Name: Chemical, dtype: object
# 0                  Linalool
# 1           alpha-Farnesene
# 2    (Z)-3-Hexenyl benzoate
# 3            Benzyl acetate
# 4       Methyl anthranilate
# Name: Chemical, dtype: object
# 0               Methyl linolenate
# 1                  Benzyl alcohol
# 2          (E)-Phenylacetaldoxime
# 3    Germacra-1(10)E,5E-dien-4-ol
# 4              Phenylacetaldehyde
# Name: Chemical, dtype: object
# 0                         alpha-Farnesene
# 1                                  Indole
# 2                                Linalool
# 3    Sesquiterpene hydrocarbons (unknown)
# 4                     Methyl anthranilate
# Name: Chemical, dtype: object
# 0               alpha-Farnesene
# 1                      Linalool
# 2               Geranyllinalool
# 3    (-)-Germacra-1,6-dien-5-ol
# 4           Methyl anthranilate
# Name: Chemical, dtype: object
# 0                      Thujopsene
# 1                    alpha-Pinene
# 2    Acoradienes (alpha- & beta-)
# 3                        Sabinene
# 4                   alpha-Cedrene
# Name: Chemical, dtype: object
# 0    Ethyl (E)-4-methoxycinnamate
# 1                     Pentadecane
# 2                 Ethyl cinnamate
# 3    Ethyl (Z)-4-methoxycinnamate
# 4                        Anethole
# Name: Chemical, dtype: object
# 0    Ethyl (E)-4-methoxycinnamate
# 1             (E)-Ethyl cinnamate
# 2                     Pentadecane
# 3                     1,8-Cineole
# 4                  delta-3-Carene
# Name: Chemical, dtype: object
# 0    2,5-Dimethoxy-p-cymene
# 1      7-epi-gamma Eudesmol
# 2            Junipercamphor
# 3            Isointermedeol
# 4        beta-Caryophyllene
# Name: Chemical, dtype: object
# 0    2,5-Dimethoxy-p-cymene
# 1            gamma-Eudesmol
# 2            alpha-Humulene
# 3        beta-Caryophyllene
# 4             Methyl thymol
# Name: Chemical, dtype: object
# 0            Spathulenol
# 1     beta-Caryophyllene
# 2           beta-Elemene
# 3    Caryophyllene oxide
# 4            beta-Pinene
# Name: Chemical, dtype: object
# 0         Viridiflorene
# 1     Germacrene-D-4-ol
# 2    beta-Caryophyllene
# 3          beta-Elemene
# 4      (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0              beta-Elemene
# 1    alpha-Terpinyl acetate
# 2             alpha-Cadinol
# 3       Caryophyllene oxide
# 4            Methyl eugenol
# Name: Chemical, dtype: object
# 0            Linalool
# ...
# 3    beta-Caryophyllene
# 4              Camphene
# Name: Chemical, dtype: object
# 0           alpha-Pinene
# 1    Dimyrcene (isomers)
# 2            beta-Pinene
# 3                Myrcene
# 4               Sabinene
# Name: Chemical, dtype: object
# 0         alpha-Pinene
# 1             Limonene
# 2          beta-Pinene
# 3      Methyl chavicol
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0         alpha-Pinene
# 1    beta-Phellandrene
# 2             Camphene
# 3             Limonene
# 4          beta-Pinene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1       Longifolene
# 2    delta-3-Carene
# 3          Camphene
# 4       para-Cymene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1              Limonene
# 2    alpha-Phellandrene
# 3        delta-3-Carene
# 4     beta-Phellandrene
# Name: Chemical, dtype: object
# 0                  alpha-Pinene
# 1                   beta-Pinene
# 2                      Limonene
# 3                      Camphene
# 4    Sesquiterpene hydrocarbons
# Name: Chemical, dtype: object
# 0    alpha-Pinene
# 1     beta-Pinene
# 2        Limonene
# 3         Myrcene
# 4        2-Carene
# Name: Chemical, dtype: object
# 0    alpha-Pinene
# 1         Myrcene
# 2        Limonene
# 3        Camphene
# 4     beta-Pinene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1           Myrcene
# 2    alpha-Humulene
# 3     Terpinen-4-ol
# 4          Limonene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1           Myrcene
# 2    alpha-Humulene
# 3          Limonene
# 4       beta-Pinene
# Name: Chemical, dtype: object
# 0       alpha-Pinene
# 1        beta-Pinene
# 2           Camphene
# 3            Borneol
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0        Eugenol
# 1       Chavicol
# 2        Myrcene
# 3       Linalool
# 4    3-Octenol-1
# Name: Chemical, dtype: object
# 0     Eugenol
# 1    Chavicol
# 2     Myrcene
# 3    Linalool
# 4    Limonene
# Name: Chemical, dtype: object
# 0            Eugenol
# 1    Eugenyl acetate
# 2         Isoeugenol
# 3            Safrole
# 4           Chavicol
# Name: Chemical, dtype: object
# 0            Eugenol
# 1           Limonene
# 2     delta-3-Carene
# 3    Eugenyl acetate
# 4        para-Cymene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1            Terpinen-4-ol
# 2                 Linalool
# 3    (E)-Cinnamyl aldehyde
# 4          Benzyl benzoate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2                 Linalool
# 3       beta-Caryophyllene
# 4       alpha-Phellandrene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    beta-Caryophyllene
# 3    alpha-Phellandrene
# 4       Eugenyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    alpha-Phellandrene
# 3              Linalool
# 4       Eugenyl acetate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1                 Linalool
# 2         Cinnamyl acetate
# 3       beta-Caryophyllene
# 4    (E)-Cinnamyl aldehyde
# Name: Chemical, dtype: object
# 0             Eugenol
# 1     Benzyl benzoate
# 2     Eugenyl acetate
# 3            Linalool
# 4    Cinnamyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1              Linalool
# 2       Eugenyl acetate
# 3    beta-Caryophyllene
# 4    alpha-Phellandrene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2              Linalool
# 3    beta-Caryophyllene
# 4       Benzyl benzoate
# Name: Chemical, dtype: object
# 0             Eugenol
# 1            Linalool
# 2          Piperitone
# 3     Eugenyl acetate
# 4    Cinnamyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2     Cinnamyl aldehyde
# 3           1,8-Cineole
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2       beta-Caryophyllene
# 3                 Linalool
# 4              para-Cymene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2          Benzyl benzoate
# 3       beta-Caryophyllene
# 4                 Linalool
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    beta-Caryophyllene
# 3              Linalool
# 4     Cinnamyl aldehyde
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2              Linalool
# 3    beta-Caryophyllene
# 4      Cinnamyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4        Benzyl alcohol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0                Eugenol
# 1        Eugenyl acetate
# 2     beta-Caryophyllene
# 3    Caryophyllene oxide
# 4         Methyl eugenol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2    Caryophyllene oxide
# 3         alpha-Humulene
# 4        Eugenyl acetate
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4        Methyl eugenol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2         alpha-Humulene
# 3    Caryophyllene oxide
# 4          alpha-Copaene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4              Chavicol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4        Methyl eugenol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1      (Z)-beta-Ocimene
# 2         beta-Cubebene
# 3    beta-Caryophyllene
# 4         Terpinen-4-ol
# Name: Chemical, dtype: object
# 0             Eugenol
# 1    (Z)-beta-Ocimene
# 2     alpha-Muurolene
# 3    Isocaryophyllene
# 4      alpha-Cadinene
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2         delta-Cadinene
# 3        gamma-Muurolene
# 4    iso-gamma-Muurolene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2       Methyl chavicol
# 3    beta-Caryophyllene
# 4               Camphor
# Name: Chemical, dtype: object
# 0               Eugenol
# 1         beta-Selinene
# 2              Limonene
# 3    beta-Caryophyllene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1       (Z)-beta-Ocimene
# 2           Germacrene D
# 3     beta-Caryophyllene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0               Eugenol
# 1              Limonene
# 2    beta-Caryophyllene
# 3           1,8-Cineole
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1           1,8-Cineole
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2           1,8-Cineole
# 3        alpha-Humulene
# 4        gamma-Cadinene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1               Myrcene
# 2    beta-Caryophyllene
# 3        Methyl eugenol
# 4              Chavicol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2               Myrcene
# 3    beta-Caryophyllene
# 4       gamma-Terpinene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2              Limonene
# 3    beta-Caryophyllene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2               Myrcene
# 3    beta-Caryophyllene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3       alpha-Terpineol
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3        alpha-Selinene
# 4       alpha-Muurolene
# Name: Chemical, dtype: object
# 0            Eugenol
# 1        1,8-Cineole
# 2      Terpinen-4-ol
# 3    alpha-Terpineol
# 4     Methyl eugenol
# Name: Chemical, dtype: object
# 0            Eugenol
# 1        para-Cymene
# 2       alpha-Pinene
# 3    Eugenyl acetate
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0      Cuminaldehyde
# 1    gamma-Terpinene
# 2        para-Cymene
# 3      Cumin alcohol
# 4           Limonene
# Name: Chemical, dtype: object
# 0        para-Cymene
# 1    gamma-Terpinene
# 2       alpha-Pinene
# 3           Sabinene
# 4            Myrcene
# Name: Chemical, dtype: object
# 0            para-Cymene
# 1          beta-Eudesmol
# 2           alpha-Pinene
# 3            Spathulenol
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0              Cuminaldehyde
# 1                para-Cymene
# 2                beta-Pinene
# 3            gamma-Terpinene
# 4    p-Isopropylbenzoic acid
# Name: Chemical, dtype: object
# 0           gamma-Terpinene
# 1             Cuminaldehyde
# 2    p-Mentha-1,3-dien-7-al
# 3               beta-Pinene
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1               beta-Pinene
# 2           gamma-Terpinene
# 3    p-Mentha-1,3-dien-7-al
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1           gamma-Terpinene
# 2    p-Mentha-1,4-dien-7-al
# 3               beta-Pinene
# 4    p-Mentha-1,3-dien-7-al
# Name: Chemical, dtype: object
# 0           gamma-Terpinene
# 1             Cuminaldehyde
# 2               para-Cymene
# 3    p-Mentha-1,3-dien-7-al
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2               beta-Pinene
# 3           gamma-Terpinene
# 4    p-Mentha-1,3-dien-7-al
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2           gamma-Terpinene
# 3    p-Mentha-1,3-dien-7-al
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2           gamma-Terpinene
# 3               beta-Pinene
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2    p-Mentha-1,3-dien-7-al
# 3           gamma-Terpinene
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2           gamma-Terpinene
# 3    p-Mentha-1,3-dien-7-al
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1           gamma-Terpinene
# 2               beta-Pinene
# 3    p-Mentha-1,3-dien-7-al
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1           gamma-Terpinene
# 2               para-Cymene
# 3    p-Mentha-1,3-dien-7-al
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1         para-Cymene
# 2         beta-Pinene
# 3       Cuminaldehyde
# 4    Perilla aldehyde
# Name: Chemical, dtype: object
# 0                             para-Cymene
# 1                      alpha-Phellandrene
# 2                            alpha-Pinene
# 3    Sesquiterpene hydrocarbons (unknown)
# 4                          delta-3-Carene
# Name: Chemical, dtype: object
# 0            para-Cymene
# 1            Spathulenol
# 2               Cryptone
# 3    Caryophyllene oxide
# 4          Terpinen-4-ol
# Name: Chemical, dtype: object
# 0     alpha-Pinene
# 1      Spathulenol
# 2      para-Cymene
# 3         Cryptone
# 4    Terpinen-4-ol
# Name: Chemical, dtype: object
# 0    gamma-Terpinene
# 1       alpha-Pinene
# 2        para-Cymene
# 3      Terpinen-4-ol
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           para-Cymene
# 1          alpha-Pinene
# 2        Thymyl acetate
# 3    beta-Caryophyllene
# 4      (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0           para-Cymene
# 1        4-Selinenol-11
# 2    alpha-Phellandrene
# 3         Methyl thymol
# 4       beta-Bisabolene
# Name: Chemical, dtype: object
# 0       para-Cymene
# 1      alpha-Pinene
# 2       beta-Pinene
# 3    alpha-Humulene
# 4     alpha-Copaene
# Name: Chemical, dtype: object
# 0    Methyl N-methyl anthranilate
# 1                 gamma-Terpinene
# 2                        Limonene
# 3                     para-Cymene
# 4                Ethyl linolenate
# Name: Chemical, dtype: object
# 0    Methyl N-methyl anthranilate
# 1                 gamma-Terpinene
# 2                        Limonene
# 3                     para-Cymene
# 4                    alpha-Pinene
# Name: Chemical, dtype: object
# 0    gamma-Terpinene
# 1        para-Cymene
# 2           Linalool
# 3      Terpinen-4-ol
# 4        Citronellol
# Name: Chemical, dtype: object
# 0           Linalool
# 1    gamma-Terpinene
# 2     Benzyl acetate
# 3        para-Cymene
# 4     delta-3-Carene
# Name: Chemical, dtype: object
# 0      para-Cymene
# 1          Myrcene
# 2     alpha-Pinene
# 3    alpha-Thujene
# 4           Thymol
# Name: Chemical, dtype: object
# 0        para-Cymene
# 1             Thymol
# 2            Borneol
# 3    gamma-Terpinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0                     gamma-Terpinene
# 1                         para-Cymene
# 2                         beta-Pinene
# 3    Muurolene(s) (unknown structure)
# 4                        beta-Elemene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1       Methyl thymol
# 2            Sabinene
# 3         para-Cymene
# 4    (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1       Methyl thymol
# 2            Sabinene
# 3         para-Cymene
# 4    (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0             para-Cymene
# 1        (Z)-beta-Ocimene
# 2    Cinnamyl isovalerate
# 3         gamma-Terpinene
# 4        (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0     para-Cymene
# 1       Carvacrol
# 2         Borneol
# 3        Camphene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0     para-Cymene
# 1         Borneol
# 2         Camphor
# 3    alpha-Pinene
# 4        Camphene
# Name: Chemical, dtype: object
# 0            Carotol
# 1       alpha-Pinene
# 2    Geranyl acetate
# 3           Linalool
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0            Carotol
# 1       alpha-Pinene
# 2    Geranyl acetate
# 3        beta-Pinene
# 4           Sabinene
# Name: Chemical, dtype: object
# 0                Carotol
# 1               Sabinene
# 2        Geranyl acetate
# 3               Geraniol
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0         alpha-Humulene
# 1     beta-Caryophyllene
# 2                Myrcene
# 3     Methyl 4-decenoate
# 4    Geranyl isobutyrate
# Name: Chemical, dtype: object
# 0        alpha-Humulene
# 1               Myrcene
# 2    beta-Caryophyllene
# 3        gamma-Cadinene
# 4        delta-Cadinene
# Name: Chemical, dtype: object
# 0    Isopinocamphone
# 1       Pinocamphone
# 2       Germacrene D
# 3        beta-Pinene
# 4        Pinocarvone
# Name: Chemical, dtype: object
# 0    Isopinocamphone
# 1        Pinocarvone
# 2       Pinocamphone
# 3       Germacrene D
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0    Isopinocamphone
# 1       Pinocamphone
# 2        beta-Pinene
# 3             Elemol
# 4       Germacrene D
# Name: Chemical, dtype: object
# 0         alpha-Pinene
# 1              Camphor
# 2             Sabinene
# 3        Terpinen-4-ol
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1    beta-Caryophyllene
# 2              Limonene
# 3           beta-Pinene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Myrcene
# 1           1,8-Cineole
# 2               Camphor
# 3    beta-Caryophyllene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0         Camphor
# 1    alpha-Pinene
# 2     1,8-Cineole
# 3       Verbenone
# 4     para-Cymene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1           Camphor
# 2         Verbenone
# 3    Bornyl acetate
# 4          Camphene
# Name: Chemical, dtype: object
# 0                 Camphor
# 1                Sabinene
# 2             1,8-Cineole
# 3            alpha-Pinene
# 4    iso-Artemisia ketone
# Name: Chemical, dtype: object

# %% [markdown]
# The next code creates a heatmap for each CSV file, with each row in the heatmap corresponding to a plant and each column corresponding to a chemical. The color of each cell in the heatmap corresponds to the value in the CSV file for that plant and chemical. The heatmaps are then saved as PDF files.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from math import sqrt

base_dir = '/Users/mariiakokina/Documents/eo_database/'
cluster_dirs = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d)) and d.startswith('cluster_')]

sns.set_style("white")
cmap = sns.diverging_palette(220, 10, as_cmap=True)

for cluster_dir in tqdm(cluster_dirs, desc='Processing clusters'):
    cluster_number = cluster_dir.split('_')[-1]
    file_path = os.path.join(base_dir, cluster_dir, 'high_similarity_plants_compositions.csv')

    if os.path.isfile(file_path):
        df = pd.read_csv(file_path, index_col=0)

        if df.empty:
            continue

        top_5_chemicals = df.apply(lambda row: row.nlargest(5).index.tolist(), axis=1)
        top_5_chemicals = top_5_chemicals.apply(lambda x: pd.Index(x).drop_duplicates().tolist())
        df_top_5 = df[top_5_chemicals.explode()]
        df_top_5 *= 100

        df_transposed = df_top_5.T.drop_duplicates()

        # Sort by total abundance
        df_transposed['total_abundance'] = df_transposed.sum(axis=1)
        df_transposed.sort_values('total_abundance', ascending=False, inplace=True)
        df_transposed.drop('total_abundance', axis=1, inplace=True)

        if df_transposed.empty:
            continue

        # Dynamic sizing of the plot
        num_rows, num_cols = df_transposed.shape
        fig_width = min(max(num_cols // 2, 10), 50)  # Set a minimum width of 10 and maximum width of 50
        fig_height = min(max(num_rows // 2, 10), 50)  # Set a minimum height of 10 and maximum height of 50

        fig, ax = plt.subplots(figsize=(fig_width, fig_height))

        cell_width = fig_width / num_cols
        cell_height = fig_height / num_rows
        font_size = max(min(min(cell_width, cell_height) * 2.5, 20), 8)  # Adjust the multiplier to control the font size and set a range (8-20)

        sns.heatmap(df_transposed, cmap=cmap, annot=True, fmt=".1f", linewidths=.5,
                    cbar_kws={'label': 'Concentration (%)'},
                    vmin=0, vmax=100, ax=ax, annot_kws={"size": font_size})  # Use dynamic font size

        for t in ax.collections[0].axes.texts:  # iterate over the text elements of the heatmap
            if t.get_text() == '0.0':
                t.set_text('')  # remove the text for zero cells

        ax.set_title(f'Top 5 Abundant Chemicals in Plants with min. 80% Similarity within {cluster_dir}', fontsize=min(font_size+6, 24), pad=20)  # Use dynamic font size and set a maximum limit of 24
        ax.set_xlabel('Plants', fontsize=min(font_size+2, 22), labelpad=10)  # Use dynamic font size and set a maximum limit of 22
        ax.set_ylabel('Chemicals', fontsize=min(font_size+2, 22), labelpad=10)  # Use dynamic font size and set a maximum limit of 22
        ax.tick_params(labelsize=min(font_size, 20))  # Use dynamic font size and set a maximum limit of 20

        sns.despine()  # Remove the top and right spines from plot

        plt.xticks(rotation=90, fontsize=font_size)  # Use dynamic font size
        plt.yticks(rotation=0, fontsize=font_size)  # Use dynamic font size

        plt.tight_layout()

        save_path = os.path.join(base_dir, cluster_dir, f'heatmap_Top_5_Abundant_Chemicals_in_Plants_with_80_Similarity.pdf')
        plt.savefig(save_path, format="pdf", bbox_inches='tight')

        plt.close()

    else:
        print(f"The file {file_path} does not exist.")
# Out:
# Processing clusters: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 90/90 [02:27<00:00,  1.63s/it]
