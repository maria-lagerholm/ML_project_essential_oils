# %% [markdown]
# After extracting data from the essentialoils.org database, I have obtained four JSON files, each representing different segments of the dataset. The script bellow reads each JSON file in the ./initial_data/ directory, appends its data to a list, and then writes the combined data to combined_data.json.

# %%
import os
import json

# Directory path
directory = "./initial_data/"

# List to store the combined data
combined_data = []

# Iterate over the files in the directory
for file_name in os.listdir(directory):
    if file_name.endswith(".json"):
        # Construct the file path
        file_path = os.path.join(directory, file_name)

        # Read data from the JSON file
        with open(file_path, "r") as file:
            data = json.load(file)

        # Append the data to the combined list
        combined_data.extend(data)

# Write the combined data to a new JSON file in the specified directory
output_file = os.path.join(directory, "combined_data.json")
with open(output_file, "w") as file:
    json.dump(combined_data, file, indent=4)

print(f"Combined data has been written to {output_file}.")
# Out:
# Combined data has been written to ./partial_data/combined_data.json.

# %% [markdown]
# Below is the code that counts both the total number of plants and the number of unique plants, as well as to identify and print the names of plants that appear more than once in the combined_data.json file and removes those:

# %%
import json
from collections import OrderedDict

# Load the JSON file
with open("initial_data/combined_data.json", "r") as file:
    data = json.load(file)

# Create an ordered dictionary to store unique plants
unique_plants = OrderedDict()

# Iterate over the data
for item in data:
    # Get the plant name
    name = item.get("name")
    
    # If this plant name has not been added to unique_plants, add it
    if name not in unique_plants:
        unique_plants[name] = item

# Convert the values of unique_plants back to a list
unique_data = list(unique_plants.values())

# Save the unique data back to a JSON file
with open("initial_data/combined_data_unique.json", "w") as file:
    json.dump(unique_data, file, indent=4)

# Print results
print(f"Total number of plants: {len(data)}")
print(f"Number of unique plants: {len(unique_data)}")
# Out:
# Total number of plants: 4106
# Number of unique plants: 4100

# %% [markdown]
# The script bellow
# ### 1. **loads JSON file:**
#    - Opens and loads combined JSON file, appending its data to `data_list`.
# Then it
#    - Initializes a `defaultdict` named `chemicals_data`.
#    - Iterates over `data_list`, extracting and processing chemical data from each entry.
#    - Creates a unique column name for each chemical, avoiding duplicates, and stores the percentage average of each chemical, filling missing values with `0.0`.
#    - Saves the DataFrame to a CSV file at the specified output path.
#
# ### 2. **Print DataFrame:**
#    - Prints the sorted DataFrame to the console.
#
# ### 3. **Load Combined JSON Data & Count Plants:**
#    - Loads another JSON file named `combined_data.json` from the `initial_data` directory.
#    - Extracts and counts the number of unique plant names in the data.
#    - Prints the count of unique plants. Number of unique plants: 4100

# %%
import pandas as pd
import json
import os
from tqdm import tqdm
from collections import defaultdict

# Directory path where the JSON files are located
directory = "./initial_data/"

# List to store the JSON data
data_list = []

# Load the combined JSON data directly
with open(os.path.join(directory, "combined_data_unique.json"), "r") as file:
    data_list = json.load(file)


# Create a dictionary to store the chemical values
chemicals_data = defaultdict(dict)

# Iterate over the JSON data with progress logging
for entry in tqdm(data_list, desc="Processing data"):
    name = entry.get("name")
    name_botanical = entry.get("name_botanical")
    compounds = entry.get("compound")
    if compounds:
        for compound in compounds:
            chemical_name = compound.get("name")
            percentage_average = compound.get("pivot", {}).get("percentage_average")
            if chemical_name and name:
                # Append both name and name_botanical to the column name
                column_name = f"{name} - {name_botanical}"
                suffix = 1
                while column_name in chemicals_data[chemical_name]:
                    suffix += 1
                    column_name = f"{name} {suffix} - {name_botanical}"
                chemicals_data[chemical_name][column_name] = float(percentage_average) if percentage_average else 0.0

# Create a DataFrame from the chemicals_data dictionary
df = pd.DataFrame.from_dict(chemicals_data, orient="index")

# Sort the columns (plant species) alphabetically
df_sorted = df.reindex(sorted(df.columns), axis=1)

# Fill NaN values with 0
df_sorted.fillna(0, inplace=True)

# Save the DataFrame as a CSV file
output_path = "initial_data/chemicals_data.csv"
df_sorted.to_csv(output_path)

# Print the DataFrame
print(df_sorted)
# Out:
# Processing data: 100%|█████| 4100/4100 [00:00<00:00, 54996.71it/s]
#                          Abies alba conifer 1 - Abies alba Mill., fam. Pinaceae  \
# Limonene                                                            0.5474
# beta-Pinene                                                         0.0050
# alpha-Pinene                                                        0.0736
# Bornyl acetate                                                      0.0096
# Camphene                                                            0.1478
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Abies alba conifer 2 - Abies alba Mill., fam. Pinaceae  \
# Limonene                                                            0.3408
# beta-Pinene                                                         0.0299
# alpha-Pinene                                                        0.3166
# Bornyl acetate                                                      0.0129
# Camphene                                                            0.0576
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Abies alba from cones - Abies alba Mill., fam. Pinaceae  \
# Limonene                                                             0.285
# beta-Pinene                                                          0.225
# alpha-Pinene                                                         0.180
# Bornyl acetate                                                       0.125
# Camphene                                                             0.080
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Abies alba needle (Montenegro) - Abies alba Mill., fam. Pinaceae  \
# Limonene                                                             0.061
# beta-Pinene                                                          0.328
# alpha-Pinene                                                         0.173
# Bornyl acetate                                                       0.090
# Camphene                                                             0.167
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Abies alba needle (Serbia) - Abies alba Mill., fam. Pinaceae  \
# Limonene                                                             0.110
# beta-Pinene                                                          0.198
# alpha-Pinene                                                         0.109
# Bornyl acetate                                                       0.000
# Camphene                                                             0.153
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Abies borisii-regis needle (Greece) - Abies borisii-regis Mattf., fam. Pinaceae  \
# Limonene                                                             0.226
# beta-Pinene                                                          0.114
# alpha-Pinene                                                         0.082
# Bornyl acetate                                                       0.000
# Camphene                                                             0.102
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Abies cephalonica - Abies cephalonica Loud., fam. Pinaceae  \
# Limonene                                                             0.123
# beta-Pinene                                                          0.350
# alpha-Pinene                                                         0.200
# Bornyl acetate                                                       0.056
# Camphene                                                             0.091
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Abies cephalonica needle (Greece) - Abies cephalonica Loud., fam. Pinaceae  \
# Limonene                                                             0.142
# beta-Pinene                                                          0.213
# alpha-Pinene                                                         0.160
# Bornyl acetate                                                       0.000
# Camphene                                                             0.093
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Abies ernestii (China) - Abies ernestii Rehd., fam. Pinaceae  \
# Limonene                                                            0.0430
# beta-Pinene                                                         0.0404
# alpha-Pinene                                                        0.3876
# Bornyl acetate                                                      0.0996
# Camphene                                                            0.1235
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Abies faxoniana (China) - Abies faxoniana Rehd. et Wils., fam. Pinaceae  \
# Limonene                                                            0.4135
# beta-Pinene                                                         0.0248
# alpha-Pinene                                                        0.2231
# Bornyl acetate                                                      0.0013
# Camphene                                                            0.1787
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          ...  \
# Limonene                 ...
# beta-Pinene              ...
# alpha-Pinene             ...
# Bornyl acetate           ...
# Camphene                 ...
# ...                      ...
# 2-Butyl isothiocyanate   ...
# Ethyl hematommate        ...
# Ethyl chlorohematommate  ...
# Chloroatranorin          ...
# Atranorin                ...
#
#                          Zingiber zerumbet (Vietnam) 1 rhizome - Zingiber zerumbet (L.) Sm., fam. Zingiberaceae  \
# Limonene                                                            0.0040
# beta-Pinene                                                         0.0010
# alpha-Pinene                                                        0.0070
# Bornyl acetate                                                      0.0005
# Camphene                                                            0.0310
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Zingiber zerumbet (Vietnam) 2a stem - Zingiber zerumbet (L.) Sm., fam. Zingiberaceae  \
# Limonene                                                             0.001
# beta-Pinene                                                          0.054
# alpha-Pinene                                                         0.011
# Bornyl acetate                                                       0.000
# Camphene                                                             0.002
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Zingiber zerumbet (Vietnam) 2b leaf - Zingiber zerumbet (L.) Sm., fam. Zingiberaceae  \
# Limonene                                                            0.0030
# beta-Pinene                                                         0.0520
# alpha-Pinene                                                        0.0160
# Bornyl acetate                                                      0.0000
# Camphene                                                            0.0005
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Zingiber zerumbet (Vietnam) 2c flower - Zingiber zerumbet (L.) Sm., fam. Zingiberaceae  \
# Limonene                                                             0.004
# beta-Pinene                                                          0.004
# alpha-Pinene                                                         0.003
# Bornyl acetate                                                       0.000
# Camphene                                                             0.001
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Ziziphora clinopodioides (Turkey) 1 - Ziziphora clinopodioides Lam., fam. Lamiaceae (Labiatae)  \
# Limonene                                                             0.030
# beta-Pinene                                                          0.008
# alpha-Pinene                                                         0.006
# Bornyl acetate                                                       0.000
# Camphene                                                             0.002
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
#                          Ziziphora clinopodioides (Turkey) 2 - Ziziphora clinopodioides Lam., fam. Lamiaceae (Labiatae)  \
# Limonene                                                            0.0819
# beta-Pinene                                                         0.0540
# alpha-Pinene                                                        0.0184
# Bornyl acetate                                                      0.0000
# Camphene                                                            0.0046
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Ziziphora hispanica - Ziziphora hispanica L., fam. Lamiaceae (Labiatae)  \
# Limonene                                                            0.0200
# beta-Pinene                                                         0.0036
# alpha-Pinene                                                        0.0032
# Bornyl acetate                                                      0.0000
# Camphene                                                            0.0001
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Ziziphora tenuior (Turkey) - Ziziphora tenuior L.(Z.acutifolia Montbret & Aucher ex Bentham), Lamiaceae  \
# Limonene                                                            0.0492
# beta-Pinene                                                         0.0077
# alpha-Pinene                                                        0.0067
# Bornyl acetate                                                      0.0000
# Camphene                                                            0.0004
# ...                                                                    ...
# 2-Butyl isothiocyanate                                              0.0000
# Ethyl hematommate                                                   0.0000
# Ethyl chlorohematommate                                             0.0000
# Chloroatranorin                                                     0.0000
# Atranorin                                                           0.0000
#
#                          Zizyphus jujuba fruit (Malaysia) - Zizyphus jujuba Mill. var. inermis, fam. Rhamnaceae  \
# Limonene                                                               0.0
# beta-Pinene                                                            0.0
# alpha-Pinene                                                           0.0
# Bornyl acetate                                                         0.0
# Camphene                                                               0.0
# ...                                                                    ...
# 2-Butyl isothiocyanate                                                 0.0
# Ethyl hematommate                                                      0.0
# Ethyl chlorohematommate                                                0.0
# Chloroatranorin                                                        0.0
# Atranorin                                                              0.0
#
#                          Zosima absinthifolia fruit - Zosima absinthifolia (Vent.) Link, fam. Apiaceae (Umbelliferae)
# Limonene                                                             0.000
# beta-Pinene                                                          0.000
# alpha-Pinene                                                         0.002
# Bornyl acetate                                                       0.000
# Camphene                                                             0.000
# ...                                                                    ...
# 2-Butyl isothiocyanate                                               0.000
# Ethyl hematommate                                                    0.000
# Ethyl chlorohematommate                                              0.000
# Chloroatranorin                                                      0.000
# Atranorin                                                            0.000
#
# [4199 rows x 4099 columns]

# %% [markdown]
# ### Data cleaning
#
# This part will load the data, transpose, Replace non-numeric values with NaN, missing with 0, print the number of rows and columns, check for duplicates, print them if any, remove them and output chemicals_data_clean.csv.

# %%
import pandas as pd

# Load the data
df = pd.read_csv('./initial_data/chemicals_data.csv', index_col=0)

# Transpose the data so that plants are rows and chemicals are columns as entities (samples) 
#should be rows and the features should be columns.
df = df.transpose()

# Replace non-numeric values with NaN
df = df.apply(pd.to_numeric, errors='coerce')

# Fill in missing values with 0s
df = df.fillna(0)

# Check the number of plants and chemicals before removing duplicates
num_plants_original = df.shape[0]
num_chemicals_original = df.shape[1]
print("Number of plants before removing duplicates:", num_plants_original)
print("Number of chemicals before removing duplicates:", num_chemicals_original)

# Check and remove duplicate rows and columns
duplicated_rows = df.duplicated(keep=False)
duplicated_columns = df.T.duplicated(keep=False)

num_duplicates_rows = duplicated_rows.sum()
num_duplicates_columns = duplicated_columns.sum()

duplicate_rows = df[duplicated_rows]

# Print the names of duplicate rows
print("Names of duplicate rows:")
print(duplicate_rows.index.tolist())

df = df.loc[~duplicated_rows]
df = df.loc[:, ~duplicated_columns]

# Check the number of unique plants and chemicals left after removing duplicates
num_plants_cleaned = df.shape[0]
num_chemicals_cleaned = df.shape[1]
print("Number of unique plants (rows) left:", num_plants_cleaned)
print("Number of unique chemicals (columns) left:", num_chemicals_cleaned)

# Convert the index to strings for comparison
df.index = df.index.astype(str)

# Identify plants with values outside the range of 0 to 1
invalid_plants = df[(df < 0) | (df > 1)].dropna(how="all").index
print("Plants with values outside the range of 0 to 1:")
print(invalid_plants)

# Save cleaned data
df.to_csv('./initial_data/chemicals_data_clean.csv')

# Print the number of duplicates
print("Number of duplicate rows:", num_duplicates_rows)
print("Number of duplicate columns:", num_duplicates_columns)
# Out:
# Number of plants before removing duplicates: 4099
# Number of chemicals before removing duplicates: 4199
# Names of duplicate rows:
# ['Patchouli (Indonesia, Sumatra) 2 - Pogostemon cablin Benth. (P. patchouli Pellet), fam. Lamiaceae (Labiatae)', 'Patchouli (Indonesia, Sumatra) 3 - Pogostemon cablin Benth., fam. Lamiaceae (Labiatae)', 'Peppermint (Italy)  6b - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Peppermint (USA)  4 - Mentha piperita L. cultivar Kennewick, fam. Lamiaceae (Labiatae)', 'Peppermint (USA)  5 - Mentha piperita L. cultivar Michigan, fam. Lamiaceae (Labiatae)', 'Peppermint (USA)  6 - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Peppermint 4 - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Peppermint 5a - Mentha piperita L. cultivar Kennewick, fam. Lamiaceae (Labiatae)', 'Peppermint 5b - Mentha piperita L. cultivar Michigan, fam. Lamiaceae (Labiatae)', 'Peppermint headspace - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Sassafras (Brazil) 2 - Sassafras albidum (Nutt.) Nees, fam. Lauraceae', 'Sassafras 2 - Sassafras albidum (Nutt.) Nees, fam. Lauraceae']
# Number of unique plants (rows) left: 4087
# Number of unique chemicals (columns) left: 3624
# Plants with values outside the range of 0 to 1:
# Index([], dtype='object')
# Number of duplicate rows: 12
# Number of duplicate columns: 575

# %%
import pandas as pd

# Load the data
df = pd.read_csv('./initial_data/chemicals_data.csv', index_col=0)

# Transpose the data so that plants are rows and chemicals are columns as entities (samples) 
#should be rows and the features should be columns.
df = df.transpose()

# Replace non-numeric values with NaN
df = df.apply(pd.to_numeric, errors='coerce')

# Fill in missing values with 0s
df = df.fillna(0)

# Check the number of plants and chemicals before removing duplicates
num_plants_original = df.shape[0]
num_chemicals_original = df.shape[1]
print("Number of plants before removing duplicates:", num_plants_original)
print("Number of chemicals before removing duplicates:", num_chemicals_original)

# Check and remove duplicate rows and columns
duplicated_rows = df.duplicated(keep=False)
duplicated_columns = df.T.duplicated(keep=False)

num_duplicates_rows = duplicated_rows.sum()
num_duplicates_columns = duplicated_columns.sum()

duplicate_rows = df[duplicated_rows]

# Print the names of duplicate rows
print("Names of duplicate rows:")
print(duplicate_rows.index.tolist())

df = df.loc[~duplicated_rows]
df = df.loc[:, ~duplicated_columns]

# Check the number of unique plants and chemicals left after removing duplicates
num_plants_cleaned = df.shape[0]
num_chemicals_cleaned = df.shape[1]
print("Number of unique plants (rows) left:", num_plants_cleaned)
print("Number of unique chemicals (columns) left:", num_chemicals_cleaned)

# Convert the index to strings for comparison
df.index = df.index.astype(str)

# Identify plants with values outside the range of 0 to 1
invalid_plants = df[(df < 0) | (df > 1)].dropna(how="all").index
print("Plants with values outside the range of 0 to 1:")
print(invalid_plants)

# Save cleaned data
df.to_csv('./initial_data/chemicals_clean_data.csv')
# Out:
# Number of plants before removing duplicates: 4099
# Number of chemicals before removing duplicates: 4199
# Names of duplicate rows:
# ['Patchouli (Indonesia, Sumatra) 2 - Pogostemon cablin Benth. (P. patchouli Pellet), fam. Lamiaceae (Labiatae)', 'Patchouli (Indonesia, Sumatra) 3 - Pogostemon cablin Benth., fam. Lamiaceae (Labiatae)', 'Peppermint (Italy)  6b - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Peppermint (USA)  4 - Mentha piperita L. cultivar Kennewick, fam. Lamiaceae (Labiatae)', 'Peppermint (USA)  5 - Mentha piperita L. cultivar Michigan, fam. Lamiaceae (Labiatae)', 'Peppermint (USA)  6 - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Peppermint 4 - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Peppermint 5a - Mentha piperita L. cultivar Kennewick, fam. Lamiaceae (Labiatae)', 'Peppermint 5b - Mentha piperita L. cultivar Michigan, fam. Lamiaceae (Labiatae)', 'Peppermint headspace - Mentha piperita L., fam. Lamiaceae (Labiatae)', 'Sassafras (Brazil) 2 - Sassafras albidum (Nutt.) Nees, fam. Lauraceae', 'Sassafras 2 - Sassafras albidum (Nutt.) Nees, fam. Lauraceae']
# Number of unique plants (rows) left: 4087
# Number of unique chemicals (columns) left: 3624
# Plants with values outside the range of 0 to 1:
# Index([], dtype='object')
