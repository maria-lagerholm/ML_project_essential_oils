# %%
import pandas as pd

# Path to CSV file
csv_file_path = 'Salmonella.csv'  
sorted_csv_file_path = 'Salmonella.csv'  # Path for the sorted CSV file

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Checking for duplicates based on 'Plant_Species'
duplicate_count = df.duplicated(subset='Plant_Species').sum()
print(f"Number of duplicate entries based on 'Plant_Species': {duplicate_count}")

# Removing duplicates
df = df.drop_duplicates(subset='Plant_Species')

# Sorting the DataFrame
sorted_df = df.sort_values(by='Plant_Species', ascending=True)

# Save the sorted DataFrame to a new CSV file
sorted_df.to_csv(sorted_csv_file_path, index=False)
print(f"CSV file has been sorted and saved to {sorted_csv_file_path}")

# Count unique plants
unique_plants_count = sorted_df['Plant_Species'].nunique()
print(f"Number of unique plants: {unique_plants_count}")

# Replace 'Salmonella Typhimurium' with the actual column name in your CSV if different
active_column = 'Salmonella Typhimurium'  # Column indicating activity against Salmonella Typhimurium

# Count the number of plants active and not active against Salmonella Typhimurium
active_plants_count = sorted_df[sorted_df[active_column] == 1]['Plant_Species'].nunique()
non_active_plants_count = sorted_df[sorted_df[active_column] == 0]['Plant_Species'].nunique()
print(f"Number of plants active against Salmonella Typhimurium: {active_plants_count}")
print(f"Number of plants not active against Salmonella Typhimurium: {non_active_plants_count}")

# Calculate the percentage of active and non-active plants
percent_active = (active_plants_count / unique_plants_count) * 100
percent_non_active = (non_active_plants_count / unique_plants_count) * 100

print(f"Percentage of plants active against Salmonella Typhimurium: {percent_active:.2f}%")
print(f"Percentage of plants not active against Salmonella Typhimurium: {percent_non_active:.2f}%")
# Out:
# Number of duplicate entries based on 'Plant_Species': 0
# CSV file has been sorted and saved to Salmonella.csv
# Number of unique plants: 177
# Number of plants active against Salmonella Typhimurium: 89
# Number of plants not active against Salmonella Typhimurium: 88
# Percentage of plants active against Salmonella Typhimurium: 50.28%
# Percentage of plants not active against Salmonella Typhimurium: 49.72%

# %%
import pandas as pd
import unicodedata
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Normalize text function
def normalize_text(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii')
    return text.lower().strip()

# Function to capitalize the first word of a string
def capitalize_first_word(text):
    parts = text.split()
    if parts:
        parts[0] = parts[0].capitalize()
    return ' '.join(parts)

# Load and process Sorted_Salmonella.csv
sorted_plants_path = 'Salmonella.csv'
# Load only the first column, assuming it's the 'Plant_Species' column
sorted_df = pd.read_csv(sorted_plants_path, usecols=[0])
sorted_df['Plant_Species'] = sorted_df['Plant_Species'].apply(normalize_text).apply(capitalize_first_word)

# Load and process chemicals_data_clean_unique.csv
chemicals_path = '/Users/mariiakokina/Documents/eo_database/initial_data/chemicals_data_clean_unique.csv'  
chemicals_df = pd.read_csv(chemicals_path)
chemicals_df['Plant_Species'] = chemicals_df['Plant_Species'].apply(normalize_text)

# Function to find the best match with a fuzzy match score and track unmatched plants
def best_match(plant, species_list):
    match_data = process.extractOne(plant, species_list, scorer=fuzz.partial_ratio)
    if match_data:
        best_match, score, _ = match_data
        if score >= 90:
            print(f"Match found: {plant} -> {best_match} with score {score}")
            return best_match
        else:
            print(f"No adequate match found for: {plant}")
            return None
    return None

# Initialize data structures for matched and unmatched plants
matched_plants = pd.DataFrame()
unmatched_plants = []  # List to keep track of unmatched plants

# Iterate through sorted plants to find matches in chemicals DataFrame
for plant in sorted_df['Plant_Species']:
    match = best_match(plant, chemicals_df['Plant_Species'])
    if match:
        # Find the row in chemicals_df that matches
        matched_plant_data = chemicals_df[chemicals_df['Plant_Species'] == match].copy()
        matched_plant_data.loc[:, 'Plant_Species'] = plant  # Set the plant species name
        matched_plants = pd.concat([matched_plants, matched_plant_data])
    else:
        unmatched_plants.append(plant)  # Add to unmatched plants list

# Save the matched DataFrame to a new CSV file
output_file_path = 'matched_plants_data.csv'
matched_plants.to_csv(output_file_path, index=False, sep=',')

# Print out the counts of plants and the list of unmatched plants
original_plants_count = sorted_df.shape[0]
matched_plants_count = matched_plants.shape[0]
print(f"Number of plants in original file: {original_plants_count}")
print(f"Number of plants in matched file: {matched_plants_count}")
print("Unmatched plant species:", unmatched_plants)
# Out:
# Match found: Abies balsamea -> fir balsam 1 - abies balsamea (l.) mill., fam. pinaceae with score 100
# Match found: Abies borisii-regis -> abies borisii-regis needle (greece) - abies borisii-regis mattf., fam. pinaceae with score 100
# Match found: Abies nordmannia -> abies nordmannia conifer - abies nordmannia (steven) spach, fam. pinaceae with score 100
# Match found: Abies semenovii -> abies semenovii - abies semenovii l., fam. pinaceae with score 100
# Match found: Achillea ligustica -> achillea ligustica flower (greece) - achillea ligustica all., fam. asteraceae (compositae) with score 100
# Match found: Achillea millefolium -> yarrow (canada) 1 - achillea millefolium l., fam. asteraceae (compositae) with score 100
# Match found: Aegle marmelos -> aegle marmelos leaf (india) 1 - aegle marmelos (l.) correa, fam. rutaceae with score 100
# Match found: Aeollanthus suaveolens -> aeollanthus suaveolens 1a flowering - aeollanthus suaveolens mart. ex spreng., fam. lamiaceae (labiatae) with score 100
# Match found: Agathosma betulina -> buchu leaf (south africa) 1a - agathosma betulina (berg.) pillans (barosma betulina bertl.), fam. rutacea with score 100
# Match found: Agathosma rosmarinifolia -> agathosma rosmarinifolia - agathosma rosmarinifolia (bartl.) williams, fam. diosmea (rutaceae) with score 100
# Match found: Allium cepa -> onion (shallot) - allium cepa l., aggregatum g., fam. liliaceae with score 100
# Match found: Allium sativum -> garlic (china) - allium sativum l., fam. liliaceae with score 100
# Match found: Allium tuberosum -> nira (brazil) - allium tuberosum rottl., fam. liliaceae with score 100
# Match found: Aloysia triphylla -> lemon verbena (morocco) 1 - aloysia triphylla (l'herit.) britton (lippia citriodora (lam.) o. kuntze) with score 100
# Match found: Alpinia katsumadai -> alpinia katsumadai leaf (vietnam) - alpinia katsumadai hayata l., fam. zingiberaceae with score 100
# Match found: Amorpha fruticosa -> amorpha fruticosa flower - amorpha fruticosa l., fam. papilionaceae with score 100
# Match found: Anethum graveolens -> dill herb (cuba) - anethum graveolens l., fam. apiaceae (umbelliferae) with score 100
# Match found: Angelica archangelica -> angelica (norvegica) lateral root - angelica archangelica l. var. norvegica, fam. apiaceae (umbelliferae) with score 100
# Match found: Anthoxanthum odoratum -> anthoxanthum odoratum (italy) 1a fresh leaf - anthoxanthum odoratum l., fam. poaceae (gramineae) with score 100
# Match found: Armoracia lapathifolia -> horseradish - armoracia lapathifolia gilib., fam. brassicaceae (cruciferae) with score 100
# Match found: Artemisia alba -> artemisia alba (belgium) - artemisia alba turra, fam. asteraceae (compositae) with score 100
# Match found: Artemisia chamaemelifolia -> artemisia chamaemelifolia (italy) - artemisia chamaemelifolia vill., fam. asteraceae (compositae) with score 100
# Match found: Artemisia scoparia -> artemisia scoparia (india) 1 - artemisia scoparia waldst. & kit., fam. asteraceae (compositae) with score 100
# Match found: Astronium urundeuva -> astronium urundeuva (brazil) - astronium urundeuva (allemao) engl., fam. anacardiaceae with score 100
# Match found: Atractylodes lancea -> atractylis - atractylodes lancea (thunb.) dc. (a. ovata thunb.; a. chinensis (bunge)dc) with score 100
# Match found: Averrhoa bilimbi -> averrhoa bilimbi fruit (malaysia) - averrhoa bilimbi l., fam. oxalidaceae with score 100
# Match found: Brassica juncea -> mustard seed (china) 1 - brassica juncea (l.) czern. et coss., fam. brassicaceae (crucifereae) with score 100
# Match found: Brassica oleraceae -> kohlrabi, green (seed) - brassica oleraceae var. gongylodes, fam. brassicaceae (cruciferae) with score 100
# Match found: Bupleurum linearifolium -> bupleurum linearifolium - bupleurum linearifolium dc., fam. apiaceae (umbelliferae) with score 100
# Match found: Bursera delpechiana -> linaloe wood - bursera delpechiana poiss., fam. burseraceae with score 100
# Match found: Calyptranthes sintenisii -> calyptranthes sintenisii leaf - calyptranthes sintenisii kiaersk, fam. myrtaceae with score 100
# Match found: Cananga odorata -> ylang ylang (china) 1 - cananga odorata (lamk.) hook. f. et thomson forma genuina, fam. annonaceae with score 100
# Match found: Carum carvi -> caraway herb (mongolia) - carum carvi l., fam. apiaceae (umbelliferae) with score 100
# Match found: Catharanthus roseus -> catharanthus roseus leaf - catharanthus roseus (l.) g. don, fam. apocynaceae with score 100
# Match found: Chaerophyllum macrospermum -> chaerophyllum macrospermum (iran) - chaerophyllum macrospermum (spreng.) fisch. et c.a. mey, fam. apiaceae with score 100
# Match found: Cichorium intybus -> chicory root, roasted 1a - cichorium intybus l., fam. asteraceae (compositae) with score 100
# Match found: Cinnamomum angustifolium -> cinnamomum angustifolium leaf (madagascar) - cinnamomum angustifolium rafin, fam. lauraceae with score 100
# Match found: Cinnamomum camphora -> camphor (china) - cinnamomum camphora (l.) nees et ebermaier, fam. lauraceae with score 100
# Match found: Cinnamomum cassia -> cassia, bark (australia) - cinnamomum cassia blume, fam. lauraceae with score 100
# Match found: Cinnamomum zeylanicum -> cinnamon bark (brazil) - cinnamomum zeylanicum blume (c. verum l. presl), fam. lauraceae with score 100
# Match found: Citrus aurantifolia -> lime (japan) leaf - citrus aurantifolia (christm.) swingle, fam. rutaceae with score 100
# Match found: Citrus aurantium -> bitter orange flower absolute 1 - citrus aurantium l., ssp. amara engl., fam. rutaceae with score 100
# Match found: Citrus bergamia -> bergamot (argentina) 1 - citrus bergamia risso et poiteau, fam. rutaceae with score 100
# Match found: Citrus japonica -> citrus japonica peel (vietnam) - citrus japonica l., fam. rutaceae with score 100
# Match found: Citrus maxima -> pummelo (shaddock) (india) peel - citrus maxima (j. burman) merrill. (c. grandis (l.) osbeck), fam. rutaceae with score 100
# Match found: Citrus medica -> citron (china) leaves - citrus medica l., fam rutaceae with score 100
# Match found: Citrus paradisi -> grapefruit (argentina) - citrus paradisi macfayden, fam. rutaceae with score 100
# Match found: Citrus reticulata -> mandarin leaf (petitgrain mandarin.) (china) - citrus reticulata blanco, fam. rutaceae with score 100
# Match found: Citrus sinensis -> citrus cybrid leaf (italy) - citrus sinensis (l.) osbeck x c. limon (l.) burm. f., fam. rutaceae with score 100
# Match found: Coleus aromaticus -> coleus aromaticus (india) 1 - coleus aromaticus benth. (wild oregano), fam. lamiaceae (labiatae) with score 100
# Match found: Coriandrum sativum -> cilantro (coriander leaf) 1 - coriandrum sativum l., fam. apiaceae (umbelliferae) with score 100
# Match found: Coridothymus capitatus -> oregano, spanish (greece) 1 - coridothymus capitatus rchb. (thymus capitatus hoffm. et link.), lamiaceae with score 100
# Match found: Corydothymus capitatus -> oregano, spanish (greece) 1 - coridothymus capitatus rchb. (thymus capitatus hoffm. et link.), lamiaceae with score 95
# Match found: Croton zambesicus -> croton zambesicus (cameroon) 1a leaf - croton zambesicus muell. arg., fam. euphorbiaceae with score 100
# Match found: Cuminum cyminum -> cumin (china) - cuminum cyminum l., fam. apiaceae (umbelliferae) with score 100
# Match found: Cupressocyparis leylandii -> cypress, leyland (poland) - cupressocyparis leylandii (dall. et jacks.) dall., fam. cupressaceae with score 100
# Match found: Curcuma longa -> turmeric (bhutan) 1a rhizome - curcuma longa l. (c. domestica val.), fam. zingiberaceae with score 100
# Match found: Cymbopogon citratus -> lemongrass (argentine) - cymbopogon citratus (dc) stapf (c. flexuosus), fam. poaceae (gramineae) with score 100
# Match found: Cymbopogon distans -> cymbopogon distans 1 (himalaya) - cymbopogon distans (steud.) wats. (chemotype 1), fam. poaceae (gramineae) with score 100
# Match found: Cymbopogon martini -> gingergrass (india) 1 - cymbopogon martini stapf., var. sofia, fam. poaceae (gramineae) with score 100
# Match found: Cymbopogon nardus -> citronella ceylon (china) - cymbopogon nardus (l.) rendle, fam. poaceae (gramineae) with score 100
# Match found: Cymbopogon winterianus -> citronella java (argentina) 1 - cymbopogon winterianus jowitt., fam. poaceae (gramineae) with score 100
# Match found: Daucus carota -> carrot leaf (india) - daucus carota l. var. sativa, fam. apiaceae (umbelliferae) with score 100
# Match found: Dracocephalum moldavica -> dragonhead - dracocephalum moldavica l., fam. lamiaceae (labiatae) with score 100
# Match found: Elaeagnus angustifolia -> elaeagnus angustifolia flower absolute (china) - elaeagnus angustifolia l., fam. elaeagnaceae with score 100
# Match found: Elletaria cardamomum -> cardamom (costa rica) - elettaria cardamomum (l.) maton, fam. zingiberaceae with score 95
# Match found: Elsholtzia blanda -> elsholtzia blanda (china) - elsholtzia blanda benth., fam. lamiaceae (labiatae) with score 100
# Match found: Eruca sativa -> rocket leaf 1 - eruca sativa l., fam. brassicaceae with score 100
# Match found: Eucalyptus camaldulensis -> eucalyptus camaldulensis (algeria) - eucalyptus camaldulensis dehn., fam. myrtaceae with score 100
# Match found: Eucalyptus globulus -> eucalyptus globulus (algeria) 1 - eucalyptus globulus labill., fam. myrtaceae with score 100
# Match found: Eugenia caryophyllus -> clove bud (india) - eugenia caryophyllus (spreng.) bullock & harrison (e.caryophyllata thunb.) with score 100
# Match found: Ferula galbaniflua -> galbanum 1 - ferula galbaniflua boiss. et buhse, fam. apiaceae (umbelliferae) with score 100
# Match found: Fissitigma shangtzeense -> fissitigma shangtzeense, flower extract - fissitigma shangtzeense tsiang et p.t. li, fam. annonaceae with score 100
# Match found: Foeniculum vulgare -> fennel, bitter (china) 1 - foeniculum vulgare miller, var. vulgare dc, fam. apiaceae (umbelliferae) with score 100
# Match found: Gardenia jasminoides -> jasmine rose absolute (india) - gardenia jasminoides ellis, fam. rubiaceae with score 100
# Match found: Guerea macrophylla -> guarea macrophylla ssp. tuberculata leaf - guarea macrophylla vahl. ssp. tuberculata vellozo, fam. meliaceae with score 94
# Match found: Helichrysum amorginum -> helichrysum amorginum (greece) - helichrysum amorginum boiss. et orph. in boiss., fam. asteraceae (compos.) with score 100
# Match found: Hibiscus abelmoschus -> ambrette seed (china) - hibiscus abelmoschus l. (abelmoschus moschatus moench), fam. malvaceae with score 100
# Match found: Homalomena aromatica -> homalomena aromatica rhizome (india) - homalomena aromatica schott. (calla aromatica), fam. araceae with score 100
# Match found: Illicium verum -> star anise (china) 1 - illicium verum hooker fil., fam. magnoliaceae (illiciaceae) with score 100
# Match found: Iris florentina -> orris butter - iris florentina l., fam. iridaceae with score 100
# Match found: Jasminum azoricum -> jasmine azoricum concrete - jasminum azoricum l., fam. oleaceae with score 100
# Match found: Jasminum sambac -> jasmine sambac (china) concrete - jasminum sambac (l.) aiton, fam. oleaceae with score 100
# Match found: Kaempferia galanga -> kaempferia galanga rhizome (china) - kaempferia galanga l. (alpinia sessilis kon.), fam. zingiberaceae with score 100
# Match found: Larix decidua -> larix conifer bark - larix decidua mill., fam. pinaceae with score 100
# Match found: Laurus nobilis -> laurel flower (france) - laurus nobilis l., fam. lauraceae with score 100
# Match found: Lavandula angustifolia -> lavender (algeria) - lavandula angustifolia mill. (l. officinalis chaix), fam. lamiaceae with score 100
# Match found: Lavandula latifolia -> spike lavender (argentina) - lavandula latifolia medikus (l. spica d.c.), fam. lamiaceae (labiatae) with score 100
# Match found: Lavandula x hybrida -> lavandin (argentina) abrialis - lavandula x hybrida rev. (l. x intermedia emeric ex loiseleur), lamiaceae with score 100
# Match found: Lawsonia inermis -> lawsonia inermis flower 1a - lawsonia inermis l. (syn. l. alba lam.), fam. lythraceae with score 100
# Match found: Lepechinia urbanii -> lepechinia urbanii - lepechinia urbanii (briq.) epling, fam. lamiaceae (labiatae) with score 100
# Match found: Levisticum officinale -> lovage headspace - levisticum officinale koch, fam. apiaceae (umbelliferae) with score 100
# Match found: Lippia alba -> lippia alba (brazil) 1 - lippia alba (mill.) n.e. brown (cidreira), fam. verbenaceae with score 100
# Match found: Lippia citriodora -> lemon verbena (morocco) 1 - aloysia triphylla (l'herit.) britton (lippia citriodora (lam.) o. kuntze) with score 100
# Match found: Lippia graveolens -> oregano, mexican (cuba) - lippia graveolens hbk., fam. verbenaceae with score 100
# Match found: Lithraea ternifolia -> lithraea ternifolia fruit - lithraea ternifolia (gillies) barkley, fam. anacardiaceae with score 100
# Match found: Litsea cubeba -> litsea cubeba (china) 2a flower - litsea cubeba (lour.) pers. (l. citrata blume), fam. lauraceae with score 100
# Match found: Litsea zeylanica -> litsea zeylanica - litsea zeylanica nees, fam. lauraceae with score 100
# Match found: Lonicera japonica -> honeysuckle, japanese - lonicera japonica l., fam. caprifoliaceae with score 100
# Match found: Majorana hortensis -> marjoram, sweet (cuba) - majorana hortensis moench, origanum majorana l., fam. lamiaceae (labiatae) with score 100
# Match found: Mangifera indica -> mango (cameroon) headspace of ripe fruit - mangifera indica l., fam. anacardiaceae with score 100
# Match found: Melaleuca alternifolia -> tea tree (australia)  1 - melaleuca alternifolia (maiden et betche) cheel, fam. myrtaceae with score 100
# Match found: Melicocca bijuga -> geneps fruit (cuba) - melicocca bijuga l., fam. sapindaceae with score 100
# Match found: Mentha arvensis -> cornmint (mentha arvensis) (brazil) 1 - mentha arvensis (l.) var. piperascens malinv., fam. lamiaceae (labiatae) with score 100
# Match found: Mentha citrata -> mentha citrata (bergamot mint) (argentina) 1 - mentha citrata ehrh., fam. lamiaceae (labiatae) with score 100
# Match found: Mentha piperita -> peppermint (argentina) - mentha piperita l., fam. lamiaceae (labiatae) with score 100
# Match found: Mentha spicata -> eromenthe (usa) 1 - mentha spicata l., var. eromenthe, fam. lamiaceae (labiatae) with score 100
# Match found: Mentha viridis -> mentha viridis (italy) - mentha viridis (l.) lavanduliodora sacco, fam lamiaceae (labiatae) with score 100
# Match found: Mimusops elengi -> mimusops elengi flower headspace - mimusops elengi l., fam. sapotaceae with score 100
# Match found: Monarda didyma -> monarda didyma flower (france) - monarda didyma l., fam. lamiaceae (labiatae) with score 100
# Match found: Monarda fistulosa -> monarda fistulosa, var. menthaefolia 1 - monarda fistulosa l. var. menthaefolia, fam. lamiaceae (labiatae) with score 100
# Match found: Narcissus jonquilla -> jonquil (france) flower headspace - narcissus jonquilla l., fam. amaryllidaceae with score 100
# Match found: Nelumbo nucifera -> lotus flower - nelumbo nucifera l., fam. nelumbonaceae with score 100
# Match found: Neolitsea australiensis -> neolitsea australiensis leaf (australia) - neolitsea australiensis kosterm., fam. lauraceae with score 100
# Match found: Neolitsea brassii -> neolitsea brassii leaf (australia) - neolitsea brassii allen, fam. lauraceae with score 100
# Match found: Nigella sativa -> nigella sativa seed - nigella sativa l., fam. ranunculaceae with score 100
# Match found: Ocimum basilicum -> basil (argentina) 1a castelar - ocimum basilicum l. cultivar castelar, fam. lamiaceae (labiatae) with score 100
# Match found: Ocimum gratissimum -> ocimum gratissimum (aruba) - ocimum gratissimum l., fam. lamiaceae (labiatae) with score 100
# Match found: Oliveria decumbens -> oliveria decumbens (iran) - oliveria decumbens vent., fam. apiaceae (umbelliferae) with score 100
# Match found: Origanum glandulosum -> origanum glandulosum (algeria) - origanum glandulosum desf., fam. lamiaceae (labiatae) with score 100
# Match found: Origanum onites -> oregano, turkish (greece) - origanum onites l., fam. lamiaceae (labiatae) with score 100
# Match found: Origanum syriacum -> origanum syriacum (lebanon) - origanum syriacum l., fam. lamiaceae (labiatae) with score 100
# Match found: Origanum vulgare -> oregano, greek (chile) - origanum vulgare l., fam. lamiaceae (labiatae) with score 100
# Match found: Osmanthus fragrans -> osmanthus absolute - osmanthus fragrans (thunb.) lour., fam. oleaceae with score 100
# Match found: Pectis elongata -> pectis elongata - pectis elongata kunth, fam. asteraceae (compositae) with score 100
# Match found: Pelargonium citronellum -> pelargonium citronellum - pelargonium citronellum j.j.a. v.d. walt, fam. geraniaceae with score 100
# Match found: Pelargonium sidoides -> pelargonium sidoides - pelargonium sidoides dc., fam. geraniaceae with score 100
# Match found: Perilla acuta -> perilla acuta - perilla acuta (thunb.) nakai & p. acuta nakai forma viridis (makino) nakai with score 100
# Match found: Perilla frutescens -> perilla frutescens (china) 1 - perilla frutescens (l.) brit., fam. lamiaceae (labiatae) with score 100
# Match found: Petroselinum crispum -> parsley 1a herb - petroselinum crispum (miller) a.w. hill (p. sativum hoffm.), fam. apiaceae with score 100
# Match found: Peucedanum petiolare -> peucedanum petiolare (iran) - peucedanum petiolare (dc) boiss., fam. apiaceae (umbelliferae) with score 100
# Match found: Peucedanum zenkeri -> peucedanum zenkeri (cameroon) 1a - peucedanum zenkeri engl., fam. apiaceae (umbelliferae) with score 100
# Match found: Picea engelmanni -> picea engelmanni conifer - picea engelmanni (parry) engelm., fam. pinaceae with score 100
# Match found: Pimenta dioica -> pimento (allspice) (cuba) 1 (berry) - pimenta dioica (l.) merr. (p. officinalis lindl.), fam. myrtaceae with score 100
# Match found: Pimenta racemosa -> bay, west indian (benin) - pimenta racemosa var. racemosa (p. miller) j.w. moore, fam. myrtaceae with score 100
# Match found: Pimpinella saxifraga -> pimpinella saxifraga root - pimpinella saxifraga l., fam. apiaceae (umbelliferae) with score 100
# Match found: Pinus halepensis -> pinus halepensis (greece) - pinus halepensis miller, fam. pinaceae with score 100
# Match found: Pinus mugo -> pinus mugo (dwarf pine) 1 - pinus mugo turra ssp. pumilio (haenke) zenari (p.montana miller), pinaceae with score 100
# Match found: Pinus nigra -> pinus nigra - pinus nigra arnold (austrian pine), fam. pinaceae with score 100
# Match found: Pinus pinaster -> pinus pinaster (france) - pinus pinaster ait., fam. pinaceae with score 100
# Match found: Pinus sibirica -> pinus sibirica (mongolia) 1a - pinus sibirica (rupr.) mayr (siberian pine), fam. pinaceae with score 100
# Match found: Pinus sylvestris -> pinus sylvestris (estonia) - pinus sylvestris l. (scotch pine), fam. pinaceae with score 100
# Match found: Piper betle -> betel leaf bangla (india) - piper betle l. var. bangla, fam. piperaceae with score 100
# Match found: Piper nigrum -> pepper, black (china) 1 fruit - piper nigrum l., fam. piperaceae with score 100
# Match found: Platonia insignis -> bacuri fruit (brazil) - platonia insignis m., fam. guttiferae with score 100
# Match found: Psidium guajava -> guava fruit (cuba) - psidium guajava l., fam. myrtaceae with score 100
# Match found: Rheum palmatum -> rhubarb root - rheum palmatum l., fam. polygonaceae with score 100
# Match found: Rosa damascena -> rose (bulgaria) 1 - rosa damascena mill., fam. rosaceae with score 100
# Match found: Rosa rugosa -> rosa rugosa (china) 1 - rosa rugosa thunb. (hybrids), fam. rosaceae with score 100
# Match found: Rosmarinus officinalis -> rosemary (algeria) 1 - rosmarinus officinalis l., fam. lamiaceae (labiatae) with score 100
# Match found: Salvia lavandulaefolia -> sage, spanish (hungary) - salvia lavandulaefolia vahl., fam. lamiaceae (labiatae) with score 100
# Match found: Salvia officinalis -> sage, dalmatian (albany) 1 - salvia officinalis l., fam. lamiaceae (labiatae) with score 100
# Match found: Salvia sclarea -> clary sage (france) 1 - salvia sclarea l., fam. lamiaceae (labiatae) with score 100
# Match found: Satureja hortensis -> savory, summer (finland) - satureja hortensis l., fam. lamiaceae (labiatae) with score 100
# Match found: Satureja montana -> savory, winter (bulgaria) - satureja montana l. ssp. kitaibelii wierzb., fam. lamiaceae (labiatae) with score 100
# Match found: Satureja thymbra -> satureja thymbra (israel) 1 - satureja thymbra l., fam. lamiaceae (labiatae) with score 100
# Match found: Saturiea hortensis -> savory, summer (finland) - satureja hortensis l., fam. lamiaceae (labiatae) with score 94
# Match found: Spartium junceum -> genet absolute 1 - spartium junceum l., fam. leguminosae (papilionaceae) with score 100
# Match found: Tagetes lucida -> tagetes lucida (hungary) - tagetes lucida l., fam. asteraceae (compositae) with score 100
# Match found: Tamarindus indica -> tamarind 1 dried fruit - tamarindus indica l., fam. leguminosae with score 100
# Match found: Terminalia bentzoe -> terminalia bentzoe - terminalia bentzoe (l.) l.f.ssp.rodriguesensis wickens, fam. combretaceae with score 100
# Match found: Thymus mastichina -> marjoram, spanish (portugal) 1 - thymus mastichina l., fam. lamiaceae (labiatae) with score 100
# Match found: Thymus mongolicus -> thymus mongolicus (china) 1 - thymus mongolicus ronn., fam. lamiaceae (labiatae) with score 100
# Match found: Thymus quinquecostatus -> thymus quinquecostatus 1 - thymus quinquecostatus celak var. asiaticus, fam. lamiaceae (labiatae) with score 100
# Match found: Thymus riatarum -> thymus riatarum - thymus riatarum humbert et maire, fam. lamiaceae (labiatae) with score 100
# Match found: Thymus richardii -> thymus richardii - thymus richardii pers. ssp. nitidus (guss.) jalas, fam. lamiaceae (labiat) with score 100
# Match found: Thymus satureoides -> thymus satureoides (morocco) - thymus satureoides boiss. et reut., fam. lamiaceae (labiatae) with score 100
# Match found: Thymus serpyllum -> thymus serpyllum (canada) - thymus serpyllum l., fam. lamiaceae (labiatae) with score 100
# Match found: Thymus vulgaris -> thyme (cameroon) - thymus vulgaris l., fam. lamiaceae (labiatae) with score 100
# Match found: Thymus zygis -> thyme red (italy) - thymus zygis l., fam. lamiaceae (labiatae) with score 100
# Match found: Trifolium pratense -> clover, red flower (austria) - trifolium pratense l., fam. leguminosae (papilionaceae) with score 100
# Match found: Trifolium repens -> clover, white flower (austria) - trifolium repens l., fam liguminosae (papilionaceae) with score 100
# Match found: Valeriana officinalis -> valerian, flower - valeriana officinalis l., fam. valerianaceae with score 100
# Match found: Viburnum orientale -> viburnum orientale leaf - viburnum orientale pallas, fam. caprifoliaceae with score 100
# Match found: Vitis vinifera -> grape flower - vitis vinifera l., ssp. gruener veltliner, fam. vitaceae with score 100
# Match found: Zanthoxylum armatum -> wartara (india) 1 pericarp - zanthoxylum armatum dc. (z. alatum roxb.), fam. rutaceae with score 100
# Match found: Zataria multiflora -> zataria multiflora (iran) 1a bud - zataria multiflora boiss., fam. lamiaceae (labiatae) with score 100
# Number of plants in original file: 177
# Number of plants in matched file: 177
# Unmatched plant species: []

# %%
import pandas as pd

# Define the path to your CSV file
csv_file_path = 'matched_plants_data.csv'

# Read the CSV file, assuming the first row is headers
df = pd.read_csv(csv_file_path)

# Convert columns to numeric (excluding 'Plant_Species' column, assuming it contains labels)
for column in df.columns[1:]:  # Assuming the first column is 'Plant_Species'
    df[column] = pd.to_numeric(df[column], errors='coerce')  # Convert to numeric, setting non-convertible values to NaN

# Replace values less than 0.1 with 0 in numeric columns only
numeric_columns = df.select_dtypes(include=['number']).columns
df[numeric_columns] = df[numeric_columns].applymap(lambda x: 0 if x < 0.09 else x)  

# Drop columns that contain only 0
columns_dropped = df.columns[(df == 0).all()]
df.drop(columns=columns_dropped, inplace=True)

# Update the list of numeric columns after dropping the all-zero columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Keep track of the original indices
original_indices = set(df.index)

# Drop rows that contain only 0 after filtering for numeric columns
df = df.loc[~(df[numeric_columns] == 0).all(axis=1)]

# Find out which indices were dropped
dropped_indices = original_indices - set(df.index)

# Print the columns that were dropped
print("Columns Dropped:", columns_dropped.tolist())
print("Rows Dropped:", dropped_indices)

# Save the modified DataFrame to a new CSV file
df.to_csv('matched_plants_10%.csv', index=False)
# Out:
# Columns Dropped: ['Bornyl acetate', 'Santene', 'alpha-Muurolene', 'Ylangene', 'Longifolene', 'beta-Selinene', 'gamma-Cadinene', 'beta-Cadinene', 'Calamene', 'Tricyclene', 'alpha-Humulene', 'Cadinene (unknown isomer)', 'Terpinolene', 'beta-Himachalene', 'alpha-Terpinene', 'beta-Bisabolene (tent.)', 'alpha-Fenchol', 'Camphene hydrate', 'Piperitone', 'Bornylene', 'Fenchyl acetate', 'gamma-Bisabolene', 'Sibirene', 'alpha-Bisabolene', 'alpha-Longipinene', 'Longicyclene', 'alpha-Ylangene', 'Benzaldehyde', 'Benzyl alcohol', 'Nerol', 'Piperitol', '(-)-Isopulegol', 'Chavibetol', 'Aromadendrene', 'meta-Cymene', 'p-Cymen-8-ol', 'trans-Fragranyl acetate', 'Fragranol', 'cis-Sabinene hydrate', 'trans-Sabinene hydrate', 'Caryophylladienol', 'Fragranyl 2-methylbutyrate', '2,3-dehydro-1,8-Cineole', 'trans-Pinocarveol', '2-Methylbutyl 2-methylbutyrate', 'Terpinen-4-yl acetate', 'delta-Terpineol', 'Fragranyl isovalerate', 'Isoamyl acetate', 'Isoamyl isovalerate', 'Spathulenol', '12-Methyl-13-tridecanolide', 'Myrtenal', 'Pinocarvone', 'Myrtenol', 'trans-Carveol', 'Cumin alcohol', '15-Hexadecanolide', 'trans-Verbenyl acetate', 'Hexanal', 'Isobutyl 2-methylbutyrate', '2-Pentylfuran', 'cis-Jasmone', 'Artemisia alcohol', 'Yomogi alcohol', 'trans-Verbenol', 'p-Mentha-1,5-dien-8-ol', 'trans-beta-Terpineol', 'Hexahydrofarnesyl acetate', 'cis-Verbenol', '1(7),2-p-Menthadienol-(8)', '1,5-Menthadienol-7', 'beta-Farnesene', 'o-Allyltoluene', 'alpha-Guaiene', 'gamma-Gurjunene', 'Perillyl acetate', 'Elemene (unknown isomer)', 'Cinnamyl acetate', 'Nerolidol (unknown isomer)', 'Benzyl acetate', 'Isopropenylbenzene', 'Decalin', '4-Thujanol', 'Isocaryophyllene', '1-Phenyl-2-butene', 'Jasmone', 'beta-Cubebene', 'gamma-Elemene', 'delta-Elemene', '(Z)-beta-Farnesene', 'Copaene (unknown isomer)', 'Germacrene (unknown isomer)', 'trans-beta-Bergamotene', 'alpha-Gurjunene', 'Methyl eugenol', 'Anisaldehyde', 'T-Muurolol', 'alpha-Cadinol', '(Z)-beta-Ocimene', 'Cadina-1,4-diene', 'T-Cadinol', 'delta-Cadinol', 'alpha-Thujene', 'alpha-Campholene aldehyde', 'Pinocarveol', 'Pinanone', 'Verbenone', 'Sabinol', 'beta-Chamigrene', '2-Methyl-6-methylene-1,7-octadien-3-one', 'cis-Carveol', 'alpha-Selinene', 'n-Butylbenzene', 'delta-Copaene', '2-Phenylbutane', 'Perillene', 'Guaiacol', 'cis-Piperitol', 'Elemol', 'Nonanal', 'Cryptone', 'alpha-Copaen-11-ol', '13-Tridecanolide', 'Humulene oxide', 'alpha-Phellandren-8-ol', 'Pentadecanolide', 'trans-p-Mentha-2,8-dien-1-ol', 'cis-p-Menth-2-en-1-ol', 'm-Cymen-8-ol', 'trans-Verbenyl isovalerate', 'Bornyl isovalerate', 'cis-Carvyl acetate', 'trans-Verbenyl 2-methylbutyrate', 'trans-Carvyl acetate', '2-Tetradecenal', 'Octanal', 'Foeniculin', 'Methyl anisate', 'trans-alpha-Bergamotene', 'p-Methoxyphenylacetone', '(Z)-Anethole', '(Z,E)-alpha-Farnesene', 'Sesquiterpene hydrocarbons', '2-(1-E-Propenyl)-5-methoxyphenyl 2-methylbutyrate', 'Anisalcohol', 'Isochavibetol', '4-Methoxyacetophenone', 'Safrole', 'Anisic acid', 'alpha-Cubebene', 'Santolina alcohol', 'Bisabolene (unknown isomer)', 'Bornyl butyrate', 'Cadinol (unknown isomer)', 'Santolinatriene', 'Isobornyl propionate', 'Hexyl tiglate', '1-Octenol-3', 'Limonene oxide (unknown structure)', 'Ionol (unknown structure)', 'Vanillin', 'Bornyl formate', 'Anisyl acetate', 'cis-Linalool oxide (5) (furanoid)', 'Acetic acid', 'alpha-Bisabolol', 'trans-Linalool oxide (5) (furanoid)', 'Acetaldehyde', 'Vetiverol', '1,1-Diethoxyethane', '2,4-Hexadienal', 'cis-/trans-Anhydrolinalooloxides', 'Undecanal', 'delta-Guaiene', 'Vulgarol', 'Isoborneol', 'allo-Aromadendrene', 'Isopiperitenone', 'trans-Piperitol', 'gamma-Himachalene', 'Artemisia ketone', 'alpha-Atlantone', 'Himachalol', 'Artemisyl acetate', 'Himachalol (isomer)', 'alpha-Himachalene', 'cis-Chrysanthenyl acetate', 'cis-Chrysanthenol', 'Chrysanthenone', 'Farnesol (unknown isomer)', 'ar-Curcumene', 'p-Cresol', 'beta-Bisabolol', 'Sesquicineole', 'Furopelargone A', '1-epi-Cubenol', 'trans-Sesquisabinene hydrate', 'alpha-Calacorene', 'cis-Sesquisabinene hydra ...
# Rows Dropped: set()

# %%
import pandas as pd
import re

# Function to extract the core chemical name (excluding parentheses)
def extract_core_name(text):
    return re.sub(r'\s*\([^)]*\)', '', text).strip().lower()

# Load the initial chemicals data
initial_file_path = 'matched_plants_10%.csv' 
initial_df = pd.read_csv(initial_file_path)

# Load the chemicals fingerprints data
fingerprints_file_path = '/Users/mariiakokina/Documents/eo_database/initial_data/matched_chemicals_fingerprints.csv'  # Update with the actual path
fingerprints_df = pd.read_csv(fingerprints_file_path)

# Normalize chemical names for case-insensitive matching
fingerprints_df['Chemical Name'] = fingerprints_df['Chemical Name'].str.lower()

# Dictionary to hold chemical name to fingerprint mapping
chemical_to_fingerprint = dict(zip(fingerprints_df['Chemical Name'], fingerprints_df['Fingerprints']))

# Track the number of columns dropped and their names
dropped_columns_count = 0
dropped_columns_names = []  # List to store names of dropped columns

# Iterate through the initial DataFrame columns and check for fingerprint matches
for col in initial_df.columns[1:]:  # Skip the first column
    normalized_col = col.lower()
    core_name = extract_core_name(normalized_col)

    if core_name not in chemical_to_fingerprint and normalized_col not in chemical_to_fingerprint:
        dropped_columns_count += 1  # Increment the count of dropped columns
        dropped_columns_names.append(col)  # Add the original column name to the list of dropped columns

# Drop the columns from the original DataFrame
initial_df.drop(columns=dropped_columns_names, inplace=True)

# Save the updated original DataFrame to a new CSV file
updated_initial_file_path = 'updated_matched_plants_10%.csv'  # Update with the actual path
initial_df.to_csv(updated_initial_file_path, index=False)

# Print out the number of columns that were dropped and their names
print(f"Number of columns dropped: {dropped_columns_count}")
for col_name in dropped_columns_names:
    print(f"Dropped column: {col_name}")
print(f"Updated initial DataFrame saved to {updated_initial_file_path}")
# Out:
# Number of columns dropped: 18
# Dropped column: Cubenol
# Dropped column: Sesquiterpene alcohols (unknown)
# Dropped column: Bupleurol
# Dropped column: Allyl-2,3,4,5-tetramethoxybenzene
# Dropped column: alpha-oxo-Bisabolene
# Dropped column: Sesquiterpenes, oxygen-containing-
# Dropped column: Methyl thymol
# Dropped column: Nonadecene/nonadecane
# Dropped column: Alkanes & alkenes
# Dropped column: Acids and esters
# Dropped column: 2-(1,2-Epoxypropane)-5-methoxyphenyl 2-methylbutyrate
# Dropped column: Alkanes
# Dropped column: cis,p-1(7),8-Menthadienol-2
# Dropped column: S-(3-Methylbut-2-enyl) 3-methylbutanethioate
# Dropped column: (E)-Cinnamyl aldehyde
# Dropped column: 2-Hydroxy-4-methoxy-acetophenone
# Dropped column: Agropinene
# Dropped column: 3-Vinyl-1,2-dithia-5-cyclohexene
# Updated initial DataFrame saved to updated_matched_plants_10%.csv

# %%
import pandas as pd
import re

# Function to extract the core chemical name (excluding parentheses)
def extract_core_name(text):
    return re.sub(r'\s*\([^)]*\)', '', text).strip().lower()

# Load the initial chemicals data with semicolon as delimiter
initial_file_path = 'updated_matched_plants_10%.csv'  # Update with the actual path
initial_df = pd.read_csv(initial_file_path)

# Load the chemicals fingerprints data with comma as delimiter
fingerprints_file_path = '/Users/mariiakokina/Documents/eo_database/initial_data/matched_chemicals_fingerprints.csv'  
fingerprints_df = pd.read_csv(fingerprints_file_path)

# Normalize chemical names for case-insensitive matching
fingerprints_df['Chemical Name'] = fingerprints_df['Chemical Name'].str.lower()

# Dictionary to hold chemical name to fingerprint mapping
chemical_to_fingerprint = dict(zip(fingerprints_df['Chemical Name'], fingerprints_df['Fingerprints']))

# Initialize the fingerprint header with placeholders for all columns
fingerprint_header = ['Plant_Species']  # Explicitly set the first column header

# Track the number of columns dropped (excluding the first one)
dropped_columns_count = 0

# Iterate through the initial DataFrame columns and update the fingerprint header
for col in initial_df.columns[1:]:  # Skip the first column
    normalized_col = col.lower()
    core_name = extract_core_name(normalized_col)

    if core_name in chemical_to_fingerprint or normalized_col in chemical_to_fingerprint:
        fingerprint = chemical_to_fingerprint.get(core_name) or chemical_to_fingerprint.get(normalized_col)
        fingerprint_header.append(fingerprint)  # Update the corresponding position in the header
    else:
        dropped_columns_count += 1
        fingerprint_header.append('Unmatched')  # Indicate unmatched columns

# Filter the DataFrame to only include columns with matched fingerprints
matched_columns = ['Plant_Species']  # Start with the first column
matched_columns.extend([col for i, col in enumerate(initial_df.columns[1:], 1) if fingerprint_header[i] != 'Unmatched'])

# Filter the initial DataFrame to only include matched columns
initial_df = initial_df[matched_columns]

# Insert the fingerprint row above the column headers as the new first row
initial_df.columns = pd.MultiIndex.from_tuples(list(zip(fingerprint_header, initial_df.columns)))

# Save the matched DataFrame to a new CSV file
output_file_path = 'matched_chemicals_with_names_fingerprints.csv'  # Update with the actual path
initial_df.to_csv(output_file_path, index=False)  

# Print out the number of columns that were dropped (excluding the first one)
print(f"Number of columns dropped (excluding the first one): {dropped_columns_count}")
print(f"Matched DataFrame saved to {output_file_path}")
# Out:
# Number of columns dropped (excluding the first one): 0
# Matched DataFrame saved to matched_chemicals_with_names_fingerprints.csv

# %%
import pandas as pd

# file path for the dataset
file_path = 'matched_chemicals_with_names_fingerprints.csv'

# Load the dataset
data = pd.read_csv(file_path)

# Rename the first column
data.rename(columns={data.columns[0]: 'Chemical_Fingerprint'}, inplace=True)

# Save the dataset back out
data.to_csv(file_path, index=False)

print(f"First column renamed and file overwritten at {file_path}")
# Out:
# First column renamed and file overwritten at matched_chemicals_with_names_fingerprints.csv

# %%
import pandas as pd
import re

# Function to extract the core chemical name (excluding parentheses)
def extract_core_name(text):
    return re.sub(r'\s*\([^)]*\)', '', text).strip().lower()

# Load the initial chemicals data with colon as delimiter
initial_file_path = 'updated_matched_plants_10%.csv'  # Update with the actual path
initial_df = pd.read_csv(initial_file_path, sep=',')

# Load the chemicals fingerprints data
fingerprints_file_path = '/Users/mariiakokina/Documents/eo_database/initial_data/matched_chemicals_fingerprints.csv'  # Update with the actual path
fingerprints_df = pd.read_csv(fingerprints_file_path)

# Normalize chemical names for case-insensitive matching
fingerprints_df['Chemical Name'] = fingerprints_df['Chemical Name'].str.lower()

# Dictionary to hold chemical name to fingerprint mapping
chemical_to_fingerprint = dict(zip(fingerprints_df['Chemical Name'], fingerprints_df['Fingerprints']))

# Track the number of columns dropped (excluding the first one)
dropped_columns_count = 0

# Iterate through the initial DataFrame columns and replace concentrations with fingerprints
for col in initial_df.columns[1:]:  # Skip the first column
    normalized_col = col.lower()
    core_name = extract_core_name(normalized_col)

    if core_name in chemical_to_fingerprint or normalized_col in chemical_to_fingerprint:
        # Get the fingerprint for the chemical
        fingerprint = chemical_to_fingerprint.get(core_name) or chemical_to_fingerprint.get(normalized_col)
        # Replace entire column's concentration values with the fingerprint
        initial_df[col] = fingerprint
    else:
        # Drop the column from the DataFrame if no match found
        initial_df.drop(columns=[col], inplace=True)
        dropped_columns_count += 1

# Save the modified DataFrame to a new CSV file
output_file_path = 'plants_with_fingerprints.csv'  # Update with the actual path
initial_df.to_csv(output_file_path, index=False)

# Print out the number of columns that were dropped (excluding the first one)
print(f"Number of columns dropped (excluding the first one): {dropped_columns_count}")
print(f"Modified DataFrame saved to {output_file_path}")
# Out:
# Number of columns dropped (excluding the first one): 0
# Modified DataFrame saved to plants_with_fingerprints.csv

# %%
import pandas as pd

# Define the path to your dataset
dataset_path = '/Users/mariiakokina/Documents/eo_database/chemical_composition/plants_with_fingerprints.csv'

# Read the dataset
df = pd.read_csv(dataset_path)

# Loop through columns (starting from the second column)
for column in df.columns[1:]:
    # Append "_fingerprint" to the column name
    df.rename(columns={column: column + '_fingerprint'}, inplace=True)

# Save the modified dataset with updated column names
df.to_csv('/Users/mariiakokina/Documents/eo_database/chemical_composition/plants_with_fingerprints_updated.csv', index=False)

# %%
import pandas as pd

# Define the file paths
file1_path = 'plants_with_fingerprints_updated.csv'
file2_path = 'Salmonella.csv'
file3_path = 'updated_matched_plants_10%.csv'

# Read the CSV files and count the number of rows and columns
df1 = pd.read_csv(file1_path)
df2 = pd.read_csv(file2_path)
df3 = pd.read_csv(file3_path)

# Get the number of rows and columns in each DataFrame
num_rows_file1, num_cols_file1 = df1.shape
num_rows_file2, num_cols_file2 = df2.shape
num_rows_file3, num_cols_file3 = df3.shape

# Compare the number of rows and columns
if num_rows_file1 == num_rows_file2 == num_rows_file3:
    print("All three files have the same number of rows:", num_rows_file1)
else:
    print("The number of rows in the files is not equal.")
    print("File 1 has {} rows.".format(num_rows_file1))
    print("File 2 has {} rows.".format(num_rows_file2))
    print("File 3 has {} rows.".format(num_rows_file3))

if num_cols_file1 == num_cols_file2 == num_cols_file3:
    print("All three files have the same number of columns:", num_cols_file1)
else:
    print("The number of columns in the files is not equal.")
    print("File 1 has {} columns.".format(num_cols_file1))
    print("File 2 has {} columns.".format(num_cols_file2))
    print("File 3 has {} columns.".format(num_cols_file3))
# Out:
# All three files have the same number of rows: 177
# The number of columns in the files is not equal.
# File 1 has 131 columns.
# File 2 has 3 columns.
# File 3 has 131 columns.
