# %% [markdown]
# Clustering Analysis: Use clustering algorithms such as K-means or DBSCAN to identify groups or clusters of plants based on their chemical compositions. This can help identify similarities and differences among different plant species. Find hidden structures is the data that are not immidiately availible. K-means - groups of simmilar instances - the closest centroid to each data sample.

# %%
import pandas as pd

# Load the data and set the first column as the index
data = pd.read_csv('./initial_data/chemicals_data_clean.csv', index_col=0)

# Extract row indices (species)
species_list = data.index.tolist()

# Count the total number of species
species_count = len(species_list)

# Create a new DataFrame from the species list
species_df = pd.DataFrame(species_list, columns=['Plant_Species'])

# Save the new DataFrame to a CSV file
species_df.to_csv('./initial_data/plant_species_list.csv', index=False)

# Print the total number of species
print(f'Total number of species: {species_count}')
# Out:
# Total number of species: 4087

# %% [markdown]
# Part 2: Clustering
#
# This part will perform the clustering using Euclidean distances
#
# This script will save a separate CSV file for each cluster. Each file will contain a similarity matrix for the plants within that cluster. The filename will include the cluster number for identification. The similarity scores are calculated by normalizing the distances (dividing by the maximum distance) and then subtracting from 1, so that a higher score corresponds to greater similarity.

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances, silhouette_score
import numpy as np
import os
import logging
from tqdm import tqdm

# Set up logging to console
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load the data
logging.info('Loading data...')
df = pd.read_csv('./initial_data/chemicals_data_clean.csv', index_col=0)
logging.info('Data loaded successfully.')

# Set the range of number of clusters to explore
min_clusters = 50
max_clusters = min(len(df), 300)

# Initialize variables
best_score = -1
best_num_clusters = -1

# Search for the optimal number of clusters using Silhouette Score
logging.info('Searching for optimal number of clusters...')
for num_clusters in tqdm(range(min_clusters, max_clusters + 1), desc='Optimizing clusters', unit='cluster'):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(df.values)
    cluster_labels = kmeans.labels_
    silhouette_avg = silhouette_score(df.values, cluster_labels)
    
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_num_clusters = num_clusters

logging.info(f'Optimal number of clusters found: {best_num_clusters} with Silhouette Score: {best_score}')

# Perform K-Means Clustering with the best number of clusters
logging.info('Performing K-Means clustering with optimal number of clusters...')
kmeans = KMeans(n_clusters=best_num_clusters, random_state=0).fit(df.values)
cluster_labels = kmeans.labels_
logging.info('K-Means clustering completed.')

# Assign cluster labels to plants
df['cluster'] = cluster_labels

# For each cluster, extract the subset of the DataFrame, calculate similarity scores, and save to CSV files
for cluster in tqdm(set(df['cluster']), desc='Processing clusters', unit='cluster'):
    logging.info(f'Processing cluster {cluster}...')
    
    # Define the directory path
    dir_path = f'./initial_data/clusters_euclidean'
    
    # Check if the directory exists, if not, create it
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
        logging.info(f'Created directory: {dir_path}')
    
    # Proceed with saving the data
    cluster_df = df[df['cluster'] == cluster].drop('cluster', axis=1)
    cluster_df.to_csv(f'{dir_path}/cluster_{cluster}_chemical_compositions.csv')
    logging.info(f'Saved chemical compositions for cluster {cluster}.')
    
    # Calculate Euclidean distances
    distances = pairwise_distances(cluster_df.values, metric='euclidean')
    
    # Convert distances to similarities (1 - normalized distance)
    similarities = 1 - distances / distances.max()
    
    # Create a DataFrame of similarity scores
    similarities_df = pd.DataFrame(similarities, index=cluster_df.index, columns=cluster_df.index)
    
    # Save similarity scores to CSV
    similarities_df.to_csv(f'{dir_path}/cluster_{cluster}_plant_similarities.csv')
    logging.info(f'Saved plant similarities for cluster {cluster}.')

logging.info('Number of clusters: {}'.format(len(set(df['cluster']))))
# Out:
# Optimizing clusters:   0%|           | 0/251 [00:00<?, ?cluster/s]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   0%|   | 1/251 [00:11<46:19, 11.12s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   1%|   | 2/251 [00:23<48:41, 11.73s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   1%|   | 3/251 [00:35<49:52, 12.07s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   2%|   | 4/251 [00:45<46:40, 11.34s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   2%|   | 5/251 [00:57<46:19, 11.30s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   2%|   | 6/251 [01:08<46:31, 11.40s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   3%|   | 7/251 [01:24<51:36, 12.69s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   3%|   | 8/251 [01:39<54:43, 13.51s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   4%|   | 9/251 [01:50<51:21, 12.73s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   4%|  | 10/251 [02:02<49:57, 12.44s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   4%|  | 11/251 [02:13<48:56, 12.24s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   5%|  | 12/251 [02:25<48:17, 12.13s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   5%|  | 13/251 [02:38<48:09, 12.14s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   6%|  | 14/251 [02:49<47:20, 11.98s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   6%|  | 15/251 [03:00<46:22, 11.79s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   6%|▏ | 16/251 [03:12<45:40, 11.66s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   7%|▏ | 17/251 [03:24<45:50, 11.76s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   7%|▏ | 18/251 [03:36<46:17, 11.92s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   8%|▏ | 19/251 [03:48<46:27, 12.02s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   8%|▏ | 20/251 [04:01<46:44, 12.14s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   8%|▏ | 21/251 [04:14<47:34, 12.41s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   9%|▏ | 22/251 [04:26<47:10, 12.36s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:   9%|▏ | 23/251 [04:39<47:37, 12.53s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  10%|▏ | 24/251 [04:51<47:17, 12.50s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  10%|▏ | 25/251 [05:05<48:26, 12.86s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  10%|▏ | 26/251 [05:18<47:41, 12.72s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  11%|▏ | 27/251 [05:30<47:41, 12.77s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  11%|▏ | 28/251 [05:44<48:04, 12.93s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  12%|▏ | 29/251 [05:57<48:01, 12.98s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  12%|▏ | 30/251 [06:10<48:24, 13.14s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  12%|▏ | 31/251 [06:24<48:42, 13.28s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  13%|▎ | 32/251 [06:38<49:28, 13.56s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  13%|▎ | 33/251 [06:55<52:30, 14.45s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  14%|▎ | 34/251 [07:10<52:58, 14.65s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  14%|▎ | 35/251 [07:24<51:53, 14.42s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  14%|▎ | 36/251 [07:38<51:27, 14.36s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  15%|▎ | 37/251 [07:52<50:59, 14.30s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  15%|▎ | 38/251 [08:07<51:17, 14.45s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  16%|▎ | 39/251 [08:23<52:25, 14.84s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  16%|▎ | 40/251 [08:38<52:23, 14.90s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  16%|▎ | 41/251 [08:54<53:09, 15.19s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  17%|▎ | 42/251 [09:10<53:59, 15.50s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  17%|▎ | 43/251 [09:26<54:04, 15.60s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  18%|▏| 44/251 [09:57<1:10:14, 20.36s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  18%|▏| 45/251 [10:12<1:04:30, 18.79s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  18%|▏| 46/251 [10:28<1:00:54, 17.82s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  19%|▎ | 47/251 [10:45<59:36, 17.53s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  19%|▍ | 48/251 [11:02<59:01, 17.44s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  20%|▍ | 49/251 [11:18<57:48, 17.17s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  20%|▍ | 50/251 [11:37<58:44, 17.53s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  20%|▏| 51/251 [11:56<1:00:18, 18.09s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  21%|▏| 52/251 [12:19<1:04:19, 19.40s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  21%|▏| 53/251 [12:42<1:08:10, 20.66s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  22%|▏| 54/251 [13:06<1:11:18, 21.72s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  22%|▏| 55/251 [13:24<1:07:21, 20.62s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  22%|▏| 56/251 [13:42<1:03:47, 19.63s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  23%|▏| 57/251 [13:58<1:00:12, 18.62s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  23%|▍ | 58/251 [14:17<59:49, 18.60s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  24%|▍ | 59/251 [14:33<57:47, 18.06s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  24%|▍ | 60/251 [14:52<57:53, 18.18s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  24%|▍ | 61/251 [15:10<57:39, 18.21s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  25%|▏| 62/251 [15:37<1:06:00, 20.95s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  25%|▎| 63/251 [16:04<1:11:00, 22.66s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  25%|▎| 64/251 [16:21<1:05:41, 21.08s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  26%|▎| 65/251 [16:49<1:11:27, 23.05s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  26%|▎| 66/251 [17:08<1:07:04, 21.75s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  27%|▎| 67/251 [17:26<1:03:48, 20.80s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  27%|▎| 68/251 [17:50<1:05:46, 21.57s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  27%|▎| 69/251 [18:12<1:05:35, 21.62s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  28%|▎| 70/251 [18:32<1:03:52, 21.17s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  28%|▎| 71/251 [18:51<1:01:59, 20.66s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  29%|▎| 72/251 [19:16<1:05:09, 21.84s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  29%|▎| 73/251 [19:40<1:07:06, 22.62s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  29%|▎| 74/251 [19:58<1:02:14, 21.10s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  30%|▎| 75/251 [20:20<1:03:09, 21.53s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  30%|▎| 76/251 [20:41<1:02:09, 21.31s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  31%|▎| 77/251 [21:01<1:00:18, 20.79s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  31%|▎| 78/251 [21:22<1:00:00, 20.81s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  31%|▋ | 79/251 [21:42<59:37, 20.80s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  32%|▋ | 80/251 [22:02<58:04, 20.38s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  32%|▋ | 81/251 [22:22<57:58, 20.46s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  33%|▋ | 82/251 [22:45<59:34, 21.15s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  33%|▋ | 83/251 [23:05<58:08, 20.77s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  33%|▋ | 84/251 [23:27<59:08, 21.25s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  34%|▋ | 85/251 [23:48<58:42, 21.22s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  34%|▋ | 86/251 [24:10<58:22, 21.23s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  35%|▎| 87/251 [24:36<1:01:53, 22.65s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  35%|▎| 88/251 [24:58<1:01:19, 22.57s/cluster/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  35%|▋ | 89/251 [25:19<59:56, 22.20s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  36%|▋ | 90/251 [25:40<58:15, 21.71s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  36%|▋ | 91/251 [26:00<56:42, 21.26s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  37%|▋ | 92/251 [26:23<57:15, 21.61s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  37%|▋ | 93/251 [26:44<56:47, 21.57s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  37%|▋ | 94/251 [27:06<56:36, 21.64s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  38%|▊ | 95/251 [27:30<57:59, 22.31s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  38%|▊ | 96/251 [27:52<57:11, 22.14s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  39%|▊ | 97/251 [28:13<56:20, 21.95s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  39%|▊ | 98/251 [28:34<55:06, 21.61s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  39%|▊ | 99/251 [28:59<57:33, 22.72s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  40%|▍| 100/251 [29:22<57:14, 22.75s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  40%|▍| 101/251 [29:44<56:14, 22.50s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  41%|▍| 102/251 [30:07<56:25, 22.72s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  41%|▍| 103/251 [30:30<56:26, 22.88s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  41%|▍| 104/251 [30:53<56:09, 22.93s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  42%|▍| 105/251 [31:17<55:54, 22.98s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  42%|▍| 106/251 [31:47<1:00:43, 25.13s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  43%|▍| 107/251 [32:09<58:33, 24.40s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  43%|▍| 108/251 [32:33<57:49, 24.26s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  43%|▍| 109/251 [32:59<58:14, 24.61s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  44%|▍| 110/251 [33:23<57:56, 24.65s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  44%|▍| 111/251 [33:46<56:13, 24.09s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  45%|▍| 112/251 [34:12<57:10, 24.68s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  45%|▍| 113/251 [34:40<58:54, 25.61s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  45%|▍| 114/251 [35:09<1:00:31, 26.51s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  46%|▍| 115/251 [35:33<58:25, 25.77s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  46%|▍| 116/251 [35:59<58:06, 25.83s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  47%|▍| 117/251 [36:22<56:10, 25.15s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  47%|▍| 118/251 [36:46<54:52, 24.75s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  47%|▍| 119/251 [37:08<52:36, 23.92s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  48%|▍| 120/251 [37:31<51:37, 23.65s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  48%|▍| 121/251 [37:54<50:37, 23.36s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  49%|▍| 122/251 [38:17<50:15, 23.38s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  49%|▍| 123/251 [38:40<49:25, 23.17s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  49%|▍| 124/251 [39:03<49:11, 23.24s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  50%|▍| 125/251 [39:27<49:00, 23.34s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  50%|▌| 126/251 [39:50<48:37, 23.34s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  51%|▌| 127/251 [40:13<47:53, 23.17s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  51%|▌| 128/251 [40:37<47:57, 23.39s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  51%|▌| 129/251 [41:00<47:36, 23.41s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  52%|▌| 130/251 [41:25<48:01, 23.81s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  52%|▌| 131/251 [41:48<47:18, 23.65s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  53%|▌| 132/251 [42:13<47:30, 23.96s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  53%|▌| 133/251 [42:37<46:59, 23.90s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  53%|▌| 134/251 [43:02<47:25, 24.32s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  54%|▌| 135/251 [43:26<46:52, 24.25s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  54%|▌| 136/251 [43:51<46:35, 24.30s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  55%|▌| 137/251 [44:15<46:09, 24.29s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  55%|▌| 138/251 [44:39<45:35, 24.21s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  55%|▌| 139/251 [45:03<45:13, 24.23s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  56%|▌| 140/251 [45:28<45:19, 24.50s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  56%|▌| 141/251 [45:53<44:59, 24.54s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  57%|▌| 142/251 [46:18<44:57, 24.75s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  57%|▌| 143/251 [46:48<47:02, 26.13s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  57%|▌| 144/251 [47:14<46:40, 26.18s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  58%|▌| 145/251 [47:39<45:55, 26.00s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  58%|▌| 146/251 [48:05<45:24, 25.95s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  59%|▌| 147/251 [48:31<44:49, 25.86s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  59%|▌| 148/251 [48:59<45:24, 26.45s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  59%|▌| 149/251 [49:25<44:59, 26.47s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  60%|▌| 150/251 [49:54<45:35, 27.08s/cluster]/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# ...
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  82%|▊| 207/251 [1:17:55<24:06, 32.88s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  83%|▊| 208/251 [1:18:29<23:40, 33.03s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  83%|▊| 209/251 [1:19:01<22:56, 32.77s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  84%|▊| 210/251 [1:19:36<22:50, 33.43s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  84%|▊| 211/251 [1:20:09<22:07, 33.19s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  84%|▊| 212/251 [1:20:41<21:23, 32.91s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  85%|▊| 213/251 [1:21:14<20:49, 32.89s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  85%|▊| 214/251 [1:21:48<20:27, 33.19s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  86%|▊| 215/251 [1:22:20<19:51, 33.10s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  86%|▊| 216/251 [1:22:54<19:22, 33.23s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  86%|▊| 217/251 [1:23:26<18:42, 33.03s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  87%|▊| 218/251 [1:24:00<18:10, 33.05s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  87%|▊| 219/251 [1:24:32<17:31, 32.86s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  88%|▉| 220/251 [1:25:06<17:04, 33.05s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  88%|▉| 221/251 [1:25:39<16:32, 33.08s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  88%|▉| 222/251 [1:26:13<16:10, 33.45s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  89%|▉| 223/251 [1:26:47<15:38, 33.51s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  89%|▉| 224/251 [1:27:22<15:20, 34.08s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  90%|▉| 225/251 [1:27:58<14:58, 34.55s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  90%|▉| 226/251 [1:28:33<14:26, 34.66s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  90%|▉| 227/251 [1:29:07<13:50, 34.61s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  91%|▉| 228/251 [1:29:41<13:13, 34.52s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  91%|▉| 229/251 [1:30:16<12:40, 34.56s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  92%|▉| 230/251 [1:30:50<12:04, 34.50s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  92%|▉| 231/251 [1:31:25<11:27, 34.40s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  92%|▉| 232/251 [1:32:04<11:20, 35.84s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  93%|▉| 233/251 [1:32:38<10:36, 35.34s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  93%|▉| 234/251 [1:33:13<09:57, 35.14s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  94%|▉| 235/251 [1:33:47<09:20, 35.06s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  94%|▉| 236/251 [1:34:23<08:46, 35.09s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  94%|▉| 237/251 [1:35:16<09:28, 40.63s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  95%|▉| 238/251 [1:36:23<10:32, 48.63s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  95%|▉| 239/251 [1:37:30<10:46, 53.89s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  96%|▉| 240/251 [1:38:35<10:32, 57.46s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  96%|▉| 241/251 [1:39:41<09:57, 59.77s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  96%|▉| 242/251 [1:40:47<09:15, 61.67s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  97%|▉| 243/251 [1:48:04<23:14, 174.36s/clust/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  97%|▉| 244/251 [1:49:18<16:50, 144.31s/clust/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  98%|▉| 245/251 [1:50:24<12:04, 120.74s/clust/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  98%|▉| 246/251 [1:51:16<08:20, 100.17s/clust/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  98%|▉| 247/251 [1:51:59<05:31, 82.84s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  99%|▉| 248/251 [1:52:36<03:27, 69.28s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters:  99%|▉| 249/251 [1:53:14<01:59, 59.93s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters: 100%|▉| 250/251 [1:53:52<00:53, 53.35s/cluste/Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Optimizing clusters: 100%|█| 251/251 [1:54:30<00:00, 27.37s/cluste
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# Processing clusters:  58%|█▏| 93/160 [00:04<00:03, 21.09cluster/s]/var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# Processing clusters:  68%|▋| 108/160 [00:04<00:01, 30.65cluster/s]/var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# Processing clusters:  77%|▊| 123/160 [00:04<00:00, 40.14cluster/s]/var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# Processing clusters:  87%|▊| 139/160 [00:05<00:00, 44.68cluster/s]/var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# Processing clusters:  92%|▉| 148/160 [00:05<00:00, 55.69cluster/s]/var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# /var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# Processing clusters:  96%|▉| 154/160 [00:05<00:00, 53.06cluster/s]/var/folders/x1/3wgmd54s6b7f7xc3rq_f0tdw0000gn/T/ipykernel_86949/3603907169.py:68: RuntimeWarning:
#
# invalid value encountered in divide
#
# Processing clusters: 100%|█| 160/160 [00:05<00:00, 29.07cluster/s]

# %% [markdown]
# Validation. We can then compare the initial count of unique plant species with the sum of unique plant species in all clusters. Ideally, the two counts should be the same.

# %%
import os
import pandas as pd

# Load the initial data
initial_data = pd.read_csv('./initial_data/chemicals_data_clean.csv', index_col=0)

# Count the number of unique plant species in the initial dataset
initial_species_count = initial_data.index.nunique()
print(f"Number of unique plant species in initial dataset: {initial_species_count}")

# Define the directory where cluster files are located
cluster_directory = './initial_data/clusters_euclidean'

# Initialize variable to store total count of unique species in all clusters
total_clustered_species = 0

# Iterate over each cluster file
for cluster_file in os.listdir(cluster_directory):
    if cluster_file.endswith('_chemical_compositions.csv'):
        # Load cluster data
        cluster_data = pd.read_csv(os.path.join(cluster_directory, cluster_file), index_col=0)
        
        # Count the number of unique plant species in the cluster
        cluster_species_count = cluster_data.index.nunique()
        
        # Add the count to the total
        total_clustered_species += cluster_species_count
        
        # Extract cluster number from file name
        cluster_number = cluster_file.split('_')[1]
        
        # Print the result
        print(f"Number of unique plant species in cluster {cluster_number}: {cluster_species_count}")

# Print total number of unique plant species clustered
print(f"Total number of unique plant species clustered: {total_clustered_species}")
# Out:
# Number of unique plant species in initial dataset: 4087
# Number of unique plant species in cluster 71: 27
# Number of unique plant species in cluster 105: 9
# Number of unique plant species in cluster 28: 19
# Number of unique plant species in cluster 79: 3
# Number of unique plant species in cluster 123: 7
# Number of unique plant species in cluster 97: 43
# Number of unique plant species in cluster 20: 42
# Number of unique plant species in cluster 57: 5
# Number of unique plant species in cluster 154: 1
# Number of unique plant species in cluster 118: 3
# Number of unique plant species in cluster 136: 8
# Number of unique plant species in cluster 82: 7
# Number of unique plant species in cluster 35: 21
# Number of unique plant species in cluster 42: 14
# Number of unique plant species in cluster 6: 60
# Number of unique plant species in cluster 141: 2
# Number of unique plant species in cluster 64: 6
# Number of unique plant species in cluster 13: 17
# Number of unique plant species in cluster 110: 4
# Number of unique plant species in cluster 149: 1
# Number of unique plant species in cluster 139: 11
# Number of unique plant species in cluster 9: 52
# Number of unique plant species in cluster 117: 12
# Number of unique plant species in cluster 14: 127
# Number of unique plant species in cluster 63: 7
# Number of unique plant species in cluster 146: 7
# Number of unique plant species in cluster 1: 128
# Number of unique plant species in cluster 45: 5
# Number of unique plant species in cluster 32: 5
# Number of unique plant species in cluster 85: 21
# Number of unique plant species in cluster 131: 2
# Number of unique plant species in cluster 153: 5
# Number of unique plant species in cluster 50: 8
# Number of unique plant species in cluster 27: 31
# Number of unique plant species in cluster 90: 5
# Number of unique plant species in cluster 124: 28
# Number of unique plant species in cluster 98: 2
# Number of unique plant species in cluster 58: 38
# Number of unique plant species in cluster 102: 19
# Number of unique plant species in cluster 76: 18
# Number of unique plant species in cluster 107: 66
# Number of unique plant species in cluster 73: 5
# Number of unique plant species in cluster 129: 9
# Number of unique plant species in cluster 156: 54
# Number of unique plant species in cluster 55: 4
# Number of unique plant species in cluster 95: 35
# Number of unique plant species in cluster 22: 58
# Number of unique plant species in cluster 121: 2
# Number of unique plant species in cluster 19: 8
# Number of unique plant species in cluster 143: 5
# Number of unique plant species in cluster 40: 19
# Number of unique plant species in cluster 4: 27
# Number of unique plant species in cluster 80: 3
# Number of unique plant species in cluster 37: 75
# Number of unique plant species in cluster 134: 3
# Number of unique plant species in cluster 112: 1
# Number of unique plant species in cluster 11: 38
# Number of unique plant species in cluster 66: 2
# Number of unique plant species in cluster 88: 15
# Number of unique plant species in cluster 48: 11
# Number of unique plant species in cluster 38: 80
# Number of unique plant species in cluster 61: 8
# Number of unique plant species in cluster 16: 13
# Number of unique plant species in cluster 115: 99
# Number of unique plant species in cluster 133: 4
# Number of unique plant species in cluster 30: 33
# Number of unique plant species in cluster 87: 7
# Number of unique plant species in cluster 3: 22
# Number of unique plant species in cluster 47: 23
# Number of unique plant species in cluster 144: 21
# Number of unique plant species in cluster 69: 9
# Number of unique plant species in cluster 126: 17
# Number of unique plant species in cluster 25: 19
# Number of unique plant species in cluster 92: 9
# Number of unique plant species in cluster 52: 33
# Number of unique plant species in cluster 151: 5
# Number of unique plant species in cluster 108: 35
# Number of unique plant species in cluster 159: 15
# Number of unique plant species in cluster 74: 10
# Number of unique plant species in cluster 100: 2
# Number of unique plant species in cluster 158: 6
# Number of unique plant species in cluster 75: 88
# Number of unique plant species in cluster 101: 63
# Number of unique plant species in cluster 24: 23
# Number of unique plant species in cluster 93: 10
# Number of unique plant species in cluster 127: 1
# Number of unique plant species in cluster 150: 1
# Number of unique plant species in cluster 53: 8
# Number of unique plant species in cluster 109: 2
# Number of unique plant species in cluster 31: 34
# Number of unique plant species in cluster 86: 5
# Number of unique plant species in cluster 132: 30
# Number of unique plant species in cluster 145: 1
# Number of unique plant species in cluster 2: 18
# Number of unique plant species in cluster 46: 14
# Number of unique plant species in cluster 68: 5
# Number of unique plant species in cluster 39: 61
# Number of unique plant species in cluster 60: 42
# Number of unique plant species in cluster 114: 10
# Number of unique plant species in cluster 17: 9
# Number of unique plant species in cluster 10: 45
# Number of unique plant species in cluster 113: 2
# Number of unique plant species in cluster 67: 13
# Number of unique plant species in cluster 89: 13
# Number of unique plant species in cluster 49: 28
# Number of unique plant species in cluster 18: 31
# Number of unique plant species in cluster 41: 16
# Number of unique plant species in cluster 5: 35
# Number of unique plant species in cluster 142: 2
# Number of unique plant species in cluster 135: 8
# Number of unique plant species in cluster 81: 9
# Number of unique plant species in cluster 36: 53
# Number of unique plant species in cluster 54: 26
# Number of unique plant species in cluster 157: 3
# Number of unique plant species in cluster 120: 27
# Number of unique plant species in cluster 94: 7
# Number of unique plant species in cluster 23: 33
# Number of unique plant species in cluster 106: 23
# Number of unique plant species in cluster 72: 12
# Number of unique plant species in cluster 128: 2
# Number of unique plant species in cluster 99: 5
# Number of unique plant species in cluster 59: 2
# Number of unique plant species in cluster 103: 9
# Number of unique plant species in cluster 77: 17
# Number of unique plant species in cluster 51: 20
# Number of unique plant species in cluster 152: 15
# Number of unique plant species in cluster 125: 2
# Number of unique plant species in cluster 26: 8
# Number of unique plant species in cluster 91: 3
# Number of unique plant species in cluster 0: 23
# Number of unique plant species in cluster 44: 5
# Number of unique plant species in cluster 147: 2
# Number of unique plant species in cluster 130: 44
# Number of unique plant species in cluster 33: 11
# Number of unique plant species in cluster 84: 126
# Number of unique plant species in cluster 138: 8
# Number of unique plant species in cluster 8: 64
# Number of unique plant species in cluster 15: 61
# Number of unique plant species in cluster 116: 2
# Number of unique plant species in cluster 62: 10
# Number of unique plant species in cluster 65: 57
# Number of unique plant species in cluster 111: 2
# Number of unique plant species in cluster 12: 22
# Number of unique plant species in cluster 148: 38
# Number of unique plant species in cluster 119: 9
# Number of unique plant species in cluster 83: 71
# Number of unique plant species in cluster 34: 37
# Number of unique plant species in cluster 137: 59
# Number of unique plant species in cluster 140: 18
# Number of unique plant species in cluster 43: 24
# Number of unique plant species in cluster 7: 61
# Number of unique plant species in cluster 78: 484
# Number of unique plant species in cluster 96: 1
# Number of unique plant species in cluster 21: 45
# Number of unique plant species in cluster 122: 18
# Number of unique plant species in cluster 155: 2
# Number of unique plant species in cluster 56: 82
# Number of unique plant species in cluster 70: 3
# Number of unique plant species in cluster 104: 5
# Number of unique plant species in cluster 29: 59
# Total number of unique plant species clustered: 4087

# %% [markdown]
# To validate even further the clustering results, we will randomly select some plants from the initial dataset and identify the clusters they have been assigned to. Subsequently, a heatmap will be generated to visually assess the similarity among plants within each identified cluster. The script provided below will facilitate this process. It will iterate through all CSV files located in the 'clusters_euclidean' directory. For each file, the script will list out plants whose names contain a specified target substring, accompanied by their respective cluster numbers.

# %%
import os
import pandas as pd

# Define the directory path where the cluster files are located
dir_path = './initial_data/clusters_euclidean'

# Define the substring of the plant name you are searching for
target_plant_substring = 'Cannabis sativa'  # replace with the substring of the actual plant name

# Iterate over all files in the directory
for filename in os.listdir(dir_path):
    # Check if the file is a CSV file
    if filename.endswith('_chemical_compositions.csv'):
        # Construct the full file path
        file_path = os.path.join(dir_path, filename)
        
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file_path, index_col=0)
        
        # Check if the target plant substring exists in any plant name in the DataFrame's index
        matching_plants = [plant for plant in df.index if target_plant_substring in plant]
        
        if matching_plants:
            # Extract the cluster number from the filename
            cluster_number = filename.split('_')[1]
            print(f'Plants containing the substring "{target_plant_substring}" are in cluster {cluster_number}:')
            print(matching_plants)
            print()  # Print a newline for readability
# Out:
# Plants containing the substring "Cannabis sativa" are in cluster 31:
# ['Marihuana (India) - Cannabis sativa L., fam. Cannabinaceae']
#
# Plants containing the substring "Cannabis sativa" are in cluster 54:
# ['Marihuana (Austria) - Cannabis sativa L., fam. Cannabinaceae']

# %% [markdown]
# Part 3 high similarity

# %% [markdown]
# This script will generate a PDF file for each high similarity pairs CSV file that contains a heatmap. The heatmap shows the similarity scores between pairs of plants.To cluster plants that are most similar to each other together in the heatmap, we can use hierarchical clustering which creates a tree of clusters, which we can then cut at a certain level to create a heat map where similar items are placed next to each other.
#
# To create meaningful titles for our heatmaps, we will extract the family names from the plant names, identify the unique families within each cluster, and then use this information to create a title that reflects the commonality among the plants in the cluster.

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re
import textwrap
# !pip install plotly


# Function to extract family names
def extract_family(plant_name):
    match = re.search(r'fam\. ?(\w+)', plant_name)
    if match:
        return match.group(1)
    return None

# Set paths
path = './initial_data/clusters_euclidean/'
output_dir = './initial_data/clusters_euclidean/heatmaps/'

# Create output directory if it does not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load cluster files
cluster_files = [file for file in os.listdir(path) if 'plant_similarities' in file]
print(f"Found {len(cluster_files)} cluster files.")

for cluster_file in cluster_files:
    print(f"Processing {cluster_file}...")
    
    # Load similarity data
    similarity_df = pd.read_csv(path + cluster_file, index_col=0)

    # Extract family names from plant names and identify unique families
    families = set(extract_family(name) for name in similarity_df.index if extract_family(name) is not None)
    common_families = ', '.join(families)

    # Wrap the family names in the title without breaking words
    max_chars_per_line = 50
    wrapper = textwrap.TextWrapper(width=max_chars_per_line, break_long_words=False, break_on_hyphens=False)
    wrapped_families = wrapper.fill(text=common_families)

    # Create a title for the heatmap with line breaks for readability
    cluster_number = re.search(r'\d+', cluster_file).group()  # Extract cluster number from file name
    title = f"Cluster {cluster_number} Heatmap:\nCommon Families - {wrapped_families}"



    # Calculate the font size based on cluster size
    num_plants = len(similarity_df)
    max_cluster_size = 100
    font_ratio = num_plants / max_cluster_size
    font_size = max(8, int(8 * font_ratio))
    annot_font_size = max(6, int(6 * font_ratio))  # Adjust font size for annotations
    
    # Create a mask for the mirror part of the heatmap
    mask = np.triu(np.ones_like(similarity_df, dtype=bool))
    
    # Create a figure and axes
    fig, ax = plt.subplots(figsize=(40, 30))
    
    # Visualize the similarity scores using a masked heatmap
    heatmap = sns.heatmap(similarity_df, cmap="YlGnBu", mask=mask, ax=ax,
                          cbar_kws={'label': 'Similarity Score', 'format': '%.1f'},
                          annot=True, fmt=".1f", annot_kws={'fontsize': annot_font_size})  # Adjust font size
    
    # Set the title for the heatmap
    ax.set_title(title, fontsize=font_size)
    
    # Add a legend explaining the heatmap colors
    cbar = heatmap.collections[0].colorbar
    cbar.set_label('Similarity Score Legend')
    
    # Save the heatmap as a vector-based PDF file
    output_file = cluster_file.replace('_plant_similarities.csv', '.pdf')
    output_path = os.path.join(output_dir, output_file)
    fig.savefig(output_path, format='pdf', bbox_inches='tight')
    plt.close()
    
print("All done.")
# Out:
# Requirement already satisfied: plotly in /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages (from plotly) (23.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Found 160 cluster files.
# Processing cluster_105_plant_similarities.csv...
# Processing cluster_34_plant_similarities.csv...
# Processing cluster_41_plant_similarities.csv...
# Processing cluster_80_plant_similarities.csv...
# Processing cluster_141_plant_similarities.csv...
# Processing cluster_70_plant_similarities.csv...
# Processing cluster_5_plant_similarities.csv...
# Processing cluster_134_plant_similarities.csv...
# Processing cluster_102_plant_similarities.csv...
# Processing cluster_33_plant_similarities.csv...
# Processing cluster_46_plant_similarities.csv...
# Processing cluster_87_plant_similarities.csv...
# Processing cluster_39_plant_similarities.csv...
# Processing cluster_108_plant_similarities.csv...
# Processing cluster_139_plant_similarities.csv...
# Processing cluster_8_plant_similarities.csv...
# Processing cluster_146_plant_similarities.csv...
# Processing cluster_77_plant_similarities.csv...
# Processing cluster_2_plant_similarities.csv...
# Processing cluster_133_plant_similarities.csv...
# Processing cluster_45_plant_similarities.csv...
# Processing cluster_84_plant_similarities.csv...
# Processing cluster_30_plant_similarities.csv...
# Processing cluster_101_plant_similarities.csv...
# Processing cluster_130_plant_similarities.csv...
# Processing cluster_74_plant_similarities.csv...
# Processing cluster_145_plant_similarities.csv...
# Processing cluster_1_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_48_plant_similarities.csv...
# Processing cluster_89_plant_similarities.csv...
# Processing cluster_42_plant_similarities.csv...
# Processing cluster_83_plant_similarities.csv...
# Processing cluster_37_plant_similarities.csv...
# Processing cluster_106_plant_similarities.csv...
# Processing cluster_137_plant_similarities.csv...
# Processing cluster_73_plant_similarities.csv...
# Processing cluster_142_plant_similarities.csv...
# Processing cluster_6_plant_similarities.csv...
# Processing cluster_148_plant_similarities.csv...
# Processing cluster_79_plant_similarities.csv...
# Processing cluster_149_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_78_plant_similarities.csv...
# Processing cluster_136_plant_similarities.csv...
# Processing cluster_7_plant_similarities.csv...
# Processing cluster_72_plant_similarities.csv...
# Processing cluster_143_plant_similarities.csv...
# Processing cluster_82_plant_similarities.csv...
# Processing cluster_43_plant_similarities.csv...
# Processing cluster_36_plant_similarities.csv...
# Processing cluster_107_plant_similarities.csv...
# Processing cluster_88_plant_similarities.csv...
# Processing cluster_49_plant_similarities.csv...
# Processing cluster_131_plant_similarities.csv...
# Processing cluster_0_plant_similarities.csv...
# Processing cluster_75_plant_similarities.csv...
# Processing cluster_144_plant_similarities.csv...
# Processing cluster_85_plant_similarities.csv...
# Processing cluster_44_plant_similarities.csv...
# Processing cluster_31_plant_similarities.csv...
# Processing cluster_100_plant_similarities.csv...
# Processing cluster_3_plant_similarities.csv...
# Processing cluster_147_plant_similarities.csv...
# Processing cluster_76_plant_similarities.csv...
# Processing cluster_132_plant_similarities.csv...
# Processing cluster_138_plant_similarities.csv...
# Processing cluster_9_plant_similarities.csv...
# Processing cluster_38_plant_similarities.csv...
# Processing cluster_109_plant_similarities.csv...
# Processing cluster_103_plant_similarities.csv...
# Processing cluster_32_plant_similarities.csv...
# Processing cluster_86_plant_similarities.csv...
# Processing cluster_47_plant_similarities.csv...
# Processing cluster_4_plant_similarities.csv...
# Processing cluster_140_plant_similarities.csv...
# Processing cluster_71_plant_similarities.csv...
# Processing cluster_135_plant_similarities.csv...
# Processing cluster_104_plant_similarities.csv...
# Processing cluster_35_plant_similarities.csv...
# Processing cluster_81_plant_similarities.csv...
# Processing cluster_40_plant_similarities.csv...
# Processing cluster_158_plant_similarities.csv...
# Processing cluster_69_plant_similarities.csv...
# Processing cluster_63_plant_similarities.csv...
# Processing cluster_152_plant_similarities.csv...
# Processing cluster_16_plant_similarities.csv...
# Processing cluster_127_plant_similarities.csv...
# Processing cluster_27_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_116_plant_similarities.csv...
# Processing cluster_52_plant_similarities.csv...
# Processing cluster_93_plant_similarities.csv...
# Processing cluster_58_plant_similarities.csv...
# Processing cluster_99_plant_similarities.csv...
# Processing cluster_64_plant_similarities.csv...
# Processing cluster_155_plant_similarities.csv...
# Processing cluster_11_plant_similarities.csv...
# Processing cluster_120_plant_similarities.csv...
# Processing cluster_20_plant_similarities.csv...
# Processing cluster_111_plant_similarities.csv...
# Processing cluster_55_plant_similarities.csv...
# Processing cluster_94_plant_similarities.csv...
# Processing cluster_123_plant_similarities.csv...
# Processing cluster_12_plant_similarities.csv...
# Processing cluster_156_plant_similarities.csv...
# Processing cluster_67_plant_similarities.csv...
# Processing cluster_18_plant_similarities.csv...
# Processing cluster_129_plant_similarities.csv...
# Processing cluster_29_plant_similarities.csv...
# Processing cluster_118_plant_similarities.csv...
# Processing cluster_56_plant_similarities.csv...
# Processing cluster_97_plant_similarities.csv...
# Processing cluster_112_plant_similarities.csv...
# Processing cluster_23_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_124_plant_similarities.csv...
# Processing cluster_15_plant_similarities.csv...
# Processing cluster_151_plant_similarities.csv...
# Processing cluster_60_plant_similarities.csv...
# Processing cluster_51_plant_similarities.csv...
# Processing cluster_90_plant_similarities.csv...
# Processing cluster_115_plant_similarities.csv...
# Processing cluster_24_plant_similarities.csv...
# Processing cluster_91_plant_similarities.csv...
# Processing cluster_50_plant_similarities.csv...
# Processing cluster_114_plant_similarities.csv...
# Processing cluster_25_plant_similarities.csv...
# Processing cluster_125_plant_similarities.csv...
# Processing cluster_14_plant_similarities.csv...
# Processing cluster_150_plant_similarities.csv...
# Processing cluster_61_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_96_plant_similarities.csv...
# Processing cluster_57_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_113_plant_similarities.csv...
# Processing cluster_22_plant_similarities.csv...
# Processing cluster_28_plant_similarities.csv...
# Processing cluster_119_plant_similarities.csv...
# Processing cluster_19_plant_similarities.csv...
# Processing cluster_128_plant_similarities.csv...
# Processing cluster_122_plant_similarities.csv...
# Processing cluster_13_plant_similarities.csv...
# Processing cluster_157_plant_similarities.csv...
# Processing cluster_66_plant_similarities.csv...
# Processing cluster_21_plant_similarities.csv...
# Processing cluster_110_plant_similarities.csv...
# Processing cluster_95_plant_similarities.csv...
# Processing cluster_54_plant_similarities.csv...
# Processing cluster_65_plant_similarities.csv...
# Processing cluster_154_plant_similarities.csv...
# Processing cluster_10_plant_similarities.csv...
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mariiakokina/Documents/python3.9_env/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning:
#
# All-NaN slice encountered
# Processing cluster_121_plant_similarities.csv...
# Processing cluster_98_plant_similarities.csv...
# Processing cluster_59_plant_similarities.csv...
# Processing cluster_26_plant_similarities.csv...
# Processing cluster_117_plant_similarities.csv...
# Processing cluster_92_plant_similarities.csv...
# Processing cluster_53_plant_similarities.csv...
# Processing cluster_62_plant_similarities.csv...
# Processing cluster_153_plant_similarities.csv...
# Processing cluster_17_plant_similarities.csv...
# Processing cluster_126_plant_similarities.csv...
# Processing cluster_159_plant_similarities.csv...
# Processing cluster_68_plant_similarities.csv...
# All done.

# %% [markdown]
# Now we compare the chemical compositions of plants with high similarity scores 90% and identify the most present chemicals that contributes to the similarity between them. After creating the results_df DataFrame, we remove duplicates based on the chemical compositions by rounding the columns 'First Most Present Amount', 'Second ...' and so on.. to two decimal places using .round() method. Then, we drop duplicates based on these rounded columns.

# %% [markdown]
# here's the code modified to display the top 5 present chemicals in order to later create a barplot

# %%
import pandas as pd
from tqdm import tqdm
import os

# Define the path to the cluster data
data_path = './initial_data/clusters_euclidean/'

# Get a list of cluster files
cluster_files = [file for file in os.listdir(data_path) if file.startswith('cluster_')]

# Iterate over the cluster files
for cluster_file in cluster_files:
    # Extract the cluster number from the file name
    cluster_num = cluster_file.split('_')[1]
    
    # Load the chemical compositions data
    composition_file = os.path.join(data_path, f'cluster_{cluster_num}_chemical_compositions.csv')
    chemical_compositions = pd.read_csv(composition_file, index_col=0)

    # Load the plant similarities data
    similarities_file = os.path.join(data_path, f'cluster_{cluster_num}_plant_similarities.csv')
    plant_similarities = pd.read_csv(similarities_file, index_col=0)

    # Create an empty DataFrame to store the results
    results_df = pd.DataFrame(columns=['Plant 1', 'Plant 2', 'Similarity Score', 'First Most Present Chemical',
                                       'First Most Present Amount', 'Second Most Present Chemical',
                                       'Second Most Present Amount', 'Third Most Present Chemical',
                                       'Third Most Present Amount', 'Fourth Most Present Chemical',
                                       'Fourth Most Present Amount', 'Fifth Most Present Chemical',
                                       'Fifth Most Present Amount'])

    # Iterate over the rows of the plant similarities data
    for index, row in tqdm(plant_similarities.iterrows(), total=len(plant_similarities), desc=f'Processing Cluster {cluster_num}'):
        plant_1 = index  # Plant 1 name
        for column in row.index:
            if index != column:  # Exclude diagonal comparisons
                similarity_score = row[column]  # Similarity score
                if similarity_score >= 0.9:  # Filter similarity score
                    plant_2 = column  # Plant 2 name

                    # Get the chemical composition of the two plants
                    composition_1 = chemical_compositions.loc[plant_1]
                    composition_2 = chemical_compositions.loc[plant_2]

                    # Find the chemicals present in both plants
                    common_chemicals = set(composition_1.index) & set(composition_2.index)

                    # Find the most present chemical and its amount in each plant
                    most_present_chemicals = [None]*5
                    max_amounts = [0]*5
                    for chemical in common_chemicals:
                        amount_1 = composition_1[chemical]
                        amount_2 = composition_2[chemical]
                        for i in range(5):
                            if amount_1 > max_amounts[i]:
                                for j in range(4, i, -1):
                                    max_amounts[j] = max_amounts[j-1]
                                    most_present_chemicals[j] = most_present_chemicals[j-1]
                                max_amounts[i] = amount_1
                                most_present_chemicals[i] = chemical
                                break

                    # Create a temporary DataFrame to store the current result
                    temp_df = pd.DataFrame({
                        'Plant 1': [plant_1],
                        'Plant 2': [plant_2],
                        'Similarity Score': [similarity_score],
                        'First Most Present Chemical': [most_present_chemicals[0]],
                        'First Most Present Amount': [max_amounts[0]],
                        'Second Most Present Chemical': [most_present_chemicals[1]],
                        'Second Most Present Amount': [max_amounts[1]],
                        'Third Most Present Chemical': [most_present_chemicals[2]],
                        'Third Most Present Amount': [max_amounts[2]],
                        'Fourth Most Present Chemical': [most_present_chemicals[3]],
                        'Fourth Most Present Amount': [max_amounts[3]],
                        'Fifth Most Present Chemical': [most_present_chemicals[4]],
                        'Fifth Most Present Amount': [max_amounts[4]]
                    })

                    # Concatenate the temporary DataFrame with the results DataFrame
                    results_df = pd.concat([results_df, temp_df], ignore_index=True)

    # Remove duplicates based on the chemical compositions
    results_df_deduplicated = results_df.round({'First Most Present Amount': 2,
                                                'Second Most Present Amount': 2,
                                                'Third Most Present Amount': 2,
                                                'Fourth Most Present Amount': 2,
                                                'Fifth Most Present Amount': 2}).drop_duplicates(subset=['First Most Present Amount',
                                                                                                      'Second Most Present Chemical',
                                                                                                      'Second Most Present Amount',
                                                                                                      'Third Most Present Chemical',
                                                                                                      'Third Most Present Amount',
                                                                                                      'Fourth Most Present Chemical',
                                                                                                      'Fourth Most Present Amount',
                                                                                                      'Fifth Most Present Chemical',
                                                                                                      'Fifth Most Present Amount'])

    # Save the results in a folder with the cluster name
    results_path = os.path.join(data_path, f'cluster_{cluster_num}')
    
    # Ensure the directory exists
    if not os.path.exists(results_path):
        os.makedirs(results_path)

    # Save the results dataframe to a csv file with designated name
    filename = f'high_similarity_plants_top5chemicals.csv'
    results_df_deduplicated.to_csv(os.path.join(results_path, filename), index=False)
# Out:
# Processing Cluster 71: 100%|███| 27/27 [00:00<00:00, 20867.18it/s]
# Processing Cluster 105: 100%|████| 9/9 [00:00<00:00, 30815.29it/s]
# Processing Cluster 152: 100%|██| 15/15 [00:00<00:00, 25731.93it/s]
# Processing Cluster 34: 100%|███| 37/37 [00:00<00:00, 17796.93it/s]
# Processing Cluster 41: 100%|█████| 16/16 [00:00<00:00, 377.06it/s]
# Processing Cluster 155: 100%|████| 2/2 [00:00<00:00, 20213.51it/s]
# Processing Cluster 105: 100%|████| 9/9 [00:00<00:00, 31909.33it/s]
# Processing Cluster 80: 100%|█████| 3/3 [00:00<00:00, 23431.87it/s]
# Processing Cluster 28: 100%|███| 19/19 [00:00<00:00, 27170.74it/s]
# Processing Cluster 130: 100%|███| 44/44 [00:00<00:00, 1001.32it/s]
# Processing Cluster 137: 100%|████| 59/59 [00:00<00:00, 895.28it/s]
# Processing Cluster 108: 100%|██| 35/35 [00:00<00:00, 19114.67it/s]
# Processing Cluster 79: 100%|█████| 3/3 [00:00<00:00, 25890.77it/s]
# Processing Cluster 123: 100%|██████| 7/7 [00:00<00:00, 327.65it/s]
# Processing Cluster 141: 100%|████| 2/2 [00:00<00:00, 20610.83it/s]
# Processing Cluster 97: 100%|████| 43/43 [00:00<00:00, 1785.27it/s]
# Processing Cluster 70: 100%|█████| 3/3 [00:00<00:00, 24197.91it/s]
# Processing Cluster 101: 100%|██| 63/63 [00:00<00:00, 12200.06it/s]
# Processing Cluster 20: 100%|████| 42/42 [00:00<00:00, 1813.23it/s]
# Processing Cluster 5: 100%|██████| 35/35 [00:00<00:00, 165.74it/s]
# Processing Cluster 106: 100%|████| 23/23 [00:00<00:00, 995.72it/s]
# Processing Cluster 139: 100%|████| 11/11 [00:00<00:00, 513.32it/s]
# Processing Cluster 57: 100%|█████| 5/5 [00:00<00:00, 26783.55it/s]
# Processing Cluster 134: 100%|████| 3/3 [00:00<00:00, 23045.63it/s]
# Processing Cluster 154: 100%|████| 1/1 [00:00<00:00, 15650.39it/s]
# Processing Cluster 118: 100%|████| 3/3 [00:00<00:00, 23831.27it/s]
# Processing Cluster 102: 100%|██| 19/19 [00:00<00:00, 26634.95it/s]
# Processing Cluster 33: 100%|█████| 11/11 [00:00<00:00, 514.07it/s]
# Processing Cluster 46: 100%|███| 14/14 [00:00<00:00, 30631.33it/s]
# Processing Cluster 87: 100%|█████| 7/7 [00:00<00:00, 30808.11it/s]
# Processing Cluster 136: 100%|████| 8/8 [00:00<00:00, 30868.84it/s]
# Processing Cluster 82: 100%|█████| 7/7 [00:00<00:00, 30456.56it/s]
# Processing Cluster 35: 100%|███| 21/21 [00:00<00:00, 26090.16it/s]
# Processing Cluster 154: 100%|████| 1/1 [00:00<00:00, 12985.46it/s]
# Processing Cluster 42: 100%|█████| 14/14 [00:00<00:00, 637.43it/s]
# Processing Cluster 39: 100%|████| 61/61 [00:00<00:00, 2186.55it/s]
# Processing Cluster 6: 100%|███████| 60/60 [00:03<00:00, 18.44it/s]
# Processing Cluster 108: 100%|██| 35/35 [00:00<00:00, 19030.42it/s]
# Processing Cluster 141: 100%|████| 2/2 [00:00<00:00, 16288.56it/s]
# Processing Cluster 153: 100%|████| 5/5 [00:00<00:00, 29959.31it/s]
# Processing Cluster 64: 100%|███████| 6/6 [00:00<00:00, 284.61it/s]
# Processing Cluster 107: 100%|███| 66/66 [00:00<00:00, 2488.60it/s]
# Processing Cluster 138: 100%|████| 8/8 [00:00<00:00, 31506.51it/s]
# Processing Cluster 139: 100%|████| 11/11 [00:00<00:00, 499.02it/s]
# Processing Cluster 100: 100%|████| 2/2 [00:00<00:00, 18355.82it/s]
# Processing Cluster 13: 100%|███| 17/17 [00:00<00:00, 28050.03it/s]
# Processing Cluster 8: 100%|███████| 64/64 [00:00<00:00, 88.55it/s]
# Processing Cluster 110: 100%|████| 4/4 [00:00<00:00, 26011.19it/s]
# Processing Cluster 146: 100%|██████| 7/7 [00:00<00:00, 337.32it/s]
# Processing Cluster 136: 100%|████| 8/8 [00:00<00:00, 33520.91it/s]
# Processing Cluster 77: 100%|██████| 17/17 [00:00<00:00, 62.99it/s]
# Processing Cluster 149: 100%|████| 1/1 [00:00<00:00, 14768.68it/s]
# Processing Cluster 109: 100%|████| 2/2 [00:00<00:00, 19021.79it/s]
# Processing Cluster 2: 100%|████| 18/18 [00:00<00:00, 26915.32it/s]
# Processing Cluster 131: 100%|████| 2/2 [00:00<00:00, 20610.83it/s]
# Processing Cluster 133: 100%|████| 4/4 [00:00<00:00, 26173.50it/s]
# Processing Cluster 51: 100%|█████| 20/20 [00:00<00:00, 905.21it/s]
# Processing Cluster 8: 100%|███████| 64/64 [00:00<00:00, 87.25it/s]
# Processing Cluster 139: 100%|████| 11/11 [00:00<00:00, 508.81it/s]
# Processing Cluster 56: 100%|█████| 82/82 [00:00<00:00, 514.83it/s]
# Processing Cluster 9: 100%|█████| 52/52 [00:00<00:00, 1039.09it/s]
# Processing Cluster 69: 100%|███████| 9/9 [00:00<00:00, 415.30it/s]
# Processing Cluster 60: 100%|█████| 42/42 [00:00<00:00, 319.07it/s]
# Processing Cluster 45: 100%|███████| 5/5 [00:00<00:00, 226.15it/s]
# Processing Cluster 6: 100%|███████| 60/60 [00:03<00:00, 18.48it/s]
# Processing Cluster 94: 100%|█████| 7/7 [00:00<00:00, 30679.34it/s]
# Processing Cluster 117: 100%|████| 12/12 [00:00<00:00, 567.94it/s]
# Processing Cluster 84: 100%|██| 126/126 [00:00<00:00, 1195.59it/s]
# Processing Cluster 14: 100%|████| 127/127 [00:09<00:00, 12.96it/s]
# Processing Cluster 93: 100%|█████| 10/10 [00:00<00:00, 471.39it/s]
# Processing Cluster 63: 100%|█████| 7/7 [00:00<00:00, 29928.77it/s]
# Processing Cluster 1: 100%|█████| 128/128 [01:02<00:00,  2.05it/s]
# Processing Cluster 67: 100%|█████| 13/13 [00:00<00:00, 208.51it/s]
# Processing Cluster 30: 100%|█████| 33/33 [00:00<00:00, 391.02it/s]
# Processing Cluster 101: 100%|██| 63/63 [00:00<00:00, 11732.06it/s]
# Processing Cluster 58: 100%|█████| 38/38 [00:00<00:00, 595.16it/s]
# Processing Cluster 146: 100%|██████| 7/7 [00:00<00:00, 332.72it/s]
# Processing Cluster 1: 100%|█████| 128/128 [01:02<00:00,  2.04it/s]
# Processing Cluster 45: 100%|███████| 5/5 [00:00<00:00, 230.28it/s]
# Processing Cluster 33: 100%|█████| 11/11 [00:00<00:00, 506.47it/s]
# Processing Cluster 130: 100%|████| 44/44 [00:00<00:00, 875.41it/s]
# Processing Cluster 32: 100%|█████| 5/5 [00:00<00:00, 31068.92it/s]
# Processing Cluster 74: 100%|███| 10/10 [00:00<00:00, 33000.03it/s]
# Processing Cluster 85: 100%|█████| 21/21 [00:00<00:00, 963.52it/s]
# Processing Cluster 131: 100%|████| 2/2 [00:00<00:00, 22489.57it/s]
# Processing Cluster 145: 100%|████| 1/1 [00:00<00:00, 17476.27it/s]
# Processing Cluster 34: 100%|███| 37/37 [00:00<00:00, 17619.12it/s]
# Processing Cluster 1: 100%|█████| 128/128 [01:02<00:00,  2.03it/s]
# Processing Cluster 0: 100%|████| 23/23 [00:00<00:00, 23023.63it/s]
# Processing Cluster 66: 100%|█████| 2/2 [00:00<00:00, 13508.23it/s]
# Processing Cluster 92: 100%|█████| 9/9 [00:00<00:00, 29491.20it/s]
# Processing Cluster 59: 100%|█████| 2/2 [00:00<00:00, 18196.55it/s]
# Processing Cluster 153: 100%|████| 5/5 [00:00<00:00, 27485.61it/s]
# Processing Cluster 50: 100%|█████| 8/8 [00:00<00:00, 32768.00it/s]
# Processing Cluster 95: 100%|█████| 35/35 [00:00<00:00, 132.34it/s]
# Processing Cluster 27: 100%|█████| 31/31 [00:00<00:00, 285.80it/s]
# Processing Cluster 90: 100%|█████| 5/5 [00:00<00:00, 29248.98it/s]
# Processing Cluster 61: 100%|█████| 8/8 [00:00<00:00, 29641.72it/s]
# Processing Cluster 124: 100%|████| 28/28 [00:00<00:00, 113.85it/s]
# Processing Cluster 48: 100%|█████| 11/11 [00:00<00:00, 472.48it/s]
# Processing Cluster 7: 100%|██████| 61/61 [00:00<00:00, 342.61it/s]
# Processing Cluster 89: 100%|█████| 13/13 [00:00<00:00, 554.77it/s]
# Processing Cluster 42: 100%|█████| 14/14 [00:00<00:00, 616.71it/s]
# Processing Cluster 57: 100%|█████| 5/5 [00:00<00:00, 27306.67it/s]
# Processing Cluster 83: 100%|████| 71/71 [00:00<00:00, 2318.38it/s]
# Processing Cluster 68: 100%|█████| 5/5 [00:00<00:00, 10371.67it/s]
# Processing Cluster 50: 100%|█████| 8/8 [00:00<00:00, 30868.84it/s]
# Processing Cluster 9: 100%|█████| 52/52 [00:00<00:00, 1008.32it/s]
# Processing Cluster 37: 100%|████| 75/75 [00:00<00:00, 2640.30it/s]
# Processing Cluster 106: 100%|███| 23/23 [00:00<00:00, 1021.94it/s]
# Processing Cluster 98: 100%|█████| 2/2 [00:00<00:00, 18396.07it/s]
# Processing Cluster 137: 100%|████| 59/59 [00:00<00:00, 857.12it/s]
# Processing Cluster 73: 100%|███████| 5/5 [00:00<00:00, 231.44it/s]
# Processing Cluster 58: 100%|█████| 38/38 [00:00<00:00, 545.77it/s]
# Processing Cluster 142: 100%|████| 2/2 [00:00<00:00, 20410.24it/s]
# Processing Cluster 6: 100%|███████| 60/60 [00:03<00:00, 18.37it/s]
# Processing Cluster 148: 100%|███| 38/38 [00:00<00:00, 1603.42it/s]
# Processing Cluster 79: 100%|█████| 3/3 [00:00<00:00, 24769.51it/s]
# Processing Cluster 102: 100%|██| 19/19 [00:00<00:00, 26283.57it/s]
# Processing Cluster 35: 100%|███| 21/21 [00:00<00:00, 25274.14it/s]
# Processing Cluster 76: 100%|███| 18/18 [00:00<00:00, 27040.64it/s]
# Processing Cluster 32: 100%|█████| 5/5 [00:00<00:00, 29046.43it/s]
# Processing Cluster 10: 100%|█████| 45/45 [00:00<00:00, 179.15it/s]
# Processing Cluster 149: 100%|████| 1/1 [00:00<00:00, 13530.01it/s]
# Processing Cluster 107: 100%|███| 66/66 [00:00<00:00, 2502.36it/s]
# Processing Cluster 78: 100%|███| 484/484 [00:02<00:00, 194.52it/s]
# Processing Cluster 73: 100%|███████| 5/5 [00:00<00:00, 234.98it/s]
# Processing Cluster 17: 100%|█████| 9/9 [00:00<00:00, 31694.99it/s]
# Processing Cluster 28: 100%|███| 19/19 [00:00<00:00, 25740.24it/s]
# Processing Cluster 21: 100%|█████| 45/45 [00:00<00:00, 697.33it/s]
# Processing Cluster 136: 100%|████| 8/8 [00:00<00:00, 33487.46it/s]
# Processing Cluster 129: 100%|██████| 9/9 [00:00<00:00, 410.36it/s]
# Processing Cluster 26: 100%|█████| 8/8 [00:00<00:00, 31506.51it/s]
# Processing Cluster 7: 100%|██████| 61/61 [00:00<00:00, 358.81it/s]
# Processing Cluster 19: 100%|█████| 8/8 [00:00<00:00, 32800.03it/s]
# Processing Cluster 72: 100%|███| 12/12 [00:00<00:00, 30066.70it/s]
# Processing Cluster 143: 100%|████| 5/5 [00:00<00:00, 31679.03it/s]
# Processing Cluster 82: 100%|█████| 7/7 [00:00<00:00, 32263.88it/s]
# Processing Cluster 72: 100%|███| 12/12 [00:00<00:00, 31496.65it/s]
# Processing Cluster 43: 100%|███| 24/24 [00:00<00:00, 23618.79it/s]
# Processing Cluster 86: 100%|█████| 5/5 [00:00<00:00, 31068.92it/s]
# Processing Cluster 36: 100%|███| 53/53 [00:00<00:00, 13802.19it/s]
# Processing Cluster 107: 100%|███| 66/66 [00:00<00:00, 2442.81it/s]
# Processing Cluster 81: 100%|█████| 9/9 [00:00<00:00, 32017.59it/s]
# Processing Cluster 75: 100%|████| 88/88 [00:00<00:00, 1705.75it/s]
# Processing Cluster 88: 100%|███| 15/15 [00:00<00:00, 29006.25it/s]
# Processing Cluster 156: 100%|███| 54/54 [00:00<00:00, 2154.83it/s]
# Processing Cluster 55: 100%|█████| 4/4 [00:00<00:00, 28976.19it/s]
# Processing Cluster 43: 100%|███| 24/24 [00:00<00:00, 23859.52it/s]
# Processing Cluster 95: 100%|█████| 35/35 [00:00<00:00, 140.82it/s]
# Processing Cluster 22: 100%|█████| 58/58 [00:00<00:00, 250.01it/s]
# Processing Cluster 88: 100%|███| 15/15 [00:00<00:00, 28314.38it/s]
# Processing Cluster 121: 100%|████| 2/2 [00:00<00:00, 20410.24it/s]
# Processing Cluster 44: 100%|█████| 5/5 [00:00<00:00, 27630.46it/s]
# Processing Cluster 49: 100%|█████| 28/28 [00:00<00:00, 651.64it/s]
# Processing Cluster 27: 100%|█████| 31/31 [00:00<00:00, 292.61it/s]
# Processing Cluster 18: 100%|████| 31/31 [00:00<00:00, 1366.97it/s]
# Processing Cluster 20: 100%|████| 42/42 [00:00<00:00, 1802.03it/s]
# Processing Cluster 19: 100%|█████| 8/8 [00:00<00:00, 29001.24it/s]
# Processing Cluster 16: 100%|███| 13/13 [00:00<00:00, 31719.58it/s]
# Processing Cluster 131: 100%|████| 2/2 [00:00<00:00, 21290.88it/s]
# Processing Cluster 29: 100%|█████| 59/59 [00:00<00:00, 346.62it/s]
# Processing Cluster 143: 100%|████| 5/5 [00:00<00:00, 30526.23it/s]
# Processing Cluster 40: 100%|█████| 19/19 [00:00<00:00, 872.41it/s]
# Processing Cluster 4: 100%|██████| 27/27 [00:00<00:00, 184.60it/s]
# Processing Cluster 80: 100%|█████| 3/3 [00:00<00:00, 24385.49it/s]
# Processing Cluster 37: 100%|████| 75/75 [00:00<00:00, 2703.65it/s]
# Processing Cluster 11: 100%|██████| 38/38 [00:00<00:00, 45.02it/s]
# Processing Cluster 134: 100%|████| 3/3 [00:00<00:00, 23087.91it/s]
# Processing Cluster 0: 100%|████| 23/23 [00:00<00:00, 24129.31it/s]
# Processing Cluster 75: 100%|████| 88/88 [00:00<00:00, 1709.72it/s]
# Processing Cluster 144: 100%|████| 21/21 [00:00<00:00, 487.93it/s]
# Processing Cluster 85: 100%|█████| 21/21 [00:00<00:00, 965.83it/s]
# Processing Cluster 112: 100%|████| 1/1 [00:00<00:00, 16980.99it/s]
# Processing Cluster 44: 100%|█████| 5/5 [00:00<00:00, 29579.01it/s]
# Processing Cluster 11: 100%|██████| 38/38 [00:00<00:00, 43.89it/s]
# Processing Cluster 45: 100%|███████| 5/5 [00:00<00:00, 235.41it/s]
# Processing Cluster 66: 100%|█████| 2/2 [00:00<00:00, 19239.93it/s]
# Processing Cluster 31: 100%|█████| 34/34 [00:00<00:00, 773.46it/s]
# Processing Cluster 100: 100%|████| 2/2 [00:00<00:00, 20867.18it/s]
# Processing Cluster 89: 100%|█████| 13/13 [00:00<00:00, 593.66it/s]
# Processing Cluster 42: 100%|█████| 14/14 [00:00<00:00, 647.93it/s]
# Processing Cluster 74: 100%|███| 10/10 [00:00<00:00, 32239.08it/s]
# Processing Cluster 88: 100%|███| 15/15 [00:00<00:00, 30437.62it/s]
# Processing Cluster 80: 100%|█████| 3/3 [00:00<00:00, 20262.34it/s]
# Processing Cluster 48: 100%|█████| 11/11 [00:00<00:00, 518.91it/s]
# Processing Cluster 87: 100%|█████| 7/7 [00:00<00:00, 31536.12it/s]
# Processing Cluster 73: 100%|███████| 5/5 [00:00<00:00, 234.47it/s]
# Processing Cluster 3: 100%|████| 22/22 [00:00<00:00, 25315.42it/s]
# Processing Cluster 147: 100%|████| 2/2 [00:00<00:00, 21076.90it/s]
# Processing Cluster 76: 100%|███| 18/18 [00:00<00:00, 27573.95it/s]
# Processing Cluster 113: 100%|████| 2/2 [00:00<00:00, 17119.61it/s]
# Processing Cluster 132: 100%|███| 30/30 [00:00<00:00, 1356.22it/s]
# Processing Cluster 114: 100%|██| 10/10 [00:00<00:00, 33000.03it/s]
# Processing Cluster 38: 100%|████| 80/80 [00:00<00:00, 1597.22it/s]
# Processing Cluster 138: 100%|████| 8/8 [00:00<00:00, 32263.88it/s]
# Processing Cluster 61: 100%|█████| 8/8 [00:00<00:00, 32545.52it/s]
# Processing Cluster 122: 100%|██| 18/18 [00:00<00:00, 26241.74it/s]
# Processing Cluster 9: 100%|█████| 52/52 [00:00<00:00, 1151.56it/s]
# Processing Cluster 16: 100%|███| 13/13 [00:00<00:00, 31015.90it/s]
# Processing Cluster 125: 100%|████| 2/2 [00:00<00:00, 15887.52it/s]
# Processing Cluster 115: 100%|███| 99/99 [00:00<00:00, 1718.69it/s]
# Processing Cluster 133: 100%|█████| 4/4 [00:00<00:00, 5548.02it/s]
# Processing Cluster 30: 100%|█████| 33/33 [00:00<00:00, 361.46it/s]
# Processing Cluster 87: 100%|█████| 7/7 [00:00<00:00, 31706.40it/s]
# Processing Cluster 38: 100%|████| 80/80 [00:00<00:00, 1521.29it/s]
# Processing Cluster 109: 100%|████| 2/2 [00:00<00:00, 15505.74it/s]
# Processing Cluster 149: 100%|████| 1/1 [00:00<00:00, 10082.46it/s]
# Processing Cluster 3: 100%|████| 22/22 [00:00<00:00, 24417.75it/s]
# Processing Cluster 47: 100%|█████| 23/23 [00:00<00:00, 150.75it/s]
# Processing Cluster 144: 100%|████| 21/21 [00:00<00:00, 469.58it/s]
# Processing Cluster 103: 100%|██████| 9/9 [00:00<00:00, 390.73it/s]
# Processing Cluster 140: 100%|████| 18/18 [00:00<00:00, 762.03it/s]
# Processing Cluster 32: 100%|█████| 5/5 [00:00<00:00, 30305.66it/s]
# Processing Cluster 86: 100%|█████| 5/5 [00:00<00:00, 28926.23it/s]
# Processing Cluster 147: 100%|████| 2/2 [00:00<00:00, 19418.07it/s]
# Processing Cluster 69: 100%|███████| 9/9 [00:00<00:00, 397.21it/s]
# Processing Cluster 47: 100%|█████| 23/23 [00:00<00:00, 145.47it/s]
# Processing Cluster 126: 100%|████| 17/17 [00:00<00:00, 742.72it/s]
# Processing Cluster 4: 100%|██████| 27/27 [00:00<00:00, 176.74it/s]
# Processing Cluster 25: 100%|█████| 19/19 [00:00<00:00, 293.24it/s]
# Processing Cluster 92: 100%|█████| 9/9 [00:00<00:00, 32181.36it/s]
# Processing Cluster 124: 100%|████| 28/28 [00:00<00:00, 122.61it/s]
# Processing Cluster 140: 100%|████| 18/18 [00:00<00:00, 824.10it/s]
# Processing Cluster 71: 100%|███| 27/27 [00:00<00:00, 22148.68it/s]
# Processing Cluster 135: 100%|████| 8/8 [00:00<00:00, 30421.06it/s]
# Processing Cluster 52: 100%|████| 33/33 [00:00<00:00, 1364.24it/s]
# Processing Cluster 151: 100%|██████| 5/5 [00:00<00:00, 222.21it/s]
# Processing Cluster 123: 100%|██████| 7/7 [00:00<00:00, 317.26it/s]
# Processing Cluster 108: 100%|██| 35/35 [00:00<00:00, 18705.48it/s]
# Processing Cluster 115: 100%|███| 99/99 [00:00<00:00, 1671.20it/s]
# Processing Cluster 112: 100%|████| 1/1 [00:00<00:00, 14122.24it/s]
# Processing Cluster 146: 100%|██████| 7/7 [00:00<00:00, 330.20it/s]
# Processing Cluster 159: 100%|████| 15/15 [00:00<00:00, 352.82it/s]
# Processing Cluster 141: 100%|████| 2/2 [00:00<00:00, 20610.83it/s]
# Processing Cluster 104: 100%|████| 5/5 [00:00<00:00, 29248.98it/s]
# Processing Cluster 74: 100%|███| 10/10 [00:00<00:00, 32768.00it/s]
# Processing Cluster 35: 100%|███| 21/21 [00:00<00:00, 25990.08it/s]
# Processing Cluster 148: 100%|███| 38/38 [00:00<00:00, 1666.74it/s]
# Processing Cluster 81: 100%|█████| 9/9 [00:00<00:00, 32486.00it/s]
# Processing Cluster 100: 100%|████| 2/2 [00:00<00:00, 19418.07it/s]
# Processing Cluster 40: 100%|█████| 19/19 [00:00<00:00, 857.36it/s]
# Processing Cluster 134: 100%|████| 3/3 [00:00<00:00, 24013.19it/s]
# Processing Cluster 158: 100%|██████| 6/6 [00:00<00:00, 273.50it/s]
# Processing Cluster 133: 100%|████| 4/4 [00:00<00:00, 23663.21it/s]
# Processing Cluster 158: 100%|██████| 6/6 [00:00<00:00, 278.37it/s]
# Processing Cluster 69: 100%|███████| 9/9 [00:00<00:00, 428.02it/s]
# Processing Cluster 105: 100%|████| 9/9 [00:00<00:00, 32853.56it/s]
# Processing Cluster 63: 100%|█████| 7/7 [00:00<00:00, 33288.13it/s]
# Processing Cluster 152: 100%|██| 15/15 [00:00<00:00, 29592.93it/s]
# Processing Cluster 75: 100%|████| 88/88 [00:00<00:00, 1687.41it/s]
# Processing Cluster 101: 100%|██| 63/63 [00:00<00:00, 12211.90it/s]
# Processing Cluster 102: 100%|██| 19/19 [00:00<00:00, 27023.32it/s]
# Processing Cluster 16: 100%|███| 13/13 [00:00<00:00, 31408.96it/s]
# Processing Cluster 127: 100%|████| 1/1 [00:00<00:00, 16710.37it/s]
# Processing Cluster 27: 100%|█████| 31/31 [00:00<00:00, 292.92it/s]
# Processing Cluster 24: 100%|█████| 23/23 [00:00<00:00, 358.33it/s]
# Processing Cluster 93: 100%|█████| 10/10 [00:00<00:00, 464.60it/s]
# Processing Cluster 156: 100%|███| 54/54 [00:00<00:00, 2175.30it/s]
# Processing Cluster 127: 100%|████| 1/1 [00:00<00:00, 13842.59it/s]
# Processing Cluster 116: 100%|████| 2/2 [00:00<00:00, 18315.74it/s]
# Processing Cluster 52: 100%|████| 33/33 [00:00<00:00, 1430.54it/s]
# Processing Cluster 150: 100%|████| 1/1 [00:00<00:00, 14768.68it/s]
# Processing Cluster 53: 100%|█████| 8/8 [00:00<00:00, 33893.37it/s]
# Processing Cluster 93: 100%|█████| 10/10 [00:00<00:00, 457.92it/s]
# Processing Cluster 151: 100%|██████| 5/5 [00:00<00:00, 239.36it/s]
# Processing Cluster 158: 100%|██████| 6/6 [00:00<00:00, 286.15it/s]
# Processing Cluster 58: 100%|█████| 38/38 [00:00<00:00, 591.80it/s]
# Processing Cluster 109: 100%|████| 2/2 [00:00<00:00, 19418.07it/s]
# Processing Cluster 99: 100%|█████| 5/5 [00:00<00:00, 28532.68it/s]
# Processing Cluster 103: 100%|██████| 9/9 [00:00<00:00, 410.77it/s]
# Processing Cluster 31: 100%|█████| 34/34 [00:00<00:00, 769.30it/s]
# Processing Cluster 86: 100%|█████| 5/5 [00:00<00:00, 29746.84it/s]
# Processing Cluster 132: 100%|███| 30/30 [00:00<00:00, 1330.15it/s]
# Processing Cluster 145: 100%|████| 1/1 [00:00<00:00, 14266.34it/s]
# Processing Cluster 2: 100%|████| 18/18 [00:00<00:00, 28244.47it/s]
# Processing Cluster 104: 100%|████| 5/5 [00:00<00:00, 30131.49it/s]
# Processing Cluster 46: 100%|███| 14/14 [00:00<00:00, 30051.31it/s]
# Processing Cluster 64: 100%|███████| 6/6 [00:00<00:00, 283.85it/s]
# Processing Cluster 132: 100%|███| 30/30 [00:00<00:00, 1317.24it/s]
# Processing Cluster 155: 100%|████| 2/2 [00:00<00:00, 20815.40it/s]
# Processing Cluster 68: 100%|█████| 5/5 [00:00<00:00, 28263.50it/s]
# Processing Cluster 135: 100%|████| 8/8 [00:00<00:00, 32928.79it/s]
# Processing Cluster 11: 100%|██████| 38/38 [00:00<00:00, 44.69it/s]
# Processing Cluster 120: 100%|██| 27/27 [00:00<00:00, 22292.56it/s]
# Processing Cluster 20: 100%|████| 42/42 [00:00<00:00, 1778.99it/s]
# Processing Cluster 111: 100%|████| 2/2 [00:00<00:00, 18001.30it/s]
# Processing Cluster 39: 100%|████| 61/61 [00:00<00:00, 2369.20it/s]
# Processing Cluster 55: 100%|█████| 4/4 [00:00<00:00, 25305.00it/s]
# Processing Cluster 159: 100%|████| 15/15 [00:00<00:00, 354.62it/s]
# Processing Cluster 94: 100%|█████| 7/7 [00:00<00:00, 33669.87it/s]
# Processing Cluster 60: 100%|█████| 42/42 [00:00<00:00, 327.55it/s]
# Processing Cluster 150: 100%|████| 1/1 [00:00<00:00, 14463.12it/s]
# Processing Cluster 114: 100%|██| 10/10 [00:00<00:00, 31068.92it/s]
# Processing Cluster 17: 100%|█████| 9/9 [00:00<00:00, 29308.02it/s]
# Processing Cluster 157: 100%|████| 3/3 [00:00<00:00, 26546.23it/s]
# Processing Cluster 10: 100%|█████| 45/45 [00:00<00:00, 173.69it/s]
# Processing Cluster 113: 100%|████| 2/2 [00:00<00:00, 18893.26it/s]
# Processing Cluster 123: 100%|██████| 7/7 [00:00<00:00, 329.57it/s]
# Processing Cluster 37: 100%|████| 75/75 [00:00<00:00, 2518.88it/s]
# Processing Cluster 12: 100%|█████| 22/22 [00:00<00:00, 345.64it/s]
# Processing Cluster 156: 100%|███| 54/54 [00:00<00:00, 2031.91it/s]
# Processing Cluster 67: 100%|█████| 13/13 [00:00<00:00, 208.40it/s]
# Processing Cluster 67: 100%|█████| 13/13 [00:00<00:00, 206.74it/s]
# Processing Cluster 30: 100%|█████| 33/33 [00:00<00:00, 378.60it/s]
# Processing Cluster 89: 100%|█████| 13/13 [00:00<00:00, 591.69it/s]
# Processing Cluster 39: 100%|████| 61/61 [00:00<00:00, 2305.83it/s]
# Processing Cluster 18: 100%|████| 31/31 [00:00<00:00, 1349.70it/s]
# Processing Cluster 49: 100%|█████| 28/28 [00:00<00:00, 638.08it/s]
# Processing Cluster 129: 100%|██████| 9/9 [00:00<00:00, 416.26it/s]
# Processing Cluster 55: 100%|█████| 4/4 [00:00<00:00, 27822.91it/s]
# Processing Cluster 29: 100%|█████| 59/59 [00:00<00:00, 345.98it/s]
# Processing Cluster 118: 100%|████| 3/3 [00:00<00:00, 26105.63it/s]
# Processing Cluster 52: 100%|████| 33/33 [00:00<00:00, 1412.93it/s]
# Processing Cluster 99: 100%|█████| 5/5 [00:00<00:00, 29248.98it/s]
# Processing Cluster 18: 100%|████| 31/31 [00:00<00:00, 1350.00it/s]
# Processing Cluster 41: 100%|█████| 16/16 [00:00<00:00, 381.45it/s]
# Processing Cluster 5: 100%|██████| 35/35 [00:00<00:00, 166.93it/s]
# Processing Cluster 90: 100%|█████| 5/5 [00:00<00:00, 29620.79it/s]
# Processing Cluster 2: 100%|████| 18/18 [00:00<00:00, 26705.86it/s]
# Processing Cluster 142: 100%|████| 2/2 [00:00<00:00, 18850.80it/s]
# Processing Cluster 56: 100%|█████| 82/82 [00:00<00:00, 523.99it/s]
# Processing Cluster 64: 100%|███████| 6/6 [00:00<00:00, 282.00it/s]
# Processing Cluster 97: 100%|████| 43/43 [00:00<00:00, 1806.55it/s]
# Processing Cluster 63: 100%|█████| 7/7 [00:00<00:00, 30679.34it/s]
# Processing Cluster 5: 100%|██████| 35/35 [00:00<00:00, 163.68it/s]
# Processing Cluster 97: 100%|████| 43/43 [00:00<00:00, 1794.15it/s]
# Processing Cluster 135: 100%|████| 8/8 [00:00<00:00, 32513.98it/s]
# Processing Cluster 112: 100%|████| 1/1 [00:00<00:00, 14873.42it/s]
# Processing Cluster 23: 100%|█████| 33/33 [00:00<00:00, 389.02it/s]
# Processing Cluster 81: 100%|█████| 9/9 [00:00<00:00, 32968.33it/s]
# Processing Cluster 36: 100%|███| 53/53 [00:00<00:00, 12968.04it/s]
# Processing Cluster 124: 100%|████| 28/28 [00:00<00:00, 121.59it/s]
# Processing Cluster 15: 100%|█████| 61/61 [00:00<00:00, 555.31it/s]
# Processing Cluster 151: 100%|██████| 5/5 [00:00<00:00, 235.10it/s]
# Processing Cluster 38: 100%|████| 80/80 [00:00<00:00, 1596.84it/s]
# Processing Cluster 60: 100%|█████| 42/42 [00:00<00:00, 328.58it/s]
# Processing Cluster 54: 100%|████| 26/26 [00:00<00:00, 1192.55it/s]
# Processing Cluster 157: 100%|████| 3/3 [00:00<00:00, 24013.19it/s]
# Processing Cluster 31: 100%|█████| 34/34 [00:00<00:00, 759.62it/s]
# Processing Cluster 120: 100%|██| 27/27 [00:00<00:00, 22279.40it/s]
# Processing Cluster 36: 100%|███| 53/53 [00:00<00:00, 13838.28it/s]
# Processing Cluster 94: 100%|█████| 7/7 [00:00<00:00, 28560.44it/s]
# Processing Cluster 23: 100%|█████| 33/33 [00:00<00:00, 385.50it/s]
# Processing Cluster 96: 100%|█████| 1/1 [00:00<00:00, 14074.85it/s]
# Processing Cluster 62: 100%|███| 10/10 [00:00<00:00, 33000.03it/s]
# Processing Cluster 4: 100%|██████| 27/27 [00:00<00:00, 179.64it/s]
# Processing Cluster 106: 100%|███| 23/23 [00:00<00:00, 1041.02it/s]
# Processing Cluster 3: 100%|████| 22/22 [00:00<00:00, 24554.20it/s]
# Processing Cluster 65: 100%|█████| 57/57 [00:00<00:00, 377.20it/s]
# Processing Cluster 91: 100%|█████| 3/3 [00:00<00:00, 24244.53it/s]
# Processing Cluster 72: 100%|███| 12/12 [00:00<00:00, 29143.98it/s]
# Processing Cluster 53: 100%|█████| 8/8 [00:00<00:00, 29986.09it/s]
# Processing Cluster 128: 100%|████| 2/2 [00:00<00:00, 21788.59it/s]
# Processing Cluster 51: 100%|█████| 20/20 [00:00<00:00, 918.77it/s]
# Processing Cluster 90: 100%|█████| 5/5 [00:00<00:00, 32263.88it/s]
# Processing Cluster 98: 100%|█████| 2/2 [00:00<00:00, 20460.02it/s]
# Processing Cluster 54: 100%|████| 26/26 [00:00<00:00, 1150.53it/s]
# Processing Cluster 115: 100%|███| 99/99 [00:00<00:00, 1826.39it/s]
# Processing Cluster 24: 100%|█████| 23/23 [00:00<00:00, 365.56it/s]
# Processing Cluster 91: 100%|█████| 3/3 [00:00<00:00, 25627.11it/s]
# Processing Cluster 99: 100%|█████| 5/5 [00:00<00:00, 27776.85it/s]
# Processing Cluster 49: 100%|█████| 28/28 [00:00<00:00, 627.30it/s]
# Processing Cluster 82: 100%|█████| 7/7 [00:00<00:00, 32586.16it/s]
# Processing Cluster 76: 100%|███| 18/18 [00:00<00:00, 28170.70it/s]
# Processing Cluster 50: 100%|█████| 8/8 [00:00<00:00, 32109.50it/s]
# Processing Cluster 114: 100%|██| 10/10 [00:00<00:00, 30504.03it/s]
# Processing Cluster 25: 100%|█████| 19/19 [00:00<00:00, 298.08it/s]
# Processing Cluster 59: 100%|█████| 2/2 [00:00<00:00, 20068.44it/s]
# Processing Cluster 71: 100%|███| 27/27 [00:00<00:00, 21828.49it/s]
# Processing Cluster 85: 100%|█████| 21/21 [00:00<00:00, 944.98it/s]
# Processing Cluster 78: 100%|███| 484/484 [00:02<00:00, 194.56it/s]
# Processing Cluster 103: 100%|██████| 9/9 [00:00<00:00, 403.35it/s]
# Processing Cluster 47: 100%|█████| 23/23 [00:00<00:00, 154.84it/s]
# Processing Cluster 40: 100%|█████| 19/19 [00:00<00:00, 871.16it/s]
# Processing Cluster 77: 100%|██████| 17/17 [00:00<00:00, 62.71it/s]
# Processing Cluster 51: 100%|█████| 20/20 [00:00<00:00, 905.07it/s]
# Processing Cluster 14: 100%|████| 127/127 [00:10<00:00, 12.54it/s]
# Processing Cluster 152: 100%|██| 15/15 [00:00<00:00, 30059.51it/s]
# Processing Cluster 13: 100%|███| 17/17 [00:00<00:00, 27604.79it/s]
# Processing Cluster 125: 100%|████| 2/2 [00:00<00:00, 20410.24it/s]
# Processing Cluster 26: 100%|█████| 8/8 [00:00<00:00, 30421.06it/s]
# Processing Cluster 91: 100%|█████| 3/3 [00:00<00:00, 20295.02it/s]
# Processing Cluster 125: 100%|████| 2/2 [00:00<00:00, 21290.88it/s]
# Processing Cluster 25: 100%|█████| 19/19 [00:00<00:00, 298.73it/s]
# Processing Cluster 14: 100%|████| 127/127 [00:10<00:00, 12.38it/s]
# Processing Cluster 22: 100%|█████| 58/58 [00:00<00:00, 234.76it/s]
# Processing Cluster 150: 100%|█████| 1/1 [00:00<00:00, 8683.86it/s]
# Processing Cluster 61: 100%|█████| 8/8 [00:00<00:00, 32109.50it/s]
# Processing Cluster 0: 100%|████| 23/23 [00:00<00:00, 22009.81it/s]
# Processing Cluster 44: 100%|█████| 5/5 [00:00<00:00, 24132.93it/s]
# Processing Cluster 96: 100%|█████| 1/1 [00:00<00:00, 14926.35it/s]
# Processing Cluster 147: 100%|████| 2/2 [00:00<00:00, 13573.80it/s]
# Processing Cluster 41: 100%|█████| 16/16 [00:00<00:00, 355.68it/s]
# Processing Cluster 57: 100%|█████| 5/5 [00:00<00:00, 26852.14it/s]
# Processing Cluster 113: 100%|████| 2/2 [00:00<00:00, 19065.02it/s]
# Processing Cluster 22: 100%|█████| 58/58 [00:00<00:00, 231.42it/s]
# Processing Cluster 79: 100%|█████| 3/3 [00:00<00:00, 19878.22it/s]
# Processing Cluster 130: 100%|████| 44/44 [00:00<00:00, 933.00it/s]
# Processing Cluster 33: 100%|█████| 11/11 [00:00<00:00, 472.54it/s]
# Processing Cluster 46: 100%|███| 14/14 [00:00<00:00, 30840.47it/s]
# Processing Cluster 84: 100%|██| 126/126 [00:00<00:00, 1139.19it/s]
# Processing Cluster 28: 100%|███| 19/19 [00:00<00:00, 25331.14it/s]
# Processing Cluster 119: 100%|████| 9/9 [00:00<00:00, 30941.59it/s]
# Processing Cluster 84: 100%|██| 126/126 [00:00<00:00, 1117.05it/s]
# Processing Cluster 70: 100%|██████| 3/3 [00:00<00:00, 5137.98it/s]
# Processing Cluster 48: 100%|█████| 11/11 [00:00<00:00, 501.73it/s]
# Processing Cluster 77: 100%|██████| 17/17 [00:00<00:00, 59.31it/s]
# Processing Cluster 83: 100%|████| 71/71 [00:00<00:00, 2477.91it/s]
# Processing Cluster 23: 100%|█████| 33/33 [00:00<00:00, 353.12it/s]
# Processing Cluster 138: 100%|████| 8/8 [00:00<00:00, 27191.60it/s]
# Processing Cluster 19: 100%|█████| 8/8 [00:00<00:00, 31359.28it/s]
# Processing Cluster 128: 100%|████| 2/2 [00:00<00:00, 20867.18it/s]
# Processing Cluster 24: 100%|█████| 23/23 [00:00<00:00, 346.18it/s]
# Processing Cluster 8: 100%|███████| 64/64 [00:00<00:00, 83.29it/s]
# Processing Cluster 15: 100%|█████| 61/61 [00:00<00:00, 524.05it/s]
# Processing Cluster 122: 100%|██| 18/18 [00:00<00:00, 27910.34it/s]
# Processing Cluster 116: 100%|████| 2/2 [00:00<00:00, 19239.93it/s]
# Processing Cluster 12: 100%|█████| 22/22 [00:00<00:00, 319.98it/s]
# Processing Cluster 13: 100%|███| 17/17 [00:00<00:00, 28670.35it/s]
# Processing Cluster 15: 100%|█████| 61/61 [00:00<00:00, 513.84it/s]
# Processing Cluster 157: 100%|████| 3/3 [00:00<00:00, 16152.65it/s]
# Processing Cluster 62: 100%|███| 10/10 [00:00<00:00, 31871.61it/s]
# Processing Cluster 66: 100%|█████| 2/2 [00:00<00:00, 18001.30it/s]
# Processing Cluster 65: 100%|█████| 57/57 [00:00<00:00, 353.38it/s]
# Processing Cluster 111: 100%|████| 2/2 [00:00<00:00, 18236.10it/s]
# Processing Cluster 12: 100%|█████| 22/22 [00:00<00:00, 332.02it/s]
# Processing Cluster 21: 100%|█████| 45/45 [00:00<00:00, 677.52it/s]
# Processing Cluster 110: 100%|████| 4/4 [00:00<00:00, 29177.77it/s]
# Processing Cluster 144: 100%|████| 21/21 [00:00<00:00, 494.71it/s]
# Processing Cluster 148: 100%|███| 38/38 [00:00<00:00, 1590.50it/s]
# Processing Cluster 143: 100%|████| 5/5 [00:00<00:00, 29916.58it/s]
# Processing Cluster 95: 100%|█████| 35/35 [00:00<00:00, 136.59it/s]
# Processing Cluster 54: 100%|████| 26/26 [00:00<00:00, 1117.32it/s]
# Processing Cluster 128: 100%|████| 2/2 [00:00<00:00, 12427.57it/s]
# Processing Cluster 117: 100%|████| 12/12 [00:00<00:00, 542.74it/s]
# Processing Cluster 119: 100%|████| 9/9 [00:00<00:00, 29793.79it/s]
# Processing Cluster 65: 100%|█████| 57/57 [00:00<00:00, 364.68it/s]
# Processing Cluster 154: 100%|████| 1/1 [00:00<00:00, 14716.86it/s]
# Processing Cluster 10: 100%|█████| 45/45 [00:00<00:00, 171.72it/s]
# Processing Cluster 121: 100%|████| 2/2 [00:00<00:00, 16545.58it/s]
# Processing Cluster 110: 100%|████| 4/4 [00:00<00:00, 22610.80it/s]
# Processing Cluster 119: 100%|████| 9/9 [00:00<00:00, 28297.40it/s]
# Processing Cluster 83: 100%|████| 71/71 [00:00<00:00, 2447.75it/s]
# Processing Cluster 34: 100%|███| 37/37 [00:00<00:00, 18155.04it/s]
# Processing Cluster 126: 100%|████| 17/17 [00:00<00:00, 736.06it/s]
# Processing Cluster 137: 100%|████| 59/59 [00:00<00:00, 825.95it/s]
# Processing Cluster 140: 100%|████| 18/18 [00:00<00:00, 778.88it/s]
# Processing Cluster 43: 100%|███| 24/24 [00:00<00:00, 21998.10it/s]
# Processing Cluster 7: 100%|██████| 61/61 [00:00<00:00, 332.80it/s]
# Processing Cluster 121: 100%|████| 2/2 [00:00<00:00, 17367.72it/s]
# Processing Cluster 98: 100%|█████| 2/2 [00:00<00:00, 12139.81it/s]
# Processing Cluster 142: 100%|████| 2/2 [00:00<00:00, 20020.54it/s]
# Processing Cluster 59: 100%|█████| 2/2 [00:00<00:00, 11444.21it/s]
# Processing Cluster 78: 100%|███| 484/484 [00:02<00:00, 188.37it/s]
# Processing Cluster 145: 100%|████| 1/1 [00:00<00:00, 12826.62it/s]
# Processing Cluster 26: 100%|█████| 8/8 [00:00<00:00, 31359.28it/s]
# Processing Cluster 117: 100%|████| 12/12 [00:00<00:00, 539.35it/s]
# Processing Cluster 96: 100%|██████| 1/1 [00:00<00:00, 8473.34it/s]
# Processing Cluster 21: 100%|█████| 45/45 [00:00<00:00, 688.22it/s]
# Processing Cluster 122: 100%|██| 18/18 [00:00<00:00, 26592.98it/s]
# Processing Cluster 155: 100%|████| 2/2 [00:00<00:00, 18001.30it/s]
# Processing Cluster 92: 100%|█████| 9/9 [00:00<00:00, 30078.67it/s]
# Processing Cluster 56: 100%|█████| 82/82 [00:00<00:00, 519.31it/s]
# Processing Cluster 53: 100%|█████| 8/8 [00:00<00:00, 29203.16it/s]
# Processing Cluster 70: 100%|█████| 3/3 [00:00<00:00, 24385.49it/s]
# Processing Cluster 62: 100%|███| 10/10 [00:00<00:00, 31750.98it/s]
# Processing Cluster 153: 100%|████| 5/5 [00:00<00:00, 28886.39it/s]
# Processing Cluster 120: 100%|██| 27/27 [00:00<00:00, 22235.66it/s]
# Processing Cluster 104: 100%|████| 5/5 [00:00<00:00, 29086.71it/s]
# Processing Cluster 118: 100%|████| 3/3 [00:00<00:00, 25015.73it/s]
# Processing Cluster 17: 100%|█████| 9/9 [00:00<00:00, 33584.28it/s]
# Processing Cluster 126: 100%|████| 17/17 [00:00<00:00, 788.80it/s]
# Processing Cluster 127: 100%|████| 1/1 [00:00<00:00, 16131.94it/s]
# Processing Cluster 111: 100%|████| 2/2 [00:00<00:00, 19831.22it/s]
# Processing Cluster 29: 100%|█████| 59/59 [00:00<00:00, 330.33it/s]
# Processing Cluster 129: 100%|██████| 9/9 [00:00<00:00, 375.46it/s]
# Processing Cluster 159: 100%|████| 15/15 [00:00<00:00, 327.82it/s]
# Processing Cluster 116: 100%|████| 2/2 [00:00<00:00, 18355.82it/s]
# Processing Cluster 68: 100%|█████| 5/5 [00:00<00:00, 29789.09it/s]
# Processing Cluster 46: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1708.94it/s]
# Processing Cluster 84: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 145.67it/s]
# Processing Cluster 28: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 167.72it/s]
# Processing Cluster 48: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 1135.80it/s]
# Processing Cluster 23: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 456.89it/s]
# Processing Cluster 19: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 614.59it/s]
# Processing Cluster 24: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 77.14it/s]
# Processing Cluster 8: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 679.47it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1070.13it/s]
# Processing Cluster 12: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 298.42it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1072.52it/s]
# Processing Cluster 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1072.72it/s]
# Processing Cluster 62: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 5068.65it/s]
# Processing Cluster 66: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 261.16it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:01<00:00, 105.55it/s]
# Processing Cluster 12: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 299.68it/s]
# Processing Cluster 1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 257.37it/s]
# Processing Cluster 21: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 724.12it/s]
# Processing Cluster 54: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 592.14it/s]
# Processing Cluster 65: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:01<00:00, 104.95it/s]
# Processing Cluster 10: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 609.29it/s]
# Processing Cluster 83: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 6445.22it/s]
# Processing Cluster 34: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 451.03it/s]
# Processing Cluster 43: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1816.14it/s]
# Processing Cluster 7: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 86.81it/s]
# Processing Cluster 59: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 999.23it/s]
# Processing Cluster 78: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 633.42it/s]
# Processing Cluster 26: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 685.89it/s]
# Processing Cluster 21: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 684.40it/s]
# Processing Cluster 45: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 647.92it/s]
# Processing Cluster 56: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 584.59it/s]
# Processing Cluster 27: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 384.53it/s]
# Processing Cluster 53: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 25771.45it/s]
# Processing Cluster 70: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 177.88it/s]
# Processing Cluster 62: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 3563.86it/s]
# Processing Cluster 17: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 176.95it/s]
# Processing Cluster 13: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1092.99it/s]
# Processing Cluster 29: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 517.36it/s]
# Processing Cluster 68: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 420.95it/s]

# %% [markdown]
# Next we represent the most similar plants and their simillarity scores in one dataframe and their chemical composion in another dataframe so that we can later visualize it as a heatmap

# %%
import pandas as pd
from tqdm import tqdm
import os

# Define the path to the cluster data
data_path = './initial_data/clusters_euclidean/'

# Get a list of cluster files
cluster_files = [file for file in os.listdir(data_path) if file.startswith('cluster_')]

# Iterate over the cluster files
for cluster_file in cluster_files:
    # Extract the cluster number from the file name
    cluster_num = cluster_file.split('_')[1]
    
    # Load the plant similarities data
    similarities_file = os.path.join(data_path, f'cluster_{cluster_num}_plant_similarities.csv')
    plant_similarities = pd.read_csv(similarities_file, index_col=0)

    # Create an empty DataFrame to store the results
    results_df = pd.DataFrame(columns=['Plant 1', 'Plant 2', 'Similarity Score'])

    # Iterate over the rows of the plant similarities data
    for plant_1 in tqdm(plant_similarities.index, total=len(plant_similarities), desc=f'Processing Cluster {cluster_num}'):
        for plant_2 in plant_similarities.columns:
            if plant_1 != plant_2:  # Exclude diagonal comparisons
                similarity_score = plant_similarities.loc[plant_1, plant_2]  # Similarity score
                if similarity_score >= 0.9:  # Filter similarity score
                    
                    # Create a temporary DataFrame to store the current result
                    temp_df = pd.DataFrame({
                        'Plant 1': [plant_1],
                        'Plant 2': [plant_2],
                        'Similarity Score': [similarity_score]
                    })

                    # Append the temporary DataFrame to the results DataFrame
                    results_df = pd.concat([results_df, temp_df], ignore_index=True)

    # Save the results to a CSV file
    results_path = os.path.join(data_path, f'cluster_{cluster_num}')
    
    # Ensure the directory exists
    if not os.path.exists(results_path):
        os.makedirs(results_path)

    # Save the results dataframe to a csv file with designated name
    filename = f'high_similarity_plants.csv'
    results_df.to_csv(os.path.join(results_path, filename), index=False)
# Out:
# Processing Cluster 71: 100%|████| 27/27 [00:00<00:00, 5867.98it/s]
# Processing Cluster 105: 100%|████| 9/9 [00:00<00:00, 15301.47it/s]
# Processing Cluster 152: 100%|██| 15/15 [00:00<00:00, 10218.38it/s]
# Processing Cluster 34: 100%|████| 37/37 [00:00<00:00, 4601.20it/s]
# Processing Cluster 41: 100%|████| 16/16 [00:00<00:00, 8465.86it/s]
# Processing Cluster 155: 100%|████| 2/2 [00:00<00:00, 14074.85it/s]
# Processing Cluster 105: 100%|████| 9/9 [00:00<00:00, 21124.08it/s]
# Processing Cluster 80: 100%|█████| 3/3 [00:00<00:00, 14631.29it/s]
# Processing Cluster 28: 100%|███| 19/19 [00:00<00:00, 12506.56it/s]
# Processing Cluster 130: 100%|███| 44/44 [00:00<00:00, 5099.74it/s]
# Processing Cluster 137: 100%|███| 59/59 [00:00<00:00, 3988.39it/s]
# Processing Cluster 108: 100%|███| 35/35 [00:00<00:00, 6951.45it/s]
# Processing Cluster 79: 100%|█████| 3/3 [00:00<00:00, 23258.62it/s]
# Processing Cluster 123: 100%|█████| 7/7 [00:00<00:00, 9535.61it/s]
# Processing Cluster 141: 100%|████| 2/2 [00:00<00:00, 20164.92it/s]
# Processing Cluster 97: 100%|████| 43/43 [00:00<00:00, 5305.34it/s]
# Processing Cluster 70: 100%|█████| 3/3 [00:00<00:00, 25216.26it/s]
# Processing Cluster 101: 100%|███| 63/63 [00:00<00:00, 4060.38it/s]
# Processing Cluster 20: 100%|████| 42/42 [00:00<00:00, 5502.44it/s]
# Processing Cluster 5: 100%|█████| 35/35 [00:00<00:00, 4253.73it/s]
# Processing Cluster 106: 100%|███| 23/23 [00:00<00:00, 8483.77it/s]
# Processing Cluster 139: 100%|███| 11/11 [00:00<00:00, 9971.33it/s]
# Processing Cluster 57: 100%|█████| 5/5 [00:00<00:00, 21642.44it/s]
# Processing Cluster 134: 100%|████| 3/3 [00:00<00:00, 23831.27it/s]
# Processing Cluster 154: 100%|████| 1/1 [00:00<00:00, 30174.85it/s]
# Processing Cluster 118: 100%|████| 3/3 [00:00<00:00, 23130.35it/s]
# Processing Cluster 102: 100%|██| 19/19 [00:00<00:00, 12691.79it/s]
# Processing Cluster 33: 100%|████| 11/11 [00:00<00:00, 8622.19it/s]
# Processing Cluster 46: 100%|███| 14/14 [00:00<00:00, 15588.07it/s]
# Processing Cluster 87: 100%|█████| 7/7 [00:00<00:00, 23081.86it/s]
# Processing Cluster 136: 100%|████| 8/8 [00:00<00:00, 20311.40it/s]
# Processing Cluster 82: 100%|█████| 7/7 [00:00<00:00, 23967.45it/s]
# Processing Cluster 35: 100%|███| 21/21 [00:00<00:00, 10802.11it/s]
# Processing Cluster 154: 100%|████| 1/1 [00:00<00:00, 40329.85it/s]
# Processing Cluster 42: 100%|███| 14/14 [00:00<00:00, 10006.86it/s]
# Processing Cluster 39: 100%|████| 61/61 [00:00<00:00, 4164.94it/s]
# Processing Cluster 6: 100%|██████| 60/60 [00:00<00:00, 961.34it/s]
# Processing Cluster 108: 100%|███| 35/35 [00:00<00:00, 6982.86it/s]
# Processing Cluster 141: 100%|████| 2/2 [00:00<00:00, 18682.87it/s]
# Processing Cluster 153: 100%|████| 5/5 [00:00<00:00, 19382.18it/s]
# Processing Cluster 64: 100%|██████| 6/6 [00:00<00:00, 8341.34it/s]
# Processing Cluster 107: 100%|███| 66/66 [00:00<00:00, 3665.04it/s]
# Processing Cluster 138: 100%|████| 8/8 [00:00<00:00, 19611.01it/s]
# Processing Cluster 139: 100%|██| 11/11 [00:00<00:00, 10193.85it/s]
# Processing Cluster 100: 100%|████| 2/2 [00:00<00:00, 19373.23it/s]
# Processing Cluster 13: 100%|███| 17/17 [00:00<00:00, 13157.99it/s]
# Processing Cluster 8: 100%|█████| 64/64 [00:00<00:00, 2379.26it/s]
# Processing Cluster 110: 100%|████| 4/4 [00:00<00:00, 24070.61it/s]
# Processing Cluster 146: 100%|█████| 7/7 [00:00<00:00, 7831.46it/s]
# Processing Cluster 136: 100%|████| 8/8 [00:00<00:00, 20610.83it/s]
# Processing Cluster 77: 100%|████| 17/17 [00:00<00:00, 3142.91it/s]
# Processing Cluster 149: 100%|████| 1/1 [00:00<00:00, 26379.27it/s]
# Processing Cluster 109: 100%|████| 2/2 [00:00<00:00, 16545.58it/s]
# Processing Cluster 2: 100%|████| 18/18 [00:00<00:00, 12684.39it/s]
# Processing Cluster 131: 100%|████| 2/2 [00:00<00:00, 16545.58it/s]
# Processing Cluster 133: 100%|████| 4/4 [00:00<00:00, 26504.29it/s]
# Processing Cluster 51: 100%|████| 20/20 [00:00<00:00, 9037.50it/s]
# Processing Cluster 8: 100%|█████| 64/64 [00:00<00:00, 2393.09it/s]
# Processing Cluster 139: 100%|██| 11/11 [00:00<00:00, 11519.94it/s]
# Processing Cluster 56: 100%|████| 82/82 [00:00<00:00, 2895.25it/s]
# Processing Cluster 9: 100%|█████| 52/52 [00:00<00:00, 4639.22it/s]
# Processing Cluster 69: 100%|█████| 9/9 [00:00<00:00, 10825.56it/s]
# Processing Cluster 60: 100%|████| 42/42 [00:00<00:00, 4679.15it/s]
# Processing Cluster 45: 100%|██████| 5/5 [00:00<00:00, 6710.89it/s]
# Processing Cluster 6: 100%|██████| 60/60 [00:00<00:00, 923.20it/s]
# Processing Cluster 94: 100%|█████| 7/7 [00:00<00:00, 23045.63it/s]
# Processing Cluster 117: 100%|███| 12/12 [00:00<00:00, 9594.29it/s]
# Processing Cluster 84: 100%|██| 126/126 [00:00<00:00, 1937.92it/s]
# Processing Cluster 14: 100%|███| 127/127 [00:00<00:00, 609.89it/s]
# Processing Cluster 93: 100%|███| 10/10 [00:00<00:00, 10835.20it/s]
# Processing Cluster 63: 100%|█████| 7/7 [00:00<00:00, 21620.12it/s]
# Processing Cluster 1: 100%|████| 128/128 [00:01<00:00, 122.61it/s]
# Processing Cluster 67: 100%|████| 13/13 [00:00<00:00, 6749.10it/s]
# Processing Cluster 30: 100%|████| 33/33 [00:00<00:00, 5736.34it/s]
# Processing Cluster 101: 100%|███| 63/63 [00:00<00:00, 4127.09it/s]
# Processing Cluster 58: 100%|████| 38/38 [00:00<00:00, 5597.32it/s]
# Processing Cluster 146: 100%|█████| 7/7 [00:00<00:00, 9270.64it/s]
# Processing Cluster 1: 100%|████| 128/128 [00:01<00:00, 119.12it/s]
# Processing Cluster 45: 100%|██████| 5/5 [00:00<00:00, 7123.48it/s]
# Processing Cluster 33: 100%|███| 11/11 [00:00<00:00, 10752.12it/s]
# Processing Cluster 130: 100%|███| 44/44 [00:00<00:00, 5306.96it/s]
# Processing Cluster 32: 100%|█████| 5/5 [00:00<00:00, 17063.89it/s]
# Processing Cluster 74: 100%|███| 10/10 [00:00<00:00, 18859.28it/s]
# Processing Cluster 85: 100%|████| 21/21 [00:00<00:00, 9375.24it/s]
# Processing Cluster 131: 100%|████| 2/2 [00:00<00:00, 18893.26it/s]
# Processing Cluster 145: 100%|████| 1/1 [00:00<00:00, 26214.40it/s]
# Processing Cluster 34: 100%|████| 37/37 [00:00<00:00, 6721.06it/s]
# Processing Cluster 1: 100%|████| 128/128 [00:01<00:00, 119.28it/s]
# Processing Cluster 0: 100%|████| 23/23 [00:00<00:00, 10972.36it/s]
# Processing Cluster 66: 100%|█████| 2/2 [00:00<00:00, 14074.85it/s]
# Processing Cluster 92: 100%|█████| 9/9 [00:00<00:00, 20360.70it/s]
# Processing Cluster 59: 100%|█████| 2/2 [00:00<00:00, 22982.49it/s]
# Processing Cluster 153: 100%|████| 5/5 [00:00<00:00, 26181.67it/s]
# Processing Cluster 50: 100%|█████| 8/8 [00:00<00:00, 18020.64it/s]
# Processing Cluster 95: 100%|████| 35/35 [00:00<00:00, 4085.63it/s]
# Processing Cluster 27: 100%|████| 31/31 [00:00<00:00, 5518.82it/s]
# Processing Cluster 90: 100%|█████| 5/5 [00:00<00:00, 19821.85it/s]
# Processing Cluster 61: 100%|█████| 8/8 [00:00<00:00, 22656.60it/s]
# Processing Cluster 124: 100%|███| 28/28 [00:00<00:00, 4059.05it/s]
# Processing Cluster 48: 100%|████| 11/11 [00:00<00:00, 9362.29it/s]
# Processing Cluster 7: 100%|█████| 61/61 [00:00<00:00, 3573.06it/s]
# Processing Cluster 89: 100%|████| 13/13 [00:00<00:00, 9794.49it/s]
# Processing Cluster 42: 100%|████| 14/14 [00:00<00:00, 9964.41it/s]
# Processing Cluster 57: 100%|█████| 5/5 [00:00<00:00, 25763.54it/s]
# Processing Cluster 83: 100%|████| 71/71 [00:00<00:00, 3482.79it/s]
# Processing Cluster 68: 100%|█████| 5/5 [00:00<00:00, 23172.95it/s]
# Processing Cluster 50: 100%|█████| 8/8 [00:00<00:00, 21385.87it/s]
# Processing Cluster 9: 100%|█████| 52/52 [00:00<00:00, 4446.65it/s]
# Processing Cluster 37: 100%|████| 75/75 [00:00<00:00, 3410.63it/s]
# Processing Cluster 106: 100%|███| 23/23 [00:00<00:00, 7892.42it/s]
# Processing Cluster 98: 100%|█████| 2/2 [00:00<00:00, 12139.81it/s]
# Processing Cluster 137: 100%|███| 59/59 [00:00<00:00, 4089.50it/s]
# Processing Cluster 73: 100%|██████| 5/5 [00:00<00:00, 6974.23it/s]
# Processing Cluster 58: 100%|████| 38/38 [00:00<00:00, 5625.37it/s]
# Processing Cluster 142: 100%|████| 2/2 [00:00<00:00, 12104.77it/s]
# Processing Cluster 6: 100%|██████| 60/60 [00:00<00:00, 998.35it/s]
# Processing Cluster 148: 100%|███| 38/38 [00:00<00:00, 6032.46it/s]
# Processing Cluster 79: 100%|█████| 3/3 [00:00<00:00, 20560.31it/s]
# Processing Cluster 102: 100%|██| 19/19 [00:00<00:00, 12924.39it/s]
# Processing Cluster 35: 100%|███| 21/21 [00:00<00:00, 11646.22it/s]
# Processing Cluster 76: 100%|███| 18/18 [00:00<00:00, 12811.38it/s]
# Processing Cluster 32: 100%|█████| 5/5 [00:00<00:00, 21355.93it/s]
# Processing Cluster 10: 100%|████| 45/45 [00:00<00:00, 3752.81it/s]
# Processing Cluster 149: 100%|█████| 1/1 [00:00<00:00, 9822.73it/s]
# Processing Cluster 107: 100%|███| 66/66 [00:00<00:00, 3806.71it/s]
# Processing Cluster 78: 100%|███| 484/484 [00:00<00:00, 530.95it/s]
# Processing Cluster 73: 100%|██████| 5/5 [00:00<00:00, 7363.60it/s]
# Processing Cluster 17: 100%|█████| 9/9 [00:00<00:00, 22075.28it/s]
# Processing Cluster 28: 100%|███| 19/19 [00:00<00:00, 12623.44it/s]
# Processing Cluster 21: 100%|████| 45/45 [00:00<00:00, 4723.08it/s]
# Processing Cluster 136: 100%|████| 8/8 [00:00<00:00, 21156.64it/s]
# Processing Cluster 129: 100%|█████| 9/9 [00:00<00:00, 9144.56it/s]
# Processing Cluster 26: 100%|█████| 8/8 [00:00<00:00, 22162.77it/s]
# Processing Cluster 7: 100%|█████| 61/61 [00:00<00:00, 3455.41it/s]
# Processing Cluster 19: 100%|█████| 8/8 [00:00<00:00, 23663.21it/s]
# Processing Cluster 72: 100%|███| 12/12 [00:00<00:00, 14921.92it/s]
# Processing Cluster 143: 100%|████| 5/5 [00:00<00:00, 22623.00it/s]
# Processing Cluster 82: 100%|█████| 7/7 [00:00<00:00, 23658.44it/s]
# Processing Cluster 72: 100%|███| 12/12 [00:00<00:00, 18463.55it/s]
# Processing Cluster 43: 100%|███| 24/24 [00:00<00:00, 10512.04it/s]
# Processing Cluster 86: 100%|█████| 5/5 [00:00<00:00, 25481.80it/s]
# Processing Cluster 36: 100%|████| 53/53 [00:00<00:00, 4708.11it/s]
# Processing Cluster 107: 100%|███| 66/66 [00:00<00:00, 3654.25it/s]
# Processing Cluster 81: 100%|█████| 9/9 [00:00<00:00, 15357.50it/s]
# Processing Cluster 75: 100%|████| 88/88 [00:00<00:00, 2827.93it/s]
# Processing Cluster 88: 100%|███| 15/15 [00:00<00:00, 15289.08it/s]
# Processing Cluster 156: 100%|███| 54/54 [00:00<00:00, 4540.11it/s]
# Processing Cluster 55: 100%|█████| 4/4 [00:00<00:00, 26173.50it/s]
# Processing Cluster 43: 100%|████| 24/24 [00:00<00:00, 9712.78it/s]
# Processing Cluster 95: 100%|████| 35/35 [00:00<00:00, 3942.76it/s]
# Processing Cluster 22: 100%|████| 58/58 [00:00<00:00, 3398.19it/s]
# Processing Cluster 88: 100%|███| 15/15 [00:00<00:00, 14876.94it/s]
# Processing Cluster 121: 100%|████| 2/2 [00:00<00:00, 22671.91it/s]
# Processing Cluster 44: 100%|█████| 5/5 [00:00<00:00, 16513.01it/s]
# Processing Cluster 49: 100%|████| 28/28 [00:00<00:00, 6548.48it/s]
# Processing Cluster 27: 100%|████| 31/31 [00:00<00:00, 5452.63it/s]
# Processing Cluster 18: 100%|████| 31/31 [00:00<00:00, 6790.80it/s]
# Processing Cluster 20: 100%|████| 42/42 [00:00<00:00, 5562.21it/s]
# Processing Cluster 19: 100%|█████| 8/8 [00:00<00:00, 20880.17it/s]
# Processing Cluster 16: 100%|███| 13/13 [00:00<00:00, 17448.30it/s]
# Processing Cluster 131: 100%|████| 2/2 [00:00<00:00, 24672.38it/s]
# Processing Cluster 29: 100%|████| 59/59 [00:00<00:00, 3528.09it/s]
# Processing Cluster 143: 100%|████| 5/5 [00:00<00:00, 25266.89it/s]
# Processing Cluster 40: 100%|████| 19/19 [00:00<00:00, 9251.43it/s]
# Processing Cluster 4: 100%|█████| 27/27 [00:00<00:00, 4908.38it/s]
# Processing Cluster 80: 100%|█████| 3/3 [00:00<00:00, 16867.17it/s]
# Processing Cluster 37: 100%|████| 75/75 [00:00<00:00, 3358.99it/s]
# Processing Cluster 11: 100%|████| 38/38 [00:00<00:00, 2055.61it/s]
# Processing Cluster 134: 100%|████| 3/3 [00:00<00:00, 16320.25it/s]
# Processing Cluster 0: 100%|████| 23/23 [00:00<00:00, 10994.87it/s]
# Processing Cluster 75: 100%|████| 88/88 [00:00<00:00, 2836.89it/s]
# Processing Cluster 144: 100%|███| 21/21 [00:00<00:00, 7865.02it/s]
# Processing Cluster 85: 100%|████| 21/21 [00:00<00:00, 9370.25it/s]
# Processing Cluster 112: 100%|████| 1/1 [00:00<00:00, 47662.55it/s]
# Processing Cluster 44: 100%|█████| 5/5 [00:00<00:00, 21936.74it/s]
# Processing Cluster 11: 100%|████| 38/38 [00:00<00:00, 2004.95it/s]
# Processing Cluster 45: 100%|██████| 5/5 [00:00<00:00, 8224.13it/s]
# Processing Cluster 66: 100%|█████| 2/2 [00:00<00:00, 27060.03it/s]
# Processing Cluster 31: 100%|████| 34/34 [00:00<00:00, 6091.42it/s]
# Processing Cluster 100: 100%|████| 2/2 [00:00<00:00, 21024.08it/s]
# Processing Cluster 89: 100%|████| 13/13 [00:00<00:00, 9084.63it/s]
# Processing Cluster 42: 100%|███| 14/14 [00:00<00:00, 10080.73it/s]
# Processing Cluster 74: 100%|███| 10/10 [00:00<00:00, 17239.23it/s]
# Processing Cluster 88: 100%|███| 15/15 [00:00<00:00, 15138.25it/s]
# Processing Cluster 80: 100%|█████| 3/3 [00:00<00:00, 28276.21it/s]
# Processing Cluster 48: 100%|████| 11/11 [00:00<00:00, 9939.11it/s]
# Processing Cluster 87: 100%|█████| 7/7 [00:00<00:00, 23027.55it/s]
# Processing Cluster 73: 100%|██████| 5/5 [00:00<00:00, 7801.90it/s]
# Processing Cluster 3: 100%|████| 22/22 [00:00<00:00, 11324.83it/s]
# Processing Cluster 147: 100%|████| 2/2 [00:00<00:00, 19831.22it/s]
# Processing Cluster 76: 100%|███| 18/18 [00:00<00:00, 13235.88it/s]
# Processing Cluster 113: 100%|████| 2/2 [00:00<00:00, 18893.26it/s]
# Processing Cluster 132: 100%|███| 30/30 [00:00<00:00, 7345.97it/s]
# Processing Cluster 114: 100%|██| 10/10 [00:00<00:00, 20281.93it/s]
# Processing Cluster 38: 100%|████| 80/80 [00:00<00:00, 3094.91it/s]
# Processing Cluster 138: 100%|████| 8/8 [00:00<00:00, 20610.83it/s]
# Processing Cluster 61: 100%|█████| 8/8 [00:00<00:00, 22104.37it/s]
# Processing Cluster 122: 100%|██| 18/18 [00:00<00:00, 12912.17it/s]
# Processing Cluster 9: 100%|█████| 52/52 [00:00<00:00, 4421.86it/s]
# Processing Cluster 16: 100%|███| 13/13 [00:00<00:00, 16881.10it/s]
# Processing Cluster 125: 100%|████| 2/2 [00:00<00:00, 25040.62it/s]
# Processing Cluster 115: 100%|███| 99/99 [00:00<00:00, 2519.79it/s]
# Processing Cluster 133: 100%|████| 4/4 [00:00<00:00, 23237.14it/s]
# Processing Cluster 30: 100%|████| 33/33 [00:00<00:00, 5700.43it/s]
# Processing Cluster 87: 100%|█████| 7/7 [00:00<00:00, 16052.56it/s]
# Processing Cluster 38: 100%|████| 80/80 [00:00<00:00, 3095.88it/s]
# Processing Cluster 109: 100%|████| 2/2 [00:00<00:00, 18850.80it/s]
# Processing Cluster 149: 100%|████| 1/1 [00:00<00:00, 41527.76it/s]
# Processing Cluster 3: 100%|████| 22/22 [00:00<00:00, 10236.82it/s]
# Processing Cluster 47: 100%|████| 23/23 [00:00<00:00, 3663.70it/s]
# Processing Cluster 144: 100%|███| 21/21 [00:00<00:00, 8325.97it/s]
# Processing Cluster 103: 100%|█████| 9/9 [00:00<00:00, 8388.61it/s]
# Processing Cluster 140: 100%|███| 18/18 [00:00<00:00, 9836.80it/s]
# Processing Cluster 32: 100%|█████| 5/5 [00:00<00:00, 27630.46it/s]
# Processing Cluster 86: 100%|█████| 5/5 [00:00<00:00, 24528.09it/s]
# Processing Cluster 147: 100%|████| 2/2 [00:00<00:00, 14926.35it/s]
# Processing Cluster 69: 100%|██████| 9/9 [00:00<00:00, 9644.54it/s]
# Processing Cluster 47: 100%|████| 23/23 [00:00<00:00, 5082.13it/s]
# Processing Cluster 126: 100%|███| 17/17 [00:00<00:00, 9498.22it/s]
# Processing Cluster 4: 100%|█████| 27/27 [00:00<00:00, 5095.21it/s]
# Processing Cluster 25: 100%|████| 19/19 [00:00<00:00, 6704.11it/s]
# Processing Cluster 92: 100%|█████| 9/9 [00:00<00:00, 20262.34it/s]
# Processing Cluster 124: 100%|███| 28/28 [00:00<00:00, 4112.78it/s]
# Processing Cluster 140: 100%|███| 18/18 [00:00<00:00, 9885.75it/s]
# Processing Cluster 71: 100%|████| 27/27 [00:00<00:00, 9021.45it/s]
# Processing Cluster 135: 100%|████| 8/8 [00:00<00:00, 19996.68it/s]
# Processing Cluster 52: 100%|████| 33/33 [00:00<00:00, 6563.54it/s]
# Processing Cluster 151: 100%|█████| 5/5 [00:00<00:00, 6029.76it/s]
# Processing Cluster 123: 100%|█████| 7/7 [00:00<00:00, 9560.45it/s]
# Processing Cluster 108: 100%|███| 35/35 [00:00<00:00, 7362.49it/s]
# Processing Cluster 115: 100%|███| 99/99 [00:00<00:00, 2579.33it/s]
# Processing Cluster 112: 100%|████| 1/1 [00:00<00:00, 28532.68it/s]
# Processing Cluster 146: 100%|█████| 7/7 [00:00<00:00, 8569.80it/s]
# Processing Cluster 159: 100%|███| 15/15 [00:00<00:00, 8567.96it/s]
# Processing Cluster 141: 100%|████| 2/2 [00:00<00:00, 23563.51it/s]
# Processing Cluster 104: 100%|████| 5/5 [00:00<00:00, 20908.79it/s]
# Processing Cluster 74: 100%|███| 10/10 [00:00<00:00, 18876.26it/s]
# Processing Cluster 35: 100%|███| 21/21 [00:00<00:00, 11449.42it/s]
# Processing Cluster 148: 100%|███| 38/38 [00:00<00:00, 5956.26it/s]
# Processing Cluster 81: 100%|█████| 9/9 [00:00<00:00, 19468.15it/s]
# Processing Cluster 100: 100%|████| 2/2 [00:00<00:00, 16384.00it/s]
# Processing Cluster 40: 100%|████| 19/19 [00:00<00:00, 9073.41it/s]
# Processing Cluster 134: 100%|████| 3/3 [00:00<00:00, 22919.69it/s]
# Processing Cluster 158: 100%|█████| 6/6 [00:00<00:00, 8927.22it/s]
# Processing Cluster 133: 100%|████| 4/4 [00:00<00:00, 28387.84it/s]
# Processing Cluster 158: 100%|█████| 6/6 [00:00<00:00, 7852.05it/s]
# Processing Cluster 69: 100%|█████| 9/9 [00:00<00:00, 10263.39it/s]
# Processing Cluster 105: 100%|████| 9/9 [00:00<00:00, 20925.02it/s]
# Processing Cluster 63: 100%|█████| 7/7 [00:00<00:00, 22225.68it/s]
# Processing Cluster 152: 100%|██| 15/15 [00:00<00:00, 15065.75it/s]
# Processing Cluster 75: 100%|████| 88/88 [00:00<00:00, 2841.08it/s]
# Processing Cluster 101: 100%|███| 63/63 [00:00<00:00, 4088.52it/s]
# Processing Cluster 102: 100%|██| 19/19 [00:00<00:00, 12752.72it/s]
# Processing Cluster 16: 100%|███| 13/13 [00:00<00:00, 17293.36it/s]
# Processing Cluster 127: 100%|████| 1/1 [00:00<00:00, 43690.67it/s]
# Processing Cluster 27: 100%|████| 31/31 [00:00<00:00, 5400.54it/s]
# Processing Cluster 24: 100%|████| 23/23 [00:00<00:00, 7080.81it/s]
# Processing Cluster 93: 100%|████| 10/10 [00:00<00:00, 9811.24it/s]
# Processing Cluster 156: 100%|███| 54/54 [00:00<00:00, 4432.42it/s]
# Processing Cluster 127: 100%|████| 1/1 [00:00<00:00, 24818.37it/s]
# Processing Cluster 116: 100%|████| 2/2 [00:00<00:00, 13421.77it/s]
# Processing Cluster 52: 100%|████| 33/33 [00:00<00:00, 6700.81it/s]
# Processing Cluster 150: 100%|████| 1/1 [00:00<00:00, 11096.04it/s]
# Processing Cluster 53: 100%|█████| 8/8 [00:00<00:00, 21675.99it/s]
# Processing Cluster 93: 100%|████| 10/10 [00:00<00:00, 9381.13it/s]
# Processing Cluster 151: 100%|█████| 5/5 [00:00<00:00, 6069.90it/s]
# Processing Cluster 158: 100%|█████| 6/6 [00:00<00:00, 8380.23it/s]
# Processing Cluster 58: 100%|████| 38/38 [00:00<00:00, 5043.14it/s]
# Processing Cluster 109: 100%|████| 2/2 [00:00<00:00, 20020.54it/s]
# Processing Cluster 99: 100%|█████| 5/5 [00:00<00:00, 28263.50it/s]
# Processing Cluster 103: 100%|████| 9/9 [00:00<00:00, 10769.97it/s]
# Processing Cluster 31: 100%|████| 34/34 [00:00<00:00, 6294.97it/s]
# Processing Cluster 86: 100%|█████| 5/5 [00:00<00:00, 27342.27it/s]
# Processing Cluster 132: 100%|███| 30/30 [00:00<00:00, 7308.00it/s]
# Processing Cluster 145: 100%|████| 1/1 [00:00<00:00, 39945.75it/s]
# Processing Cluster 2: 100%|████| 18/18 [00:00<00:00, 11850.18it/s]
# Processing Cluster 104: 100%|████| 5/5 [00:00<00:00, 26579.87it/s]
# Processing Cluster 46: 100%|███| 14/14 [00:00<00:00, 13845.85it/s]
# Processing Cluster 64: 100%|██████| 6/6 [00:00<00:00, 7719.58it/s]
# Processing Cluster 132: 100%|███| 30/30 [00:00<00:00, 7418.30it/s]
# Processing Cluster 155: 100%|████| 2/2 [00:00<00:00, 26296.58it/s]
# Processing Cluster 68: 100%|█████| 5/5 [00:00<00:00, 23669.89it/s]
# Processing Cluster 135: 100%|████| 8/8 [00:00<00:00, 22904.05it/s]
# Processing Cluster 11: 100%|████| 38/38 [00:00<00:00, 2054.07it/s]
# Processing Cluster 120: 100%|███| 27/27 [00:00<00:00, 9180.14it/s]
# Processing Cluster 20: 100%|████| 42/42 [00:00<00:00, 5653.61it/s]
# Processing Cluster 111: 100%|████| 2/2 [00:00<00:00, 12264.05it/s]
# Processing Cluster 39: 100%|████| 61/61 [00:00<00:00, 4046.12it/s]
# Processing Cluster 55: 100%|█████| 4/4 [00:00<00:00, 29433.71it/s]
# Processing Cluster 159: 100%|███| 15/15 [00:00<00:00, 8341.89it/s]
# Processing Cluster 94: 100%|█████| 7/7 [00:00<00:00, 19945.74it/s]
# Processing Cluster 60: 100%|████| 42/42 [00:00<00:00, 4482.35it/s]
# Processing Cluster 150: 100%|█████| 1/1 [00:00<00:00, 7943.76it/s]
# Processing Cluster 114: 100%|██| 10/10 [00:00<00:00, 20440.08it/s]
# Processing Cluster 17: 100%|█████| 9/9 [00:00<00:00, 21934.19it/s]
# Processing Cluster 157: 100%|████| 3/3 [00:00<00:00, 28276.21it/s]
# Processing Cluster 10: 100%|████| 45/45 [00:00<00:00, 3649.34it/s]
# Processing Cluster 113: 100%|████| 2/2 [00:00<00:00, 21290.88it/s]
# Processing Cluster 123: 100%|█████| 7/7 [00:00<00:00, 8237.97it/s]
# Processing Cluster 37: 100%|████| 75/75 [00:00<00:00, 3382.21it/s]
# Processing Cluster 12: 100%|████| 22/22 [00:00<00:00, 5542.69it/s]
# Processing Cluster 156: 100%|███| 54/54 [00:00<00:00, 4413.59it/s]
# Processing Cluster 67: 100%|████| 13/13 [00:00<00:00, 6839.68it/s]
# Processing Cluster 67: 100%|████| 13/13 [00:00<00:00, 6862.93it/s]
# Processing Cluster 30: 100%|████| 33/33 [00:00<00:00, 5782.35it/s]
# Processing Cluster 89: 100%|████| 13/13 [00:00<00:00, 9638.67it/s]
# Processing Cluster 39: 100%|████| 61/61 [00:00<00:00, 3869.05it/s]
# Processing Cluster 18: 100%|████| 31/31 [00:00<00:00, 7342.64it/s]
# Processing Cluster 49: 100%|████| 28/28 [00:00<00:00, 6685.29it/s]
# Processing Cluster 129: 100%|█████| 9/9 [00:00<00:00, 9792.15it/s]
# Processing Cluster 55: 100%|█████| 4/4 [00:00<00:00, 23663.21it/s]
# Processing Cluster 29: 100%|████| 59/59 [00:00<00:00, 3477.57it/s]
# Processing Cluster 118: 100%|████| 3/3 [00:00<00:00, 18836.69it/s]
# Processing Cluster 52: 100%|████| 33/33 [00:00<00:00, 6746.87it/s]
# Processing Cluster 99: 100%|█████| 5/5 [00:00<00:00, 16885.28it/s]
# Processing Cluster 18: 100%|████| 31/31 [00:00<00:00, 6943.10it/s]
# Processing Cluster 41: 100%|████| 16/16 [00:00<00:00, 7788.87it/s]
# Processing Cluster 5: 100%|█████| 35/35 [00:00<00:00, 4163.61it/s]
# Processing Cluster 90: 100%|█████| 5/5 [00:00<00:00, 25763.54it/s]
# Processing Cluster 2: 100%|████| 18/18 [00:00<00:00, 12996.64it/s]
# Processing Cluster 142: 100%|████| 2/2 [00:00<00:00, 27413.75it/s]
# Processing Cluster 56: 100%|████| 82/82 [00:00<00:00, 2772.04it/s]
# Processing Cluster 64: 100%|██████| 6/6 [00:00<00:00, 8333.05it/s]
# Processing Cluster 97: 100%|████| 43/43 [00:00<00:00, 5551.27it/s]
# Processing Cluster 63: 100%|█████| 7/7 [00:00<00:00, 22058.70it/s]
# Processing Cluster 5: 100%|█████| 35/35 [00:00<00:00, 4277.16it/s]
# Processing Cluster 97: 100%|████| 43/43 [00:00<00:00, 5614.52it/s]
# Processing Cluster 135: 100%|████| 8/8 [00:00<00:00, 22089.82it/s]
# Processing Cluster 112: 100%|████| 1/1 [00:00<00:00, 24385.49it/s]
# Processing Cluster 23: 100%|████| 33/33 [00:00<00:00, 5876.87it/s]
# Processing Cluster 81: 100%|█████| 9/9 [00:00<00:00, 19857.30it/s]
# Processing Cluster 36: 100%|████| 53/53 [00:00<00:00, 4808.01it/s]
# Processing Cluster 124: 100%|███| 28/28 [00:00<00:00, 4036.87it/s]
# Processing Cluster 15: 100%|████| 61/61 [00:00<00:00, 3750.62it/s]
# Processing Cluster 151: 100%|█████| 5/5 [00:00<00:00, 7497.86it/s]
# Processing Cluster 38: 100%|████| 80/80 [00:00<00:00, 2775.96it/s]
# Processing Cluster 60: 100%|████| 42/42 [00:00<00:00, 4083.37it/s]
# Processing Cluster 54: 100%|████| 26/26 [00:00<00:00, 7710.66it/s]
# Processing Cluster 157: 100%|████| 3/3 [00:00<00:00, 20132.66it/s]
# Processing Cluster 31: 100%|████| 34/34 [00:00<00:00, 6344.83it/s]
# Processing Cluster 120: 100%|███| 27/27 [00:00<00:00, 9035.84it/s]
# Processing Cluster 36: 100%|████| 53/53 [00:00<00:00, 4741.45it/s]
# Processing Cluster 94: 100%|█████| 7/7 [00:00<00:00, 22812.84it/s]
# Processing Cluster 23: 100%|████| 33/33 [00:00<00:00, 5447.36it/s]
# Processing Cluster 96: 100%|█████| 1/1 [00:00<00:00, 29330.80it/s]
# Processing Cluster 62: 100%|███| 10/10 [00:00<00:00, 18452.72it/s]
# Processing Cluster 4: 100%|█████| 27/27 [00:00<00:00, 5063.77it/s]
# Processing Cluster 106: 100%|███| 23/23 [00:00<00:00, 8345.07it/s]
# Processing Cluster 3: 100%|████| 22/22 [00:00<00:00, 11100.05it/s]
# Processing Cluster 65: 100%|████| 57/57 [00:00<00:00, 3773.34it/s]
# Processing Cluster 91: 100%|█████| 3/3 [00:00<00:00, 27776.85it/s]
# Processing Cluster 72: 100%|███| 12/12 [00:00<00:00, 16616.59it/s]
# Processing Cluster 53: 100%|█████| 8/8 [00:00<00:00, 18396.07it/s]
# Processing Cluster 128: 100%|████| 2/2 [00:00<00:00, 23497.50it/s]
# Processing Cluster 51: 100%|████| 20/20 [00:00<00:00, 9532.51it/s]
# Processing Cluster 90: 100%|█████| 5/5 [00:00<00:00, 24499.44it/s]
# Processing Cluster 98: 100%|█████| 2/2 [00:00<00:00, 12175.05it/s]
# Processing Cluster 54: 100%|████| 26/26 [00:00<00:00, 8160.12it/s]
# Processing Cluster 115: 100%|███| 99/99 [00:00<00:00, 2539.44it/s]
# Processing Cluster 24: 100%|████| 23/23 [00:00<00:00, 7050.80it/s]
# Processing Cluster 91: 100%|█████| 3/3 [00:00<00:00, 24769.51it/s]
# Processing Cluster 99: 100%|█████| 5/5 [00:00<00:00, 20420.18it/s]
# Processing Cluster 49: 100%|████| 28/28 [00:00<00:00, 6673.14it/s]
# Processing Cluster 82: 100%|█████| 7/7 [00:00<00:00, 22075.28it/s]
# Processing Cluster 76: 100%|███| 18/18 [00:00<00:00, 13242.85it/s]
# Processing Cluster 50: 100%|█████| 8/8 [00:00<00:00, 22295.30it/s]
# Processing Cluster 114: 100%|██| 10/10 [00:00<00:00, 20291.75it/s]
# Processing Cluster 25: 100%|████| 19/19 [00:00<00:00, 7486.31it/s]
# Processing Cluster 59: 100%|█████| 2/2 [00:00<00:00, 25970.92it/s]
# Processing Cluster 71: 100%|████| 27/27 [00:00<00:00, 9249.87it/s]
# Processing Cluster 85: 100%|████| 21/21 [00:00<00:00, 8994.22it/s]
# Processing Cluster 78: 100%|███| 484/484 [00:00<00:00, 503.49it/s]
# Processing Cluster 103: 100%|█████| 9/9 [00:00<00:00, 9583.33it/s]
# Processing Cluster 47: 100%|████| 23/23 [00:00<00:00, 4885.50it/s]
# Processing Cluster 40: 100%|████| 19/19 [00:00<00:00, 9514.30it/s]
# Processing Cluster 77: 100%|████| 17/17 [00:00<00:00, 3232.53it/s]
# Processing Cluster 51: 100%|████| 20/20 [00:00<00:00, 9315.50it/s]
# Processing Cluster 14: 100%|███| 127/127 [00:00<00:00, 587.86it/s]
# Processing Cluster 152: 100%|██| 15/15 [00:00<00:00, 15274.23it/s]
# Processing Cluster 13: 100%|███| 17/17 [00:00<00:00, 14058.20it/s]
# Processing Cluster 125: 100%|████| 2/2 [00:00<00:00, 20867.18it/s]
# Processing Cluster 26: 100%|█████| 8/8 [00:00<00:00, 22295.30it/s]
# Processing Cluster 91: 100%|█████| 3/3 [00:00<00:00, 19753.39it/s]
# Processing Cluster 125: 100%|████| 2/2 [00:00<00:00, 20610.83it/s]
# Processing Cluster 25: 100%|████| 19/19 [00:00<00:00, 6800.22it/s]
# Processing Cluster 14: 100%|███| 127/127 [00:00<00:00, 603.57it/s]
# Processing Cluster 22: 100%|████| 58/58 [00:00<00:00, 3334.84it/s]
# Processing Cluster 150: 100%|████| 1/1 [00:00<00:00, 13842.59it/s]
# Processing Cluster 61: 100%|█████| 8/8 [00:00<00:00, 22324.97it/s]
# Processing Cluster 0: 100%|████| 23/23 [00:00<00:00, 11062.96it/s]
# Processing Cluster 44: 100%|█████| 5/5 [00:00<00:00, 20908.79it/s]
# Processing Cluster 96: 100%|█████| 1/1 [00:00<00:00, 27060.03it/s]
# Processing Cluster 147: 100%|████| 2/2 [00:00<00:00, 19599.55it/s]
# Processing Cluster 41: 100%|████| 16/16 [00:00<00:00, 7847.15it/s]
# Processing Cluster 57: 100%|█████| 5/5 [00:00<00:00, 19526.55it/s]
# Processing Cluster 113: 100%|████| 2/2 [00:00<00:00, 23763.76it/s]
# Processing Cluster 22: 100%|████| 58/58 [00:00<00:00, 3433.01it/s]
# Processing Cluster 79: 100%|█████| 3/3 [00:00<00:00, 26602.35it/s]
# Processing Cluster 130: 100%|███| 44/44 [00:00<00:00, 5154.00it/s]
# Processing Cluster 33: 100%|████| 11/11 [00:00<00:00, 9856.30it/s]
# Processing Cluster 46: 100%|███| 14/14 [00:00<00:00, 15785.02it/s]
# Processing Cluster 84: 100%|██| 126/126 [00:00<00:00, 2007.52it/s]
# Processing Cluster 28: 100%|███| 19/19 [00:00<00:00, 12416.92it/s]
# Processing Cluster 119: 100%|████| 9/9 [00:00<00:00, 20775.31it/s]
# Processing Cluster 84: 100%|██| 126/126 [00:00<00:00, 1993.64it/s]
# Processing Cluster 70: 100%|█████| 3/3 [00:00<00:00, 13827.38it/s]
# Processing Cluster 48: 100%|████| 11/11 [00:00<00:00, 8934.42it/s]
# Processing Cluster 77: 100%|████| 17/17 [00:00<00:00, 3196.02it/s]
# Processing Cluster 83: 100%|████| 71/71 [00:00<00:00, 3483.84it/s]
# Processing Cluster 23: 100%|████| 33/33 [00:00<00:00, 5862.68it/s]
# Processing Cluster 138: 100%|████| 8/8 [00:00<00:00, 23464.64it/s]
# Processing Cluster 19: 100%|█████| 8/8 [00:00<00:00, 23045.63it/s]
# Processing Cluster 128: 100%|████| 2/2 [00:00<00:00, 22017.34it/s]
# Processing Cluster 24: 100%|████| 23/23 [00:00<00:00, 6736.66it/s]
# Processing Cluster 8: 100%|█████| 64/64 [00:00<00:00, 2459.75it/s]
# Processing Cluster 15: 100%|████| 61/61 [00:00<00:00, 3776.37it/s]
# Processing Cluster 122: 100%|██| 18/18 [00:00<00:00, 12914.38it/s]
# Processing Cluster 116: 100%|████| 2/2 [00:00<00:00, 14716.86it/s]
# Processing Cluster 12: 100%|████| 22/22 [00:00<00:00, 6495.47it/s]
# Processing Cluster 13: 100%|███| 17/17 [00:00<00:00, 13576.38it/s]
# Processing Cluster 15: 100%|████| 61/61 [00:00<00:00, 3688.28it/s]
# Processing Cluster 157: 100%|████| 3/3 [00:00<00:00, 16194.22it/s]
# Processing Cluster 62: 100%|███| 10/10 [00:00<00:00, 19499.32it/s]
# Processing Cluster 66: 100%|█████| 2/2 [00:00<00:00, 23563.51it/s]
# Processing Cluster 65: 100%|████| 57/57 [00:00<00:00, 3804.02it/s]
# Processing Cluster 111: 100%|████| 2/2 [00:00<00:00, 21454.24it/s]
# Processing Cluster 12: 100%|████| 22/22 [00:00<00:00, 6791.90it/s]
# Processing Cluster 21: 100%|████| 45/45 [00:00<00:00, 4981.75it/s]
# Processing Cluster 110: 100%|████| 4/4 [00:00<00:00, 28197.00it/s]
# Processing Cluster 144: 100%|███| 21/21 [00:00<00:00, 7689.25it/s]
# Processing Cluster 148: 100%|███| 38/38 [00:00<00:00, 5915.36it/s]
# Processing Cluster 143: 100%|████| 5/5 [00:00<00:00, 20400.31it/s]
# Processing Cluster 95: 100%|████| 35/35 [00:00<00:00, 3977.69it/s]
# Processing Cluster 54: 100%|████| 26/26 [00:00<00:00, 8110.36it/s]
# Processing Cluster 128: 100%|████| 2/2 [00:00<00:00, 14614.30it/s]
# Processing Cluster 117: 100%|███| 12/12 [00:00<00:00, 9933.22it/s]
# Processing Cluster 119: 100%|████| 9/9 [00:00<00:00, 18568.00it/s]
# Processing Cluster 65: 100%|████| 57/57 [00:00<00:00, 3780.56it/s]
# Processing Cluster 154: 100%|████| 1/1 [00:00<00:00, 45590.26it/s]
# Processing Cluster 10: 100%|████| 45/45 [00:00<00:00, 3608.38it/s]
# Processing Cluster 121: 100%|████| 2/2 [00:00<00:00, 14716.86it/s]
# Processing Cluster 110: 100%|█████| 4/4 [00:00<00:00, 3956.89it/s]
# Processing Cluster 119: 100%|████| 9/9 [00:00<00:00, 18441.00it/s]
# Processing Cluster 83: 100%|████| 71/71 [00:00<00:00, 3263.44it/s]
# Processing Cluster 34: 100%|████| 37/37 [00:00<00:00, 6756.47it/s]
# Processing Cluster 126: 100%|███| 17/17 [00:00<00:00, 9691.88it/s]
# Processing Cluster 137: 100%|███| 59/59 [00:00<00:00, 3927.56it/s]
# Processing Cluster 140: 100%|███| 18/18 [00:00<00:00, 9364.61it/s]
# Processing Cluster 43: 100%|████| 24/24 [00:00<00:00, 9958.77it/s]
# Processing Cluster 7: 100%|█████| 61/61 [00:00<00:00, 3482.50it/s]
# Processing Cluster 121: 100%|████| 2/2 [00:00<00:00, 13617.87it/s]
# Processing Cluster 98: 100%|█████| 2/2 [00:00<00:00, 14388.69it/s]
# Processing Cluster 142: 100%|████| 2/2 [00:00<00:00, 21959.71it/s]
# Processing Cluster 59: 100%|█████| 2/2 [00:00<00:00, 25653.24it/s]
# Processing Cluster 78: 100%|███| 484/484 [00:00<00:00, 507.44it/s]
# Processing Cluster 145: 100%|████| 1/1 [00:00<00:00, 27060.03it/s]
# Processing Cluster 26: 100%|█████| 8/8 [00:00<00:00, 19228.90it/s]
# Processing Cluster 117: 100%|███| 12/12 [00:00<00:00, 9972.59it/s]
# Processing Cluster 96: 100%|█████| 1/1 [00:00<00:00, 22429.43it/s]
# Processing Cluster 21: 100%|████| 45/45 [00:00<00:00, 5017.38it/s]
# Processing Cluster 122: 100%|██| 18/18 [00:00<00:00, 12346.28it/s]
# Processing Cluster 155: 100%|████| 2/2 [00:00<00:00, 16008.79it/s]
# Processing Cluster 92: 100%|█████| 9/9 [00:00<00:00, 21521.51it/s]
# Processing Cluster 56: 100%|████| 82/82 [00:00<00:00, 2847.93it/s]
# Processing Cluster 53: 100%|█████| 8/8 [00:00<00:00, 22265.71it/s]
# Processing Cluster 70: 100%|█████| 3/3 [00:00<00:00, 23652.09it/s]
# Processing Cluster 62: 100%|███| 10/10 [00:00<00:00, 19382.18it/s]
# Processing Cluster 153: 100%|████| 5/5 [00:00<00:00, 23804.22it/s]
# Processing Cluster 120: 100%|███| 27/27 [00:00<00:00, 8467.01it/s]
# Processing Cluster 104: 100%|████| 5/5 [00:00<00:00, 24499.44it/s]
# Processing Cluster 118: 100%|████| 3/3 [00:00<00:00, 27354.16it/s]
# Processing Cluster 17: 100%|█████| 9/9 [00:00<00:00, 21231.01it/s]
# Processing Cluster 126: 100%|██| 17/17 [00:00<00:00, 10106.76it/s]
# Processing Cluster 127: 100%|████| 1/1 [00:00<00:00, 43240.25it/s]
# Processing Cluster 111: 100%|████| 2/2 [00:00<00:00, 17886.16it/s]
# Processing Cluster 29: 100%|████| 59/59 [00:00<00:00, 3653.04it/s]
# Processing Cluster 129: 100%|█████| 9/9 [00:00<00:00, 8911.41it/s]
# Processing Cluster 159: 100%|███| 15/15 [00:00<00:00, 7374.82it/s]
# Processing Cluster 116: 100%|████| 2/2 [00:00<00:00, 22250.95it/s]
# Processing Cluster 68: 100%|█████| 5/5 [00:00<00:00, 26445.80it/s]

# %% [markdown]
# Here we create a data frame with the full chemical compositions of the most similar plants

# %%
import pandas as pd
import glob
import os

# Path to the chemicals data
chemicals_data_path = './initial_data/chemicals_data_clean.csv'

# Read the full chemical composition data
chemicals_df = pd.read_csv(chemicals_data_path, index_col=0)  # Assume the plant name is the index

# Get the list of high similarity plant files
high_similarity_files = glob.glob('./initial_data/clusters_euclidean/cluster_*/high_similarity_plants.csv')

# Iterate over each high similarity file
for hs_file in high_similarity_files:
    # Read the high similarity file
    hs_df = pd.read_csv(hs_file)
    
    # Get the plant names from high similarity file
    plant_names = hs_df.iloc[:, 0].unique()  # Assuming plant names are in the first column
    
    # Get the chemical compositions for the plants in high similarity file
    compositions = chemicals_df.loc[plant_names]
    
    # Save the compositions DataFrame as a CSV file in the corresponding cluster folder
    compositions.to_csv(os.path.join(os.path.dirname(hs_file), 'high_similarity_plants_compositions.csv'))

# Pattern to match your CSV files
pattern = './initial_data/clusters_euclidean/cluster_*/high_similarity_plants_compositions.csv'

# Get a list of all matching file paths
files = glob.glob(pattern)

for file in files:
    # Load the data
    df = pd.read_csv(file, index_col=0)  # Assuming the first column is the index

    # Remove columns that only contain zeros
    df = df.loc[:, (df != 0).any(axis=0)]

    # Save the dataframe back to CSV
    df.to_csv(file, index=True)

# %% [markdown]
# This code will create a bar plot with the x-axis representing main chemicals and the y-axis representing the amount.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

files = glob.glob('./initial_data/clusters_euclidean/cluster_*/high_similarity_plants_top5chemicals.csv')

barWidth = 0.15

# Use a more colorful palette
colors = sns.color_palette('Set3')

# Set the dark grid style
sns.set_style('darkgrid')

for file in files:
    df = pd.read_csv(file)
    unique_plants = []
    plants = []
    
    for i in range(len(df)):
        plant = df.iloc[i, 0]
        if plant in unique_plants:
            continue
        unique_plants.append(plant)
        
        chemicals = [df.iloc[i, j] for j in range(3, 13, 2)]
        amounts = [df.iloc[i, j]*100 for j in range(4, 14, 2)]
        
        plants.append(pd.DataFrame({"Plant": plant, "Chemical": chemicals, "Amount": amounts}))
    
    if not plants:
        continue

    fig, axs = plt.subplots(len(plants), 1, figsize=(12, 8*len(plants)))
    
    if isinstance(axs, plt.Axes):
        axs = [axs]
        
    for i, ax in enumerate(axs):
        print(plants[i]["Chemical"])
        plants[i]["Chemical"] = plants[i]["Chemical"].astype(str)

        bars = ax.bar(plants[i]["Chemical"], plants[i]["Amount"], color=colors[i % len(colors)], 
                width=barWidth, edgecolor='grey', 
                label='{}'.format(plants[i]['Plant'][0]))
        ax.set_xlabel('Chemical', fontweight='bold')
        ax.set_ylabel('Percentage (%)', fontweight='bold')
        ax.set_ylim([0, 100])

        # Add gridlines
        ax.grid(True)

        # Rotate the x-axis labels if they are overlapping
        plt.xticks(rotation=45, ha='right')

        for bar in bars:
            yval = bar.get_height()
            ax.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval,2), ha='center', va='bottom')

        ax.text(0.75, 0.5, 'Sum of main chemicals: {:.2f}%'.format(sum(plants[i]["Amount"])), 
                transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

        ax.legend()
    
    dir_name = os.path.dirname(file)
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

    fig.savefig(os.path.splitext(file)[0] + '.pdf', format='pdf', bbox_inches='tight')
    plt.close(fig)
# Out:
# 0               Geranial
# 1                  Neral
# 2        Geranyl acetate
# 3               Geraniol
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0                   Geranial
# 1                      Neral
# 2                   Geraniol
# 3            Geranyl acetate
# 4    6-Methyl-5-hepten-2-one
# Name: Chemical, dtype: object
# 0               Geranial
# 1                  Neral
# 2    Caryophyllene oxide
# 3    Citronellyl acetate
# 4     beta-Caryophyllene
# Name: Chemical, dtype: object
# 0               Geranial
# 1                  Neral
# 2    Caryophyllene oxide
# 3    Citronellyl acetate
# 4               Limonene
# Name: Chemical, dtype: object
# 0           Linalool
# 1            Camphor
# 2        para-Cymene
# 3    gamma-Terpinene
# 4           Geraniol
# Name: Chemical, dtype: object
# 0           Linalool
# 1            Camphor
# 2        para-Cymene
# 3    gamma-Terpinene
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0           Linalool
# 1       alpha-Pinene
# 2    gamma-Terpinene
# 3            Camphor
# 4    Geranyl acetate
# Name: Chemical, dtype: object
# 0           Linalool
# 1    Geranyl acetate
# 2    gamma-Terpinene
# 3            Camphor
# 4           Limonene
# Name: Chemical, dtype: object
# 0           Linalool
# 1    Geranyl acetate
# 2    gamma-Terpinene
# 3            Camphor
# 4           Geraniol
# Name: Chemical, dtype: object
# 0            Menthol
# 1           Menthone
# 2        Isomenthone
# 3    Menthyl acetate
# 4         Neomenthol
# Name: Chemical, dtype: object
# 0         Menthol
# 1        Menthone
# 2     Isomenthone
# 3        Limonene
# 4    Germacrene D
# Name: Chemical, dtype: object
# 0                Myrcene
# 1         alpha-Humulene
# 2     beta-Caryophyllene
# 3    Geranyl isobutyrate
# 4                 Citral
# Name: Chemical, dtype: object
# 0               Myrcene
# 1        alpha-Humulene
# 2    beta-Caryophyllene
# 3              Linalool
# 4                Citral
# Name: Chemical, dtype: object
# 0         Sabinene
# 1     alpha-Pinene
# 2      beta-Pinene
# 3    Terpinen-4-ol
# 4         Limonene
# Name: Chemical, dtype: object
# 0         Sabinene
# 1     alpha-Pinene
# 2      beta-Pinene
# 3    Terpinen-4-ol
# 4       Myristicin
# Name: Chemical, dtype: object
# 0    (E)-beta-Ocimene
# 1      gamma-Cadinene
# 2      delta-Cadinene
# 3    (Z)-beta-Ocimene
# 4      alpha-Cubebene
# Name: Chemical, dtype: object
# 0    (E)-beta-Ocimene
# 1    (Z)-beta-Ocimene
# 2     alpha-Terpineol
# 3              Indole
# 4       alpha-Thujene
# Name: Chemical, dtype: object
# 0            Eugenol
# 1           Limonene
# 2     delta-3-Carene
# 3    Eugenyl acetate
# 4        para-Cymene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1            Terpinen-4-ol
# 2                 Linalool
# 3    (E)-Cinnamyl aldehyde
# 4          Benzyl benzoate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2                 Linalool
# 3       beta-Caryophyllene
# 4       alpha-Phellandrene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    beta-Caryophyllene
# 3    alpha-Phellandrene
# 4       Eugenyl acetate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1                 Linalool
# 2         Cinnamyl acetate
# 3       beta-Caryophyllene
# 4    (E)-Cinnamyl aldehyde
# Name: Chemical, dtype: object
# 0               Eugenol
# 1              Linalool
# 2       Eugenyl acetate
# 3    beta-Caryophyllene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2              Linalool
# 3    beta-Caryophyllene
# 4       Benzyl benzoate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2       beta-Caryophyllene
# 3                 Linalool
# 4              para-Cymene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2          Benzyl benzoate
# 3       beta-Caryophyllene
# 4                 Linalool
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    beta-Caryophyllene
# 3              Linalool
# 4     Cinnamyl aldehyde
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4                   NaN
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2                  Nerol
# 3    Caryophyllene oxide
# 4         alpha-Humulene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2        alpha-Humulene
# 3               Carvone
# 4      Methyl carvacrol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4              Chavicol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4        Methyl eugenol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1      (Z)-beta-Ocimene
# 2         Terpinen-4-ol
# 3           3-Hexenol-1
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1         beta-Selinene
# 2              Limonene
# 3    beta-Caryophyllene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1           1,8-Cineole
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2              Limonene
# 3    beta-Caryophyllene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3       alpha-Terpineol
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0           1,8-Cineole
# 1           beta-Pinene
# 2        alpha-Humulene
# 3    beta-Caryophyllene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0           1,8-Cineole
# 1           beta-Pinene
# 2        alpha-Humulene
# 3    beta-Caryophyllene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0           1,8-Cineole
# 1    alpha-Phellandrene
# 2          alpha-Pinene
# 3       alpha-Terpineol
# 4              Sabinene
# Name: Chemical, dtype: object
# 0      1,8-Cineole
# 1    alpha-Cadinol
# 2          Camphor
# 3         Linalool
# 4     alpha-Pinene
# Name: Chemical, dtype: object
# 0           1,8-Cineole
# 1               Camphor
# 2              Camphene
# 3    alpha-Phellandrene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0        1,8-Cineole
# 1    alpha-Terpineol
# 2            Myrcene
# 3        beta-Pinene
# 4    Geranyl acetate
# Name: Chemical, dtype: object
# 0        1,8-Cineole
# 1    alpha-Terpineol
# 2           Geraniol
# 3           Linalool
# 4           Myrcenol
# Name: Chemical, dtype: object
# 0           1,8-Cineole
# 1    beta-Caryophyllene
# 2    (Z)-beta-Farnesene
# 3         beta-Selinene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0           1,8-Cineole
# 1         beta-Selinene
# 2    beta-Caryophyllene
# 3    (Z)-beta-Farnesene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0    Bornyl acetate
# 1           Camphor
# 2           Borneol
# 3          Camphene
# 4          Limonene
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2        para-Cymene
# 3    alpha-Terpinene
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3    alpha-Terpineol
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3        para-Cymene
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3        1,8-Cineole
# 4        Terpinolene
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3        1,8-Cineole
# 4        para-Cymene
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3        1,8-Cineole
# 4        para-Cymene
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3        Terpinolene
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0      Terpinen-4-ol
# 1    gamma-Terpinene
# 2    alpha-Terpinene
# 3        1,8-Cineole
# 4        Terpinolene
# Name: Chemical, dtype: object
# 0                         Methyl chavicol
# 1    Sesquiterpene hydrocarbons (unknown)
# 2                        (Z)-beta-Ocimene
# 3                            (E)-Anethole
# 4                                Limonene
# Name: Chemical, dtype: object
# 0            Methyl chavicol
# 1                   Limonene
# 2    2-Methoxycinnamaldehyde
# 3                    Carvone
# 4                    Menthol
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        beta-Pinene
# 2       alpha-Pinene
# 3       Anisaldehyde
# 4       (E)-Anethole
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        beta-Pinene
# 2           Camphene
# 3            Camphor
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0               Methyl chavicol
# 1    Nerolidol (unknown isomer)
# 2                Methyl eugenol
# 3                  Anisaldehyde
# 4                   beta-Pinene
# Name: Chemical, dtype: object
# 0       Methyl chavicol
# 1           1,8-Cineole
# 2              Linalool
# 3               Camphor
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1            Linalool
# 2         1,8-Cineole
# 3    (Z)-beta-Ocimene
# 4             Camphor
# Name: Chemical, dtype: object
# 0          Methyl chavicol
# 1    (Z,Z)-alpha-Farnesene
# 2              1,8-Cineole
# 3                 Geranial
# 4            alpha-Copaene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1         1,8-Cineole
# 2    (E)-beta-Ocimene
# 3             Eugenol
# 4            Linalool
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1      Methyl eugenol
# 2             Fenchol
# 3            Linalool
# 4    alpha-Bisabolene
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        1,8-Cineole
# 2        para-Cymene
# 3     Methyl eugenol
# 4           Linalool
# Name: Chemical, dtype: object
# 0         Methyl chavicol
# 1             1,8-Cineole
# 2          Methyl eugenol
# 3        (E)-beta-Ocimene
# 4    10-epi-alpha-Cadinol
# Name: Chemical, dtype: object
# 0       Methyl chavicol
# 1           1,8-Cineole
# 2        Methyl eugenol
# 3    beta-Caryophyllene
# 4              Linalool
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1      Methyl eugenol
# 2         1,8-Cineole
# 3            Linalool
# 4    alpha-Bisabolene
# Name: Chemical, dtype: object
# 0              Methyl chavicol
# 1                     Linalool
# 2                      Eugenol
# 3                  1,8-Cineole
# 4    Cadinene (unknown isomer)
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        1,8-Cineole
# 2           Linalool
# 3        para-Cymene
# 4     Methyl eugenol
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        1,8-Cineole
# 2     Methyl eugenol
# 3            Borneol
# 4           Linalool
# Name: Chemical, dtype: object
# 0            Methyl chavicol
# 1                1,8-Cineole
# 2            beta-Bisabolene
# 3         beta-Caryophyllene
# 4    p-Methoxycinnamaldehyde
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        1,8-Cineole
# 2    gamma-Terpinene
# 3           Linalool
# 4     Methyl eugenol
# Name: Chemical, dtype: object
# 0       Methyl chavicol
# 1           1,8-Cineole
# 2      (Z)-beta-Ocimene
# 3    (E)-beta-Farnesene
# 4              Linalool
# Name: Chemical, dtype: object
# 0       Methyl chavicol
# 1           1,8-Cineole
# 2      (Z)-beta-Ocimene
# 3    (E)-beta-Farnesene
# 4              Linalool
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1         1,8-Cineole
# 2      Methyl eugenol
# 3    (Z)-beta-Ocimene
# 4        beta-Elemene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1         1,8-Cineole
# 2    (Z)-beta-Ocimene
# 3            Linalool
# 4        (E)-Anethole
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        para-Cymene
# 2      Terpinen-4-ol
# 3        1,8-Cineole
# 4           Linalool
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1        1,8-Cineole
# 2           Limonene
# 3           Linalool
# 4        para-Cymene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1         1,8-Cineole
# 2      Methyl eugenol
# 3            Linalool
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0                Methyl chavicol
# 1     Allyl-2,4-dimethoxybenzene
# 2                      3-Nonanol
# 3    Bisabolene (unknown isomer)
# 4                    Zingiberene
# Name: Chemical, dtype: object
# 0               Methyl chavicol
# 1    Allyl-2,4-dimethoxybenzene
# 2                   beta-Pinene
# 3             beta-Phellandrene
# 4                           NaN
# Name: Chemical, dtype: object
# 0    Methyl chavicol
# 1           Limonene
# 2    gamma-Terpinene
# 3           Anethole
# 4     Methyl eugenol
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (E)-beta-Ocimene
# 2    (Z)-beta-Ocimene
# 3            Limonene
# 4      Methyl eugenol
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (E)-beta-Ocimene
# 2    (Z)-beta-Ocimene
# 3        alpha-Pinene
# 4                 NaN
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (E)-beta-Ocimene
# 2    (Z)-beta-Ocimene
# 3            Limonene
# 4                 NaN
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (Z)-beta-Ocimene
# 2    (E)-beta-Ocimene
# 3            Limonene
# 4        alpha-Pinene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (E)-beta-Ocimene
# 2    (Z)-beta-Ocimene
# 3            Limonene
# 4            Sabinene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (E)-beta-Ocimene
# 2    (Z)-beta-Ocimene
# 3            Limonene
# 4        alpha-Pinene
# Name: Chemical, dtype: object
# 0     Methyl chavicol
# 1    (E)-beta-Ocimene
# 2    (Z)-beta-Ocimene
# 3            Limonene
# 4     gamma-Terpinene
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1               ar-Curcumene
# 2    beta-Sesquiphellandrene
# 3            beta-Bisabolene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0                Zingiberene
# 1               ar-Curcumene
# 2    beta-Sesquiphellandrene
# 3            beta-Bisabolene
# 4                   Camphene
# Name: Chemical, dtype: object
# 0              Limonene
# 1               Myrcene
# 2      (E)-beta-Ocimene
# 3          alpha-Pinene
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3        para-Cymene
# 4             Thymol
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Linalool
# 3        Sabinene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Linalool
# 3    alpha-Pinene
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Linalool
# 3        Sabinene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Linalool
# 3    alpha-Pinene
# 4         Octanal
# Name: Chemical, dtype: object
# 0                     Limonene
# 1                      Myrcene
# 2                     Sabinene
# 3                     Linalool
# 4    Sinensal (unknown isomer)
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    gamma-Terpinene
# 3           Sabinene
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3    alpha-Pinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3        Linalool
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    Linalyl acetate
# 3       alpha-Pinene
# 4            Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2     beta-Pinene
# 3    alpha-Pinene
# 4         Decanal
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2           Sabinene
# 3       alpha-Pinene
# 4    beta-Bisabolene
# Name: Chemical, dtype: object
# 0       Limonene
# 1        Myrcene
# 2       Sabinene
# 3        Octanal
# 4    para-Cymene
# Name: Chemical, dtype: object
# 0              Limonene
# 1               Myrcene
# 2    alpha-Phellandrene
# 3          alpha-Pinene
# 4              Sabinene
# Name: Chemical, dtype: object
# 0              Limonene
# 1               Myrcene
# 2          alpha-Pinene
# 3              Sabinene
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4         Octanal
# Name: Chemical, dtype: object
# 0            Limonene
# 1             Myrcene
# 2        alpha-Pinene
# 3            Sabinene
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0                             Limonene
# 1                              Myrcene
# 2    cis-Linalool oxide (5) (furanoid)
# 3                           Nootkatone
# 4                             Sabinene
# Name: Chemical, dtype: object
# 0      Limonene
# 1       Myrcene
# 2      Sabinene
# 3    Nootkatone
# 4      Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3     para-Cymene
# 4      Nootkatone
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2      Nootkatone
# 3     para-Cymene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2         Octanal
# 3        Sabinene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3    alpha-Pinene
# 4         Octanal
# Name: Chemical, dtype: object
# 0                               Limonene
# 1                                Myrcene
# 2    cis-Linalool oxide (unknown isomer)
# 3                             Nootkatone
# 4                               Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2      Nootkatone
# 3    alpha-Pinene
# 4        Sabinene
# Name: Chemical, dtype: object
# 0      Limonene
# 1       Myrcene
# 2      Sabinene
# 3    Nootkatone
# 4       Decanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2         Decanal
# 3    alpha-Pinene
# 4         Octanal
# Name: Chemical, dtype: object
# 0    Limonene
# 1     Myrcene
# 2     Octanal
# 3    Sabinene
# 4     Decanal
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3       alpha-Pinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3       alpha-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Linalool
# 3    alpha-Pinene
# 4        Sabinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2       alpha-Pinene
# 3           Linalool
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0             Limonene
# 1      gamma-Terpinene
# 2              Myrcene
# 3         alpha-Pinene
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0             Limonene
# 1      gamma-Terpinene
# 2              Myrcene
# 3         alpha-Pinene
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3           Linalool
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3     beta-Pinene
# 4        Sabinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    alpha-Terpinene
# 3       alpha-Pinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0            Limonene
# 1             Myrcene
# 2            Linalool
# 3        alpha-Pinene
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0              Limonene
# 1       gamma-Terpinene
# 2               Myrcene
# 3          alpha-Pinene
# 4    (E)-beta-Farnesene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2        beta-Pinene
# 3       alpha-Pinene
# 4    Linalyl acetate
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    Linalyl acetate
# 3       alpha-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2        beta-Pinene
# 3    Linalyl acetate
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    Linalyl acetate
# 3           Meranzin
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0            Limonene
# 1             Myrcene
# 2    (E)-beta-Ocimene
# 3     Linalyl acetate
# 4        alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3     beta-Pinene
# 4        Sabinene
# Name: Chemical, dtype: object
# 0             Limonene
# 1              Myrcene
# 2    beta-Phellandrene
# 3             Linalool
# 4             Sabinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    Linalyl acetate
# 3        beta-Pinene
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2     beta-Pinene
# 3        Sabinene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0          Limonene
# 1           Myrcene
# 2    delta-3-Carene
# 3          Linalool
# 4       beta-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    beta-Bisabolene
# 3       alpha-Pinene
# 4          1-Nonanol
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3       alpha-Pinene
# 4    alpha-Farnesene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4         Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Decanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3    alpha-Pinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Decanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3        Linalool
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3         Octanal
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3        Linalool
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Linalool
# 3    alpha-Pinene
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3    alpha-Pinene
# 4     beta-Pinene
# Name: Chemical, dtype: object
# 0       Limonene
# 1        Myrcene
# 2       Sabinene
# 3    beta-Pinene
# 4        Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    alpha-Farnesene
# 3           Linalool
# 4    gamma-Terpinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4        Linalool
# Name: Chemical, dtype: object
# 0    Limonene
# 1     Myrcene
# 2     Decanal
# 3    Linalool
# 4    Geraniol
# Name: Chemical, dtype: object
# 0                              Limonene
# 1                               Myrcene
# 2                          alpha-Pinene
# 3                              Linalool
# 4    Limonene oxide (unknown structure)
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Decanal
# Name: Chemical, dtype: object
# 0            Limonene
# 1             Myrcene
# 2            Linalool
# 3        alpha-Pinene
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Decanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4         Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Sabinene
# 4         Decanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2         Octanal
# 3         Decanal
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Octanal
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3         Octanal
# 4        Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3         Octanal
# 4        Sabinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3         Octanal
# 4         Decanal
# Name: Chemical, dtype: object
# 0                    Limonene
# 1              delta-3-Carene
# 2                    Linalool
# 3                     Carvone
# 4    cis-Limonene-1,2-epoxide
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4        Sabinene
# Name: Chemical, dtype: object
# 0         Limonene
# 1          Myrcene
# 2     alpha-Pinene
# 3    Octyl acetate
# 4     Germacrene D
# Name: Chemical, dtype: object
# 0             Limonene
# 1              Myrcene
# 2          beta-Pinene
# 3         alpha-Pinene
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0            Limonene
# 1            Sabinene
# 2             Myrcene
# 3     beta-Bisabolene
# 4    (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3     delta-Cadinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0                 Limonene
# 1          gamma-Terpinene
# 2                  Myrcene
# 3             alpha-Pinene
# 4    (E,E)-alpha-Farnesene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2        Sabinene
# 3         Octanal
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2     beta-Pinene
# 3    alpha-Pinene
# 4     1,8-Cineole
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2       alpha-Pinene
# 3    gamma-Terpinene
# 4           Sabinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    gamma-Terpinene
# 3       alpha-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3       alpha-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1            Myrcene
# 2    gamma-Terpinene
# 3       alpha-Pinene
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3       alpha-Pinene
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0           Limonene
# 1    gamma-Terpinene
# 2            Myrcene
# 3       alpha-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0        Limonene
# 1         Myrcene
# 2    alpha-Pinene
# 3        Linalool
# 4         Decanal
# Name: Chemical, dtype: object
# 0             Limonene
# 1              Myrcene
# 2         alpha-Pinene
# 3          beta-Pinene
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0    alpha-Terpinyl acetate
# 1               1,8-Cineole
# 2           Linalyl acetate
# 3                  Sabinene
# 4                  Linalool
# Name: Chemical, dtype: object
# 0    alpha-Terpinyl acetate
# 1               1,8-Cineole
# 2                  Linalool
# 3           alpha-Terpineol
# 4                  Limonene
# Name: Chemical, dtype: object
# 0    alpha-Terpinyl acetate
# 1               1,8-Cineole
# 2           alpha-Terpineol
# 3                  Sabinene
# 4                  Linalool
# Name: Chemical, dtype: object
# 0    alpha-Terpinyl acetate
# 1               1,8-Cineole
# 2           alpha-Terpineol
# 3               beta-Pinene
# 4                  Linalool
# Name: Chemical, dtype: object
# 0    alpha-Terpinyl acetate
# 1               1,8-Cineole
# 2           Linalyl acetate
# 3                  Sabinene
# 4                  Linalool
# Name: Chemical, dtype: object
# 0             Carvacrol
# 1           para-Cymene
# 2       gamma-Terpinene
# 3    beta-Caryophyllene
# 4               Myrcene
# Name: Chemical, dtype: object
# 0             Carvacrol
# 1           para-Cymene
# 2       gamma-Terpinene
# 3    beta-Caryophyllene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0                 Carvacrol
# 1               para-Cymene
# 2           gamma-Terpinene
# 3                   Myrcene
# 4    trans-Sabinene hydrate
# Name: Chemical, dtype: object
# 0             Carvacrol
# 1           para-Cymene
# 2       gamma-Terpinene
# 3    beta-Caryophyllene
# 4               Myrcene
# Name: Chemical, dtype: object
# 0             Carvacrol
# 1       gamma-Terpinene
# 2           para-Cymene
# 3    beta-Caryophyllene
# 4         alpha-Thujene
# Name: Chemical, dtype: object
# 0             Carvacrol
# 1           para-Cymene
# 2       gamma-Terpinene
# 3    alpha-Phellandrene
# 4       alpha-Terpinene
# Name: Chemical, dtype: object
# 0         2-Undecanone
# 1           2-Nonanone
# 2      2-Nonyl acetate
# 3    2-Undecyl acetate
# 4         2-Dodecanone
# Name: Chemical, dtype: object
# 0         2-Undecanone
# 1           2-Nonanone
# 2      2-Nonyl acetate
# 3    2-Undecyl acetate
# 4           2-Decanone
# Name: Chemical, dtype: object
# 0     Benzyl acetate
# 1    Benzyl benzoate
# 2             Phytol
# 3          Isophytol
# 4     Phytyl acetate
# Name: Chemical, dtype: object
# 0     Benzyl acetate
# 1    Benzyl benzoate
# 2             Phytol
# 3     Phytyl acetate
# 4          Isophytol
# Name: Chemical, dtype: object
# 0               Phytol
# 1    Alkanes & alkenes
# 2       Benzyl acetate
# 3            Isophytol
# 4             Linalool
# Name: Chemical, dtype: object
# 0    Benzyl benzoate
# 1     Benzyl acetate
# 2          Isophytol
# 3     Phytyl acetate
# 4             Phytol
# Name: Chemical, dtype: object
# 0     Benzyl acetate
# 1    Benzyl benzoate
# 2     Phytyl acetate
# 3             Phytol
# 4          Isophytol
# Name: Chemical, dtype: object
# 0     Benzyl acetate
# 1    Benzyl benzoate
# 2             Phytol
# 3     Phytyl acetate
# 4           Linalool
# Name: Chemical, dtype: object
# 0    Alkanes & alkenes
# 1       Benzyl acetate
# 2               Phytol
# 3            Isophytol
# 4      Benzyl benzoate
# Name: Chemical, dtype: object
# 0    Alkanes & alkenes
# 1       Benzyl acetate
# 2               Phytol
# 3            Isophytol
# 4             Linalool
# Name: Chemical, dtype: object
# 0    Alkanes & alkenes
# 1               Phytol
# 2       Benzyl acetate
# 3            Isophytol
# 4               Indole
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3    Citronellyl formate
# 4            Isomenthone
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2        Geranyl formate
# 3    Citronellyl formate
# 4            Isomenthone
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3    Citronellyl formate
# 4            Isomenthone
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3    Citronellyl formate
# 4            Isomenthone
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3    Citronellyl formate
# 4            Isomenthone
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3    Citronellyl formate
# 4        Geranyl formate
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3            Isomenthone
# 4    Citronellyl formate
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2    Citronellyl formate
# 3        Geranyl formate
# 4            Isomenthone
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3            Isomenthone
# 4    Citronellyl formate
# Name: Chemical, dtype: object
# 0            Citronellol
# 1               Geraniol
# 2               Linalool
# 3            Isomenthone
# 4    Citronellyl formate
# Name: Chemical, dtype: object
# 0     alpha-Thujone
# 1      beta-Thujone
# 2           Camphor
# 3           Borneol
# 4    Bornyl acetate
# Name: Chemical, dtype: object
# 0     alpha-Thujone
# 1      beta-Thujone
# 2           Camphor
# 3           Borneol
# 4    Bornyl acetate
# Name: Chemical, dtype: object
# 0          Camphor
# 1    alpha-Thujone
# 2      1,8-Cineole
# 3         Camphene
# 4     beta-Thujone
# Name: Chemical, dtype: object
# 0           Limonene
# 1           Linalool
# 2    Linalyl acetate
# 3           Geraniol
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Limonene
# 2           Linalool
# 3        beta-Pinene
# 4    gamma-Terpinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2        beta-Pinene
# 3           Linalool
# 4    gamma-Terpinene
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Limonene
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2    gamma-Terpinene
# 3        beta-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2    gamma-Terpinene
# 3        beta-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Limonene
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2    gamma-Terpinene
# 3        beta-Pinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2           Linalool
# 3    gamma-Terpinene
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           Limonene
# 1    Linalyl acetate
# 2    gamma-Terpinene
# 3           Linalool
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0              Thymol
# 1           Carvacrol
# 2         para-Cymene
# 3     gamma-Terpinene
# 4    Methyl carvacrol
# Name: Chemical, dtype: object
# 0              Thymol
# 1           Carvacrol
# 2         para-Cymene
# 3     gamma-Terpinene
# 4    Methyl carvacrol
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1           beta-Pinene
# 2              Limonene
# 3    beta-Caryophyllene
# 4               Myrcene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1              Camphene
# 2              Limonene
# 3    beta-Caryophyllene
# 4           beta-Pinene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1    beta-Caryophyllene
# 2              Limonene
# 3           beta-Pinene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1    beta-Caryophyllene
# 2              Limonene
# 3           beta-Pinene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0          Pulegone
# 1       Isomenthone
# 2          Limonene
# 3    Pulegone oxide
# 4          Menthone
# Name: Chemical, dtype: object
# 0       Pulegone
# 1       Menthone
# 2       Menthene
# 3    1,8-Cineole
# 4       Limonene
# Name: Chemical, dtype: object
# 0           Pulegone
# 1           Menthone
# 2           Limonene
# 3    cis-Isopulegone
# 4           Linalool
# Name: Chemical, dtype: object
# 0              Pulegone
# 1              Menthone
# 2           Isomenthone
# 3             3-Octanol
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0        Pulegone
# 1        Menthone
# 2     Isomenthone
# 3    Piperitenone
# 4       3-Octanol
# Name: Chemical, dtype: object
# 0             Pulegone
# 1             Menthene
# 2             Limonene
# 3          1,8-Cineole
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0       alpha-Pinene
# 1        1,8-Cineole
# 2            Camphor
# 3    alpha-Terpineol
# 4            Borneol
# Name: Chemical, dtype: object
# 0            Sabinene
# 1            Linalool
# 2       Terpinen-4-ol
# 3    (E)-beta-Ocimene
# 4      delta-3-Carene
# Name: Chemical, dtype: object
# 0            Sabinene
# 1            Linalool
# 2    (E)-beta-Ocimene
# 3       Terpinen-4-ol
# 4            Limonene
# Name: Chemical, dtype: object
# 0     Linalyl acetate
# 1            Linalool
# 2         beta-Pinene
# 3    (E)-beta-Ocimene
# 4     alpha-Terpineol
# Name: Chemical, dtype: object
# 0           Linalool
# 1    Linalyl acetate
# 2    alpha-Terpineol
# 3        beta-Pinene
# 4           Geraniol
# Name: Chemical, dtype: object
# 0           Linalool
# 1    Linalyl acetate
# 2    alpha-Terpineol
# 3           Geraniol
# 4    Geranyl acetate
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2            Camphor
# 3        1,8-Cineole
# 4            Borneol
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2            Camphor
# 3        1,8-Cineole
# 4            Borneol
# Name: Chemical, dtype: object
# 0           Linalool
# 1    Linalyl acetate
# 2            Camphor
# 3        1,8-Cineole
# 4            Borneol
# Name: Chemical, dtype: object
# 0              Linalool
# 1       Linalyl acetate
# 2    Lavandulyl acetate
# 3               Borneol
# 4           1-Octenol-3
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2      (Z)-beta-Ocimene
# 3    Lavandulyl acetate
# 4         Terpinen-4-ol
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2        1,8-Cineole
# 3            Camphor
# 4      Terpinen-4-ol
# Name: Chemical, dtype: object
# 0              Linalool
# 1       Linalyl acetate
# 2    beta-Caryophyllene
# 3      (E)-beta-Ocimene
# 4      (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2    beta-Caryophyllene
# 3      (Z)-beta-Ocimene
# 4      (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2    Lavandulyl acetate
# 3      (Z)-beta-Ocimene
# 4            3-Octanone
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2    Lavandulyl acetate
# 3      (Z)-beta-Ocimene
# 4            3-Octanone
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2           Limonene
# 3        beta-Pinene
# 4            Myrcene
# Name: Chemical, dtype: object
# 0         (E)-Anethole
# 1      Methyl chavicol
# 2    Anisyl propionate
# 3      Anisyl butyrate
# 4         Anisaldehyde
# Name: Chemical, dtype: object
# 0          (E)-Anethole
# 1       Methyl chavicol
# 2          Anisaldehyde
# 3    beta-Caryophyllene
# 4               Carvone
# Name: Chemical, dtype: object
# 0    (E)-Anethole
# 1        Limonene
# 2    Anisaldehyde
# 3     Anisalcohol
# 4    (Z)-Anethole
# Name: Chemical, dtype: object
# 0                                         (E)-Anethole
# 1                           Sesquiterpene hydrocarbons
# 2    2-(1-E-Propenyl)-5-methoxyphenyl 2-methylbutyrate
# 3                                      Methyl chavicol
# 4                                         Anisaldehyde
# Name: Chemical, dtype: object
# 0       (E)-Anethole
# 1    Methyl chavicol
# 2       Anisaldehyde
# 3      Isochavibetol
# 4       (Z)-Anethole
# Name: Chemical, dtype: object
# 0              (E)-Anethole
# 1           Methyl chavicol
# 2              (Z)-Anethole
# 3                   Carvone
# 4    p-Methoxyphenylacetone
# Name: Chemical, dtype: object
# 0     (E)-Anethole
# 1      Anisalcohol
# 2     Anisaldehyde
# 3     (Z)-Anethole
# 4    Isochavibetol
# Name: Chemical, dtype: object
# 0             (E)-Anethole
# 1             (Z)-Anethole
# 2          Methyl chavicol
# 3    4-Methoxyacetophenone
# 4             Anisaldehyde
# Name: Chemical, dtype: object
# 0                                         (E)-Anethole
# 1                 Sesquiterpene hydrocarbons (unknown)
# 2    2-(1-E-Propenyl)-5-methoxyphenyl 2-methylbutyrate
# 3                                      Methyl chavicol
# 4                                         Anisaldehyde
# Name: Chemical, dtype: object
# 0                                         (E)-Anethole
# 1                                      Methyl chavicol
# 2                                    gamma-Himachalene
# 3    2-(1-E-Propenyl)-5-methoxyphenyl 2-methylbutyrate
# 4                                         Anisaldehyde
# Name: Chemical, dtype: object
# 0             (E)-Anethole
# 1          Methyl chavicol
# 2    (E)-Cinnamyl aldehyde
# 3                Carvacrol
# 4                    Ionol
# Name: Chemical, dtype: object
# 0                          (E)-Anethole
# 1                       Methyl chavicol
# 2                          alpha-Pinene
# 3                       alpha-Farnesene
# 4    Monoterpene hydrocarbons (unknown)
# Name: Chemical, dtype: object
# 0       (E)-Anethole
# 1    Methyl chavicol
# 2       (Z)-Anethole
# 3       Anisaldehyde
# 4           Linalool
# Name: Chemical, dtype: object
# 0       (E)-Anethole
# 1           Fenchone
# 2           Limonene
# 3    Methyl chavicol
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0       (E)-Anethole
# 1           Fenchone
# 2    Methyl chavicol
# 3           Limonene
# 4    gamma-Terpinene
# Name: Chemical, dtype: object
# 0       (E)-Anethole
# 1    Methyl chavicol
# 2           Limonene
# 3           Fenchone
# 4       Anisaldehyde
# Name: Chemical, dtype: object
# 0    (E)-Anethole
# 1        Limonene
# 2    (Z)-Anethole
# 3        Fenchone
# 4     1,8-Cineole
# Name: Chemical, dtype: object
# 0           (E)-Anethole
# 1        Methyl chavicol
# 2    trans-Isoosmorhizol
# 3       (Z)-beta-Ocimene
# 4     beta-Caryophyllene
# Name: Chemical, dtype: object
# 0       (E)-Anethole
# 1    Methyl chavicol
# 2           Linalool
# 3           Limonene
# 4       alpha-Pinene
# Name: Chemical, dtype: object
# 0      (E)-Anethole
# 1          Limonene
# 2        Foeniculin
# 3          Linalool
# 4    delta-3-Carene
# Name: Chemical, dtype: object
# 0                         (E)-Nerolidol
# 1                    (E)-alpha-Farnesol
# 2            Bisabolol (unknown isomer)
# 3    Sesquiterpenes, oxygen-containing-
# 4                                   NaN
# Name: Chemical, dtype: object
# 0     (E)-Nerolidol
# 1      beta-Elemene
# 2    alpha-Cubebene
# 3          Limonene
# 4     beta-Eudesmol
# Name: Chemical, dtype: object
# 0           beta-Thujone
# 1    cis-Ocimene epoxide
# 2       (Z)-beta-Ocimene
# 3            Chamazulene
# 4           Germacrene D
# Name: Chemical, dtype: object
# 0           beta-Thujone
# 1    cis-Ocimene epoxide
# 2       (Z)-beta-Ocimene
# 3                Camphor
# 4               Sabinene
# Name: Chemical, dtype: object
# 0    Piperitenone oxide
# 1          Germacrene D
# 2           1,8-Cineole
# 3          Piperitenone
# 4            Piperitone
# Name: Chemical, dtype: object
# 0             Piperitenone oxide
# 1                   Germacrene D
# 2    Bisabolene (unknown isomer)
# 3               Piperitone oxide
# 4                 Dihydrocarveol
# Name: Chemical, dtype: object
# 0        Benzaldehyde
# 1    Hydrocyanic acid
# 2      Benzyl alcohol
# 3        Benzoic acid
# 4                 NaN
# Name: Chemical, dtype: object
# 0        Benzaldehyde
# 1    Hydrocyanic acid
# 2                 NaN
# 3                 NaN
# 4                 NaN
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1       Methyl thymol
# 2            Sabinene
# 3         para-Cymene
# 4    (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1       Methyl thymol
# 2            Sabinene
# 3         para-Cymene
# 4    (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2    alpha-Terpineol
# 3    Geranyl acetate
# 4      Neryl acetate
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1    beta-Caryophyllene
# 2       beta-Bisabolene
# 3              Linalool
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2    beta-Caryophyllene
# 3       beta-Bisabolene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2    alpha-Terpineol
# 3            Myrcene
# 4           Geraniol
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2    alpha-Terpineol
# 3    Geranyl acetate
# 4           Geraniol
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2       alpha-Terpineol
# 3               Camphor
# 4    beta-Caryophyllene
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2          Germacrene D
# 3    beta-Caryophyllene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2    beta-Caryophyllene
# 3       alpha-Terpineol
# 4       Geranyl acetate
# Name: Chemical, dtype: object
# 0    Linalyl acetate
# 1           Linalool
# 2       Germacrene D
# 3    alpha-Terpineol
# 4    Geranyl acetate
# Name: Chemical, dtype: object
# 0        Linalyl acetate
# 1               Linalool
# 2        alpha-Terpineol
# 3    Caryophyllene oxide
# 4     beta-Caryophyllene
# Name: Chemical, dtype: object
# 0       Linalyl acetate
# 1              Linalool
# 2               Carvone
# 3    beta-Caryophyllene
# 4    alpha-Phellandrene
# Name: Chemical, dtype: object
# 0        Linalyl acetate
# 1               Linalool
# 2      beta-Phellandrene
# 3               Geraniol
# 4    Citronellyl formate
# Name: Chemical, dtype: object
# 0        Methyl eugenol
# 1              Elemicin
# 2       Methyl chavicol
# 3    beta-Caryophyllene
# 4         alpha-Elemene
# Name: Chemical, dtype: object
# 0           Methyl eugenol
# 1            Terpinen-4-ol
# 2         (E)-beta-Ocimene
# 3               Calamenene
# 4    (E)-Methyl isoeugenol
# Name: Chemical, dtype: object
# 0        beta-Caryophyllene
# 1                  Linalool
# 2       Caryophyllene oxide
# 3            alpha-Humulene
# 4    alpha-Terpinyl acetate
# Name: Chemical, dtype: object
# 0         (E)-2-Hexenal
# 1    beta-Caryophyllene
# 2           1,8-Cineole
# 3              Linalool
# 4               Myrcene
# Name: Chemical, dtype: object
# 0                 (E)-2-Hexenal
# 1            beta-Caryophyllene
# 2                   1,8-Cineole
# 3                       Myrcene
# 4    Nerolidol (unknown isomer)
# Name: Chemical, dtype: object
# 0                  (-)-Menthol
# 1               (+)-Neomenthol
# 2              (+)-Isomenthone
# 3         Menthones & menthols
# 4    Menthol (unknown isomers)
# Name: Chemical, dtype: object
# 0            Citronellol
# 1    Citronellyl formate
# 2            Isomenthone
# 3               Geraniol
# 4          alpha-Guaiene
# Name: Chemical, dtype: object
# 0              Citronellol
# 1      Citronellyl formate
# 2              Isomenthone
# 3                 Geraniol
# 4    2-Phenylethyl tiglate
# Name: Chemical, dtype: object
# 0         Limonene
# 1         Linalool
# 2         Sabinene
# 3    Terpinen-4-ol
# 4         Geranial
# Name: Chemical, dtype: object
# 0         Limonene
# 1         Linalool
# 2         Sabinene
# 3    Terpinen-4-ol
# 4      para-Cymene
# Name: Chemical, dtype: object
# 0    Methyl cinnamate
# 1            Linalool
# 2     Linalyl acetate
# 3             Camphor
# 4     Methyl chavicol
# Name: Chemical, dtype: object
# ...
# 3    beta-Caryophyllene
# 4              Camphene
# Name: Chemical, dtype: object
# 0           alpha-Pinene
# 1    Dimyrcene (isomers)
# 2            beta-Pinene
# 3                Myrcene
# 4               Sabinene
# Name: Chemical, dtype: object
# 0         alpha-Pinene
# 1             Limonene
# 2          beta-Pinene
# 3      Methyl chavicol
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0         alpha-Pinene
# 1    beta-Phellandrene
# 2             Camphene
# 3             Limonene
# 4          beta-Pinene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1       Longifolene
# 2    delta-3-Carene
# 3          Camphene
# 4       para-Cymene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1              Limonene
# 2    alpha-Phellandrene
# 3        delta-3-Carene
# 4     beta-Phellandrene
# Name: Chemical, dtype: object
# 0                  alpha-Pinene
# 1                   beta-Pinene
# 2                      Limonene
# 3                      Camphene
# 4    Sesquiterpene hydrocarbons
# Name: Chemical, dtype: object
# 0    alpha-Pinene
# 1     beta-Pinene
# 2        Limonene
# 3         Myrcene
# 4        2-Carene
# Name: Chemical, dtype: object
# 0    alpha-Pinene
# 1         Myrcene
# 2        Limonene
# 3        Camphene
# 4     beta-Pinene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1           Myrcene
# 2    alpha-Humulene
# 3     Terpinen-4-ol
# 4          Limonene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1           Myrcene
# 2    alpha-Humulene
# 3          Limonene
# 4       beta-Pinene
# Name: Chemical, dtype: object
# 0       alpha-Pinene
# 1        beta-Pinene
# 2           Camphene
# 3            Borneol
# 4    alpha-Terpineol
# Name: Chemical, dtype: object
# 0        Eugenol
# 1       Chavicol
# 2        Myrcene
# 3       Linalool
# 4    3-Octenol-1
# Name: Chemical, dtype: object
# 0     Eugenol
# 1    Chavicol
# 2     Myrcene
# 3    Linalool
# 4    Limonene
# Name: Chemical, dtype: object
# 0            Eugenol
# 1    Eugenyl acetate
# 2         Isoeugenol
# 3            Safrole
# 4           Chavicol
# Name: Chemical, dtype: object
# 0            Eugenol
# 1           Limonene
# 2     delta-3-Carene
# 3    Eugenyl acetate
# 4        para-Cymene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1            Terpinen-4-ol
# 2                 Linalool
# 3    (E)-Cinnamyl aldehyde
# 4          Benzyl benzoate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2                 Linalool
# 3       beta-Caryophyllene
# 4       alpha-Phellandrene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    beta-Caryophyllene
# 3    alpha-Phellandrene
# 4       Eugenyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    alpha-Phellandrene
# 3              Linalool
# 4       Eugenyl acetate
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1                 Linalool
# 2         Cinnamyl acetate
# 3       beta-Caryophyllene
# 4    (E)-Cinnamyl aldehyde
# Name: Chemical, dtype: object
# 0             Eugenol
# 1     Benzyl benzoate
# 2     Eugenyl acetate
# 3            Linalool
# 4    Cinnamyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1              Linalool
# 2       Eugenyl acetate
# 3    beta-Caryophyllene
# 4    alpha-Phellandrene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2              Linalool
# 3    beta-Caryophyllene
# 4       Benzyl benzoate
# Name: Chemical, dtype: object
# 0             Eugenol
# 1            Linalool
# 2          Piperitone
# 3     Eugenyl acetate
# 4    Cinnamyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2     Cinnamyl aldehyde
# 3           1,8-Cineole
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2       beta-Caryophyllene
# 3                 Linalool
# 4              para-Cymene
# Name: Chemical, dtype: object
# 0                  Eugenol
# 1    (E)-Cinnamyl aldehyde
# 2          Benzyl benzoate
# 3       beta-Caryophyllene
# 4                 Linalool
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Benzyl benzoate
# 2    beta-Caryophyllene
# 3              Linalool
# 4     Cinnamyl aldehyde
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2              Linalool
# 3    beta-Caryophyllene
# 4      Cinnamyl acetate
# Name: Chemical, dtype: object
# 0               Eugenol
# 1       Eugenyl acetate
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4        Benzyl alcohol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0                Eugenol
# 1        Eugenyl acetate
# 2     beta-Caryophyllene
# 3    Caryophyllene oxide
# 4         Methyl eugenol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2    Caryophyllene oxide
# 3         alpha-Humulene
# 4        Eugenyl acetate
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4        Methyl eugenol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2        Eugenyl acetate
# 3         alpha-Humulene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2         alpha-Humulene
# 3    Caryophyllene oxide
# 4          alpha-Copaene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4              Chavicol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2       Eugenyl acetate
# 3        alpha-Humulene
# 4        Methyl eugenol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1      (Z)-beta-Ocimene
# 2         beta-Cubebene
# 3    beta-Caryophyllene
# 4         Terpinen-4-ol
# Name: Chemical, dtype: object
# 0             Eugenol
# 1    (Z)-beta-Ocimene
# 2     alpha-Muurolene
# 3    Isocaryophyllene
# 4      alpha-Cadinene
# Name: Chemical, dtype: object
# 0                Eugenol
# 1     beta-Caryophyllene
# 2         delta-Cadinene
# 3        gamma-Muurolene
# 4    iso-gamma-Muurolene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2       Methyl chavicol
# 3    beta-Caryophyllene
# 4               Camphor
# Name: Chemical, dtype: object
# 0               Eugenol
# 1         beta-Selinene
# 2              Limonene
# 3    beta-Caryophyllene
# 4       alpha-Terpineol
# Name: Chemical, dtype: object
# 0                Eugenol
# 1       (Z)-beta-Ocimene
# 2           Germacrene D
# 3     beta-Caryophyllene
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0               Eugenol
# 1              Limonene
# 2    beta-Caryophyllene
# 3           1,8-Cineole
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1           1,8-Cineole
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1    beta-Caryophyllene
# 2           1,8-Cineole
# 3        alpha-Humulene
# 4        gamma-Cadinene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1               Myrcene
# 2    beta-Caryophyllene
# 3        Methyl eugenol
# 4              Chavicol
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2               Myrcene
# 3    beta-Caryophyllene
# 4       gamma-Terpinene
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3        alpha-Humulene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2              Limonene
# 3    beta-Caryophyllene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2               Myrcene
# 3    beta-Caryophyllene
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3       alpha-Terpineol
# 4           1,8-Cineole
# Name: Chemical, dtype: object
# 0               Eugenol
# 1        Methyl eugenol
# 2    beta-Caryophyllene
# 3        alpha-Selinene
# 4       alpha-Muurolene
# Name: Chemical, dtype: object
# 0            Eugenol
# 1        1,8-Cineole
# 2      Terpinen-4-ol
# 3    alpha-Terpineol
# 4     Methyl eugenol
# Name: Chemical, dtype: object
# 0            Eugenol
# 1        para-Cymene
# 2       alpha-Pinene
# 3    Eugenyl acetate
# 4        1,8-Cineole
# Name: Chemical, dtype: object
# 0      Cuminaldehyde
# 1    gamma-Terpinene
# 2        para-Cymene
# 3      Cumin alcohol
# 4           Limonene
# Name: Chemical, dtype: object
# 0        para-Cymene
# 1    gamma-Terpinene
# 2       alpha-Pinene
# 3           Sabinene
# 4            Myrcene
# Name: Chemical, dtype: object
# 0            para-Cymene
# 1          beta-Eudesmol
# 2           alpha-Pinene
# 3            Spathulenol
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0              Cuminaldehyde
# 1                para-Cymene
# 2                beta-Pinene
# 3            gamma-Terpinene
# 4    p-Isopropylbenzoic acid
# Name: Chemical, dtype: object
# 0           gamma-Terpinene
# 1             Cuminaldehyde
# 2    p-Mentha-1,3-dien-7-al
# 3               beta-Pinene
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1               beta-Pinene
# 2           gamma-Terpinene
# 3    p-Mentha-1,3-dien-7-al
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1           gamma-Terpinene
# 2    p-Mentha-1,4-dien-7-al
# 3               beta-Pinene
# 4    p-Mentha-1,3-dien-7-al
# Name: Chemical, dtype: object
# 0           gamma-Terpinene
# 1             Cuminaldehyde
# 2               para-Cymene
# 3    p-Mentha-1,3-dien-7-al
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2               beta-Pinene
# 3           gamma-Terpinene
# 4    p-Mentha-1,3-dien-7-al
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2           gamma-Terpinene
# 3    p-Mentha-1,3-dien-7-al
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2           gamma-Terpinene
# 3               beta-Pinene
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2    p-Mentha-1,3-dien-7-al
# 3           gamma-Terpinene
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0    p-Mentha-1,4-dien-7-al
# 1             Cuminaldehyde
# 2           gamma-Terpinene
# 3    p-Mentha-1,3-dien-7-al
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1           gamma-Terpinene
# 2               beta-Pinene
# 3    p-Mentha-1,3-dien-7-al
# 4               para-Cymene
# Name: Chemical, dtype: object
# 0             Cuminaldehyde
# 1           gamma-Terpinene
# 2               para-Cymene
# 3    p-Mentha-1,3-dien-7-al
# 4               beta-Pinene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1         para-Cymene
# 2         beta-Pinene
# 3       Cuminaldehyde
# 4    Perilla aldehyde
# Name: Chemical, dtype: object
# 0                             para-Cymene
# 1                      alpha-Phellandrene
# 2                            alpha-Pinene
# 3    Sesquiterpene hydrocarbons (unknown)
# 4                          delta-3-Carene
# Name: Chemical, dtype: object
# 0            para-Cymene
# 1            Spathulenol
# 2               Cryptone
# 3    Caryophyllene oxide
# 4          Terpinen-4-ol
# Name: Chemical, dtype: object
# 0     alpha-Pinene
# 1      Spathulenol
# 2      para-Cymene
# 3         Cryptone
# 4    Terpinen-4-ol
# Name: Chemical, dtype: object
# 0    gamma-Terpinene
# 1       alpha-Pinene
# 2        para-Cymene
# 3      Terpinen-4-ol
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0           para-Cymene
# 1          alpha-Pinene
# 2        Thymyl acetate
# 3    beta-Caryophyllene
# 4      (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0           para-Cymene
# 1        4-Selinenol-11
# 2    alpha-Phellandrene
# 3         Methyl thymol
# 4       beta-Bisabolene
# Name: Chemical, dtype: object
# 0       para-Cymene
# 1      alpha-Pinene
# 2       beta-Pinene
# 3    alpha-Humulene
# 4     alpha-Copaene
# Name: Chemical, dtype: object
# 0    Methyl N-methyl anthranilate
# 1                 gamma-Terpinene
# 2                        Limonene
# 3                     para-Cymene
# 4                Ethyl linolenate
# Name: Chemical, dtype: object
# 0    Methyl N-methyl anthranilate
# 1                 gamma-Terpinene
# 2                        Limonene
# 3                     para-Cymene
# 4                    alpha-Pinene
# Name: Chemical, dtype: object
# 0    gamma-Terpinene
# 1        para-Cymene
# 2           Linalool
# 3      Terpinen-4-ol
# 4        Citronellol
# Name: Chemical, dtype: object
# 0           Linalool
# 1    gamma-Terpinene
# 2     Benzyl acetate
# 3        para-Cymene
# 4     delta-3-Carene
# Name: Chemical, dtype: object
# 0      para-Cymene
# 1          Myrcene
# 2     alpha-Pinene
# 3    alpha-Thujene
# 4           Thymol
# Name: Chemical, dtype: object
# 0        para-Cymene
# 1             Thymol
# 2            Borneol
# 3    gamma-Terpinene
# 4           Linalool
# Name: Chemical, dtype: object
# 0                     gamma-Terpinene
# 1                         para-Cymene
# 2                         beta-Pinene
# 3    Muurolene(s) (unknown structure)
# 4                        beta-Elemene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1       Methyl thymol
# 2            Sabinene
# 3         para-Cymene
# 4    (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0     gamma-Terpinene
# 1       Methyl thymol
# 2            Sabinene
# 3         para-Cymene
# 4    (Z)-beta-Ocimene
# Name: Chemical, dtype: object
# 0             para-Cymene
# 1        (Z)-beta-Ocimene
# 2    Cinnamyl isovalerate
# 3         gamma-Terpinene
# 4        (E)-beta-Ocimene
# Name: Chemical, dtype: object
# 0     para-Cymene
# 1       Carvacrol
# 2         Borneol
# 3        Camphene
# 4    alpha-Pinene
# Name: Chemical, dtype: object
# 0     para-Cymene
# 1         Borneol
# 2         Camphor
# 3    alpha-Pinene
# 4        Camphene
# Name: Chemical, dtype: object
# 0            Carotol
# 1       alpha-Pinene
# 2    Geranyl acetate
# 3           Linalool
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0            Carotol
# 1       alpha-Pinene
# 2    Geranyl acetate
# 3        beta-Pinene
# 4           Sabinene
# Name: Chemical, dtype: object
# 0                Carotol
# 1               Sabinene
# 2        Geranyl acetate
# 3               Geraniol
# 4    Caryophyllene oxide
# Name: Chemical, dtype: object
# 0         alpha-Humulene
# 1     beta-Caryophyllene
# 2                Myrcene
# 3     Methyl 4-decenoate
# 4    Geranyl isobutyrate
# Name: Chemical, dtype: object
# 0        alpha-Humulene
# 1               Myrcene
# 2    beta-Caryophyllene
# 3        gamma-Cadinene
# 4        delta-Cadinene
# Name: Chemical, dtype: object
# 0    Isopinocamphone
# 1       Pinocamphone
# 2       Germacrene D
# 3        beta-Pinene
# 4        Pinocarvone
# Name: Chemical, dtype: object
# 0    Isopinocamphone
# 1        Pinocarvone
# 2       Pinocamphone
# 3       Germacrene D
# 4        beta-Pinene
# Name: Chemical, dtype: object
# 0    Isopinocamphone
# 1       Pinocamphone
# 2        beta-Pinene
# 3             Elemol
# 4       Germacrene D
# Name: Chemical, dtype: object
# 0         alpha-Pinene
# 1              Camphor
# 2             Sabinene
# 3        Terpinen-4-ol
# 4    beta-Phellandrene
# Name: Chemical, dtype: object
# 0          alpha-Pinene
# 1    beta-Caryophyllene
# 2              Limonene
# 3           beta-Pinene
# 4           para-Cymene
# Name: Chemical, dtype: object
# 0               Myrcene
# 1           1,8-Cineole
# 2               Camphor
# 3    beta-Caryophyllene
# 4          alpha-Pinene
# Name: Chemical, dtype: object
# 0         Camphor
# 1    alpha-Pinene
# 2     1,8-Cineole
# 3       Verbenone
# 4     para-Cymene
# Name: Chemical, dtype: object
# 0      alpha-Pinene
# 1           Camphor
# 2         Verbenone
# 3    Bornyl acetate
# 4          Camphene
# Name: Chemical, dtype: object
# 0                 Camphor
# 1                Sabinene
# 2             1,8-Cineole
# 3            alpha-Pinene
# 4    iso-Artemisia ketone
# Name: Chemical, dtype: object

# %% [markdown]
# The next code creates a heatmap for each CSV file, with each row in the heatmap corresponding to a plant and each column corresponding to a chemical. The color of each cell in the heatmap corresponds to the value in the CSV file for that plant and chemical. The heatmaps are then saved as PDF files.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from math import sqrt

base_dir = './initial_data/clusters_euclidean/'
cluster_dirs = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d)) and d.startswith('cluster_')]

sns.set_style("white")
cmap = sns.diverging_palette(220, 10, as_cmap=True)

for cluster_dir in tqdm(cluster_dirs, desc='Processing clusters'):
    cluster_number = cluster_dir.split('_')[-1]
    file_path = os.path.join(base_dir, cluster_dir, 'high_similarity_plants_compositions.csv')

    if os.path.isfile(file_path):
        df = pd.read_csv(file_path, index_col=0)

        if df.empty:
            continue

        top_5_chemicals = df.apply(lambda row: row.nlargest(5).index.tolist(), axis=1)
        top_5_chemicals = top_5_chemicals.apply(lambda x: pd.Index(x).drop_duplicates().tolist())
        df_top_5 = df[top_5_chemicals.explode()]
        df_top_5 *= 100

        df_transposed = df_top_5.T.drop_duplicates()

        # Sort by total abundance
        df_transposed['total_abundance'] = df_transposed.sum(axis=1)
        df_transposed.sort_values('total_abundance', ascending=False, inplace=True)
        df_transposed.drop('total_abundance', axis=1, inplace=True)

        if df_transposed.empty:
            continue

        # Dynamic sizing of the plot
        num_rows, num_cols = df_transposed.shape
        fig_width = min(max(num_cols // 2, 10), 50)  # Set a minimum width of 10 and maximum width of 50
        fig_height = min(max(num_rows // 2, 10), 50)  # Set a minimum height of 10 and maximum height of 50

        fig, ax = plt.subplots(figsize=(fig_width, fig_height))

        cell_width = fig_width / num_cols
        cell_height = fig_height / num_rows
        font_size = max(min(min(cell_width, cell_height) * 2.5, 20), 8)  # Adjust the multiplier to control the font size and set a range (8-20)

        sns.heatmap(df_transposed, cmap=cmap, annot=True, fmt=".1f", linewidths=.5,
                    cbar_kws={'label': 'Concentration (%)'},
                    vmin=0, vmax=100, ax=ax, annot_kws={"size": font_size})  # Use dynamic font size

        for t in ax.collections[0].axes.texts:  # iterate over the text elements of the heatmap
            if t.get_text() == '0.0':
                t.set_text('')  # remove the text for zero cells

        ax.set_title(f'Top 5 Abundant Chemicals in Plants with min. 90% Similarity within {cluster_dir}', fontsize=min(font_size+6, 24), pad=20)  # Use dynamic font size and set a maximum limit of 24
        ax.set_xlabel('Plants', fontsize=min(font_size+2, 22), labelpad=10)  # Use dynamic font size and set a maximum limit of 22
        ax.set_ylabel('Chemicals', fontsize=min(font_size+2, 22), labelpad=10)  # Use dynamic font size and set a maximum limit of 22
        ax.tick_params(labelsize=min(font_size, 20))  # Use dynamic font size and set a maximum limit of 20

        sns.despine()  # Remove the top and right spines from plot

        plt.xticks(rotation=90, fontsize=font_size)  # Use dynamic font size
        plt.yticks(rotation=0, fontsize=font_size)  # Use dynamic font size

        plt.tight_layout()

        save_path = os.path.join(base_dir, cluster_dir, f'heatmap_Top_5_Abundant_Chemicals_in_Plants_with_90_Similarity.pdf')
        plt.savefig(save_path, format="pdf", bbox_inches='tight')

        plt.close()

    else:
        print(f"The file {file_path} does not exist.")
# Out:
# Processing clusters: 100%|██████| 160/160 [00:23<00:00,  6.76it/s]
